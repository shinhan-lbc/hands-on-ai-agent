# %% [markdown]
# # ⚙️ 환경 설정 및 라이브러리 설치
#
# 프로젝트 실행에 필요한 파이썬 라이브러리들을 설치합니다. 각 라이브러리의 역할은 다음과 같습니다.
#
#   * **`langchain`, `langgraph`, `langchain-community`**: LangChain 및 LangGraph의 핵심 기능을 사용하기 위한 라이브러리입니다.
#   * **`langchain-google-genai`**: Google Gemini와 같은 생성형 AI 모델을 LangChain과 연동합니다.
#   * **`tavily-python`**: 실시간 정보 검색을 위한 Tavily 검색 도구를 추가합니다.
#   * **`langchain-mcp-adapters`**: 특정 어댑터(MCP)를 사용하기 위해 필요합니다.
#
# 아래 셀을 실행하여 모든 라이브러리를 한 번에 설치하세요.

# %%
# !pip install langchain==0.3.27 langgraph==0.6.6 langchain-google-genai==2.1.9 langchain-community==0.3.27 langchain-mcp-adapters==0.1.9 tavily-python==0.7.11
# Out:
# Requirement already satisfied: langchain==0.3.27 in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Requirement already satisfied: langgraph==0.6.6 in /usr/local/lib/python3.12/dist-packages (0.6.6)
# Requirement already satisfied: langchain-google-genai==2.1.9 in /usr/local/lib/python3.12/dist-packages (2.1.9)
# Requirement already satisfied: langchain-community==0.3.27 in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Requirement already satisfied: langchain-mcp-adapters==0.1.9 in /usr/local/lib/python3.12/dist-packages (0.1.9)
# Requirement already satisfied: tavily-python==0.7.11 in /usr/local/lib/python3.12/dist-packages (0.7.11)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (0.3.79)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (0.4.38)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (2.11.10)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (2.0.44)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (6.0.3)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph==0.6.6) (2.1.2)
# Requirement already satisfied: langgraph-prebuilt<0.7.0,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from langgraph==0.6.6) (0.6.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from langgraph==0.6.6) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph==0.6.6) (3.6.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai==2.1.9) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.18 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai==2.1.9) (0.6.18)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community==0.3.27) (3.13.1)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community==0.3.27) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community==0.3.27) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community==0.3.27) (2.11.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community==0.3.27) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community==0.3.27) (2.0.2)
# Requirement already satisfied: mcp>=1.9.2 in /usr/local/lib/python3.12/dist-packages (from langchain-mcp-adapters==0.1.9) (1.19.0)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from langchain-mcp-adapters==0.1.9) (4.15.0)
# Requirement already satisfied: tiktoken>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tavily-python==0.7.11) (0.12.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from tavily-python==0.7.11) (0.28.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.27) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.27) (0.9.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (2.28.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (5.29.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain==0.3.27) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain==0.3.27) (25.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph==0.6.6) (1.11.0)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph==0.6.6) (3.11.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->tavily-python==0.7.11) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx->tavily-python==0.7.11) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->tavily-python==0.7.11) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx->tavily-python==0.7.11) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->tavily-python==0.7.11) (0.16.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain==0.3.27) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain==0.3.27) (0.25.0)
# Requirement already satisfied: jsonschema>=4.20.0 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (4.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (0.49.1)
# Requirement already satisfied: uvicorn>=0.31.1 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (0.38.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.27) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.27) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.27) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.27) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain==0.3.27) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain==0.3.27) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.3.27) (3.2.4)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.5.1->tavily-python==0.7.11) (2024.11.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx->tavily-python==0.7.11) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (1.71.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (4.9.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain==0.3.27) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (0.28.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.27) (1.1.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.31.1->mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (8.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (0.6.1)

# %% [markdown]
# # API 키 설정 가이드
#
# API를 사용하기 위한 키 설정 방법을 안내합니다. 각 서비스별로 아래 절차를 따라주세요.
#
# -----
#
# ## ✨ Gemini API 키 설정
#
# 1.  **API 키 발급받기**
#     Gemini API를 사용하려면 먼저 API 키가 필요합니다. Google AI Studio에서 클릭 한 번으로 간편하게 키를 생성하세요.
#
#     <a class="button button-primary" href="https://makersuite.google.com/app/apikey" target="_blank" rel="noopener noreferrer">API 키 받기</a>
#
# 2.  **Colab에 키 저장하기**
#     Colab의 왼쪽 패널에서 "🔑" 아이콘(보안 비밀)을 열어, 발급받은 키를 **`GOOGLE_API_KEY`** 라는 이름으로 저장하세요.
#
# 3.  **코드에서 키 사용하기**
#     SDK는 **환경 변수**로 저장된 키를 자동으로 인식하여 사용합니다. Colab 보안 비밀에 저장한 키는 아래와 같이 불러올 수 있습니다.
#
#     ```python
#     # SDK가 자동으로 키를 인식합니다
#     os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")
#     ```
#
# -----
#
# ## 🔍 Tavily API 키 설정
#
# 1.  **API 키 발급받기**
#     Tavily 검색 API를 사용하려면 API 키를 발급받아야 합니다. Tavily 대시보드에서 키를 생성하고 복사하세요.
#
#     <a class="button button-primary" href="https://app.tavily.com" target="_blank" rel="noopener noreferrer">Tavily API 키 받기</a>
#
#     > ✅ **참고:** Tavily는 무료 플랜을 제공하여 간단한 테스트나 소규모 프로젝트를 부담 없이 시작할 수 있습니다.
#
# 2.  **Colab에 키 저장하기**
#     Colab의 "🔑" 아이콘(보안 비밀)을 열어, 발급받은 키를 **`TAVILY_API_KEY`** 라는 이름으로 저장하세요.
#
# 3.  **코드에서 키 사용하기**
#     Tavily SDK 역시 **환경 변수**로 저장된 키를 자동으로 찾아 사용합니다.
#
#     ```python
#     # SDK가 자동으로 키를 인식합니다
#     os.environ["TAVILY_API_KEY"] = userdata.get("TAVILY_API_KEY")
#     ```

# %%
import os
from google.colab import userdata

# Gemini API 키 설정
os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

# Tavily API 키 설정
os.environ["TAVILY_API_KEY"] = userdata.get("TAVILY_API_KEY")

print("API 키 설정이 완료되었습니다.")
# Out:
# API 키 설정이 완료되었습니다.

# %% [markdown]
# # 🔍 검색 도구(Tavily) 정의 및 테스트
#
# 이 단계에서는 **Tavily 검색 API**를 사용하는 LangChain 검색 도구를 정의하고, 정상적으로 작동하는지 테스트합니다. 이 도구는 Agent가 외부 최신 정보에 접근해야 할 때 사용됩니다.
#
#   * **도구 정의**: `TavilySearchResults`를 가져와 `search_tool`이라는 이름의 도구를 생성합니다.
#   * **결과 수 제한**: `max_results=3` 파라미터를 설정하여, 검색 시 최대 3개의 관련성 높은 결과만 반환하도록 제한합니다.
#   * **테스트 실행**: `"삼성전자 현재 주가"`와 같은 실제 검색어를 입력하여 도구가 외부 정보를 잘 가져오는지 확인합니다.

# %%
from langchain_community.tools.tavily_search import TavilySearchResults

# Tavily 검색 도구를 정의하고, 반환 결과의 수를 3개로 제한합니다.
search_tool = TavilySearchResults(max_results=3)

# 정의된 도구가 잘 작동하는지 'invoke'를 통해 테스트합니다.
results = search_tool.invoke({"query": "삼성전자 현재 주가"})
print(results)
# Out:
# [{'title': '삼성전자 (005930) - 인베스팅닷컴', 'url': 'https://kr.investing.com/equities/samsung-electronics-co-ltd', 'content': 'PLTR\n\n+3.04%\n\n## 자주 묻는 질문\n\n### 오늘 삼성전자 (005930)의 주가는?\n\n오늘 삼성전자 주가는 107,500입니다.\n\n### 삼성전자은(는) 어떤 증권 거래소에서 거래되나요?\n\n삼성전자은(는) 서울 증권 거래소 증권 거래소에 상장되어 거래되고 있습니다.\n\n### 삼성전자의 주식 티커는?\n\n삼성전자의 주식 티커는 “005930”입니다.\n\n### 삼성전자은(는) 배당을 지급하나요? 현재 배당수익률은 얼마인가요?\n\n삼성전자 배당수익률은 1.38%입니다.\n\n### 삼성전자 시가총액은 얼마인가요?\n\n오늘 현재 삼성전자 시가총액은 700.06T입니다.\n\n### 삼성전자의 주당순이익(TTM)은 얼마인가요?\n\n삼성전자의 EPS(TTM)는 4,606.36입니다.\n\n### 삼성전자의 다음 실적 발표일은 언제인가요?\n\n삼성전자은(는) 2026년 1월 28일에 다음 실적 보고서를 발표할 예정입니다.\n\n### 삼성전자에는 몇 명의 직원이 있나요? [...] 삼성전자의 직원은 128735명입니다.\n\n### 삼성전자(005930)의 현재 거래는 어떤가요?\n\n2025년 10월 31일 기준, 삼성전자(005930)은(는) 107,500 가격에 거래되고 있으며 이전 종가는 104,100.00입니다. 일간 범위는 103,300~108,600이고, 52주 범위는 49,900~108,600입니다.\n\n### 삼성전자(005930)의 애널리스트 목표주가는 얼마인가요?\n\n삼성전자의 12개월 목표주가 평균은 KRW112219.64706입니다. 목표주가 최고치 KRW150000, 최저치는 KRW58500입니다. 29명의 애널리스트는 매수 의견, 1명은 매도 의견을 제시했으며, 전반적인 투자의견 등급은 매수입니다. 이 주식은 +4.39% 상승 여력 있음 잠재력이 있습니다.\n\n주식 중개업체(브로커) 찾기\n\n1일\n\n1주\n\n1달\n\n6달\n\n1년\n\n5년\n\n최대\n\n코스피지수\n\n4,107.50\n\n+20.61\n\n+0.50%\n\n코스피200 선물 (F) (F)") [...] 적극 매수\n\n적극 매도\n\n매도\n\n중립\n\n매수\n\n적극 매수\n\n애널리스트 센티멘트\n\n매수\n\n목표 주가 \n\n112,220\n\n상승 여력 있음\n\n+4.39%\n\n유저들의 센티멘트\n\n하락\n\n상승\n\nProTips\n\n복잡한 금융 데이터를 간결하고 실행 가능한 투자 통찰력으로 추출하는 팁.\n\n16개 모두 확인\n\n대차대조표에 부채보다 현금을 더 많이 보유하고 있음\n\n적정가치\n\n현금흐름 할인법, 동종업계 밸류에이션 멀티플, 배당할인모형 등 가치평가 모형을 기반으로 산출한 주식의 실제 가격 추정치입니다.\n\n가치 공개\n\n금일 변동\n\n103,300108,600\n\n52주 변동폭\n\n49,900108,600\n\n주요 통계\n\n편집하기\n\n005930의 지표 더 보기\n\n매수/매도\n:   107,500.00 / 107,600.00\n\n전일 종가\n:   104,100\n\n금일 시가\n:   105,000\n\n금일 변동\n:   103,300-108,600\n\n52주 변동폭\n:   49,900-108,600', 'score': 0.90102744}, {'title': '삼성전자(005930) - 네이버 금융 - NAVER', 'url': 'https://finance.naver.com/item/main.nhn?code=005930', 'content': '메인 메뉴로 바로가기 본문으로 바로가기\n\n# 네이버 페이 증권\n\n 증권 홈\n 국내증시선택됨\n 해외증시\n 시장지표\n 리서치\n 뉴스\n MY\n\n종목 시세 정보\n:   2025년 10월 30일 14시 03분 기준 장중\n:   종목명 삼성전자\n:   종목코드 005930 코스피\n:   현재가 103,800 전일대비 상승 3,300 플러스 3.28 퍼센트\n:   전일가 100,500\n:   시가 102,400\n:   고가 105,800\n:   상한가 130,600\n:   저가 102,000\n:   하한가 70,400\n:   거래량 28,805,126\n:   거래대금 2,992,087백만\n\n## 삼성전자\n\n005930 날짜  2025.10.30 14:03 기준(KRX 장중)   실시간   기업개요\n\n#### 기업개요\n\n동사는 1969년 설립된 글로벌 전자 기업이며, DX 부문 9개, DS 부문 5개 해외 지역총괄과 230개 종속기업으로 구성되어 있음. [...] 넥스트레이드(NXT)\n\n넥스트레이드(NXT) 넥스트레이드(NXT)란 대한민국 최초의 대체거래소(ATS, Alternative Trading System)입니다.\n\n삼성전자\n:   오늘의시세 103,800 포인트\n:   3,300 포인트 상승\n:   3.28% 플러스\n\n103,800 103,800\n\n전일대비  상승 3,300 3,300  l  + 3.28 3.28 %\n\n주요 시세\n\n     | 전일  100,500 100,500 | 고가  105,800105,800  (상한가  130,600130,600  ) | 거래량  28,805,126 28,805,126 |\n| 시가  102,400102,400 | 저가  102,000102,000  (하한가  70,400  ) | 거래대금  2,992,087 2,992,087  백만 |\n\n삼성전자\n:   오늘의시세 103,750 포인트\n:   3,250 포인트 상승\n:   3.23% 플러스\n\n103,750 103,750 [...] | 종목명 | 삼성전자\\005930 | SK하이닉스\\000660 | 한미반도체\\042700 | 리노공업058470 | 원익IPS\\240810 |\n| 현재가 | 103,800 | 570,000 | 142,100 | 57,800 | 64,600 |\n| 전일대비 | 상향 3,300 | 상향 12,000 | 상향 3,900 | 하향 600 | 하향 1,200 |\n| 등락률 | 상향 +3.28% | 상향 +2.15% | 상향 +2.82% | 하향 -1.03% | 하향 -1.82% |\n| 시가총액(억) | 6,144,584 | 4,149,613 | 135,438 | 44,050 | 31,708 |\n| 외국인비율(%) | 52.26 | 54.60 | 7.75 | 34.42 | 27.07 |\n| 매출액(억) | 745,663 | 222,320 | 1,800 | 1,125 | 2,422 |\n| 영업이익(억) | 46,761 | 92,129 | 863 | 534 | 365 |', 'score': 0.87166095}, {'title': '삼성전자(005930) 주가 및 뉴스 - Google Finance', 'url': 'https://www.google.com/finance/quote/005930:KRX?hl=ko&ref=thepickool.com', 'content': '일정 부분의 회사 소유권 및 보유한 주식 수에 해당하는 회사 자산과 이익의 지분을 주장할 권리입니다.\n\nKR에 본사 소재\n\n대한민국 경기도 수원시에 본사가 있습니다.\n\n전일 종가\n\n전일 마감 종가입니다.\n\n₩69,600.00\n\n일일 변동폭\n\n전일 최고가와 최저가 사이의 범위입니다.\n\n₩69,700.00 - ₩70,500.00\n\n52주 변동폭\n\n지난 52주 동안 최고가와 최저가 사이의 범위입니다.\n\n₩49,900.00 - ₩75,000.00\n\n시가총액\n\n회사의 주가와 총 발행 주식 수를 곱한 평가 방법입니다.\n\n465.68조 KRW\n\n평균 거래량\n\n지난 30일 동안 매일 거래된 평균 주식 수입니다.\n\n1,743.06만\n\n주가수익률\n\n현재 주가 대 12개월 후행 EPS의 비율로서 주가가 다른 주식과  ...

# %% [markdown]
# # 🤖 Agent 설정 및 상태(State) 정의
#
# Agent의 핵심 구성 요소를 설정합니다. Agent의 **'두뇌'** 역할을 하는 **LLM(거대 언어 모델)**과, 작업 흐름 전반에 걸쳐 정보를 저장하고 공유하는 **'메모리'** 역할의 **상태(State)**를 정의합니다.
#
#   * **LLM (두뇌) 설정**: Agent의 추론과 판단을 담당할 언어 모델로 **Google의 `Gemini 1.5 Flash`**를 설정합니다. 이 모델은 빠른 응답 속도와 우수한 성능을 균형 있게 제공합니다.
#   * **AgentState (메모리) 정의**: Agent가 각 단계를 거치며 얻는 정보를 저장하고 공유할 데이터 구조인 `AgentState`를 정의합니다. LangGraph에서는 이 **상태(State)** 객체를 통해 각 노드(작업 단위)가 정보를 주고받습니다.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph, END
from typing import TypedDict, List

# 1. Agent의 '두뇌' 역할을 할 LLM을 설정합니다.
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash-lite")

# 2. Agent의 작업 내용을 기억하고 공유할 '메모리' 구조(State)를 정의합니다.
class AgentState(TypedDict):
    """
    Agent의 상태를 정의합니다. 모든 노드는 이 상태를 공유하며 정보를 업데이트합니다.

    Attributes:
        company_name: 분석할 회사의 이름 (사용자 입력)
        stock_price: 검색된 주가 정보
        news: 검색된 관련 뉴스 목록
    """
    company_name: str
    stock_price: str
    news: List[str]

# %% [markdown]
# # 🧩 Agent 작업 노드(Node) 함수 정의
#
# Agent 워크플로우를 구성하는 각 **노드(Node)**의 실제 동작을 함수로 정의합니다. 각 함수는 **`AgentState`** 를 입력받아 특정 작업을 수행하고, 그 결과를 다시 **`AgentState`** 에 저장하거나 최종 결과를 생성하는 역할을 합니다.
#
#   * **`stock_price_search_node`**: `AgentState`에서 **회사 이름**을 가져와 **주가**를 검색하고, 결과를 상태에 업데이트합니다.
#   * **`news_search_node`**: `AgentState`에서 **회사 이름**을 가져와 **최신 뉴스 3개**를 검색하고, 결과를 상태에 업데이트합니다.
#   * **`analysis_node`**: 모든 정보가 채워진 `AgentState`를 기반으로, **LLM에게 전달할 상세 프롬프트**를 생성합니다. LLM은 이 프롬프트를 바탕으로 최종 분석 리포트를 생성하며, 이 노드는 상태를 추가로 업데이트하지 않고 리포트를 출력하는 것으로 작업을 마칩니다.

# %%
def stock_price_search_node(state: AgentState):
    """주어진 회사 이름으로 현재 주가를 검색하는 노드"""
    print("--- (1/3) 주가 정보 검색 중... ---")
    company_name = state["company_name"]

    # Tavily 도구를 사용하여 주가 정보 검색
    stock_price = search_tool.invoke({"query": f"{company_name} 현재 주가"})
    return {"stock_price": stock_price}

def news_search_node(state: AgentState):
    """주어진 회사 이름으로 최신 뉴스를 검색하는 노드"""
    print("--- (2/3) 관련 뉴스 검색 중... ---")
    company_name = state["company_name"]

    # Tavily 도구를 사용하여 최신 뉴스 3개 검색
    news = search_tool.invoke({"query": f"{company_name} 최신 주요 뉴스 3개"})
    return {"news": news}

def analysis_node(state: AgentState):
    """수집된 정보를 바탕으로 종합 분석 리포트를 생성하는 노드"""
    print("--- (3/3) 종합 분석 리포트 생성 중... ---")
    company_name = state["company_name"]
    stock_price = state["stock_price"]
    news = state["news"]

    # Gemini LLM에게 전달할 프롬프트(지시문) 작성
    prompt = f"""
    당신은 전문 주식 애널리스트입니다. 다음 정보를 바탕으로 '{company_name}'에 대한 투자 분석 리포트를 작성해주세요.

    **[분석 정보]**
    1. **현재 주가**: {stock_price}
    2. **관련 최신 뉴스**: {news}

    **[리포트 작성 가이드라인]**
    - **개요**: 현재 상황을 간결하게 요약합니다.
    - **긍정적 요인**: 주가에 긍정적인 영향을 줄 수 있는 요소를 뉴스 내용에 기반하여 분석합니다.
    - **부정적 요인**: 주가에 부정적인 영향을 줄 수 있는 요소를 뉴스 내용에 기반하여 분석합니다.
    - **종합 의견 및 투자 전략**: 위 내용을 종합하여 최종 투자 의견과 간단한 전략을 제시해주세요. 전문가적이지만 이해하기 쉬운 톤으로 작성해주세요.

    **주의**: 이 리포트는 정보 제공 및 교육적 목적으로 작성되었으며, 실제 투자 권유가 아님을 반드시 명시해주세요.
    """

    # LLM을 호출하여 분석 리포트 생성
    response = llm.invoke(prompt)

    print("\n\n--- [AI 주식 분석 리포트] ---")
    print(response.content)
    print("---------------------------\n")

    # 이 노드는 최종 출력을 담당하므로 state를 추가로 업데이트하지 않음
    return

# %% [markdown]
# # ⛓️ Agent 워크플로우 그래프 생성 및 실행
#
# 앞서 정의한 **노드(Node)** 함수들을 **LangGraph**를 사용하여 연결하고, 실행 가능한 **Agent**를 완성합니다. 전체 과정은 **그래프 정의 → 컴파일 및 시각화 → 실행**의 3단계로 진행됩니다.
#
# ### 1\. 워크플로우 정의
#
# 먼저 `StateGraph` 객체를 생성하고, `add_node`를 이용해 각 작업 함수를 노드로 추가합니다. 그 후, `set_entry_point`로 시작 노드를 지정하고, `add_edge`로 노드들을 **주가 검색 → 뉴스 검색 → 분석** 순서로 연결하여 순차적인 워크플로우를 만듭니다.
#
# ```python
# # 노드 실행 순서를 정의합니다.
# workflow.set_entry_point("stock_price_search")
# workflow.add_edge("stock_price_search", "news_search")
# workflow.add_edge("news_search", "analysis")
# workflow.add_edge("analysis", END)
# ```
#
# ### 2\. 그래프 컴파일
#
# 정의된 워크플로우를 `compile()` 메서드를 통해 실행 가능한 애플리케이션(`app`)으로 만듭니다.
#
# ```python
# # 그래프를 실행 가능한 app으로 컴파일합니다.
# app = workflow.compile()
# ```
#
# ### 3\. Agent 실행 및 결과 확인
#
# 컴파일된 `app`에 분석할 회사 이름을 입력하여 Agent를 실행합니다. \*\*`app.stream()`\*\*을 사용하면 각 노드가 실행될 때마다 중간 결과와 상태 변화를 실시간으로 확인할 수 있어, Agent의 작동 과정을 단계별로 추적하는 데 유용합니다.
#
# ```python
# # app.stream()을 통해 각 단계의 실행 과정을 실시간으로 확인합니다.
# for event in app.stream(inputs):
#     ...
# ```

# %%
## 1. 워크플로우 정의
# 그래프의 상태(State)는 AgentState로 정의합니다.
workflow = StateGraph(AgentState)

# 1) 정의한 함수들을 노드로 추가합니다.
workflow.add_node("stock_price_search", stock_price_search_node)
workflow.add_node("news_search", news_search_node)
workflow.add_node("analysis", analysis_node)

# 2) 노드 실행 순서를 정의합니다. (A -> B -> C -> 종료)
workflow.set_entry_point("stock_price_search") # 시작점
workflow.add_edge("stock_price_search", "news_search")
workflow.add_edge("news_search", "analysis")
workflow.add_edge("analysis", END) # 'analysis' 노드 실행 후 워크플로우를 종료합니다.

## 2. 그래프 컴파일 및 시각화
# 1) 그래프를 실행 가능한 app으로 컴파일합니다.
app = workflow.compile()

# 2-1) app 객체에서 Mermaid 다이어그램 문법(텍스트)을 생성합니다.
mermaid_syntax = app.get_graph().draw_mermaid()
# 2-2) 이 Mermaid 텍스트를 HTML과 Javascript로 감싸서 렌더링할 준비를 합니다.
import textwrap
html_code = f"""
<div style="background-color: white; border: 1px solid #ddd; padding: 10px; border-radius: 5px;">
    <pre class="mermaid">{textwrap.dedent(mermaid_syntax)}</pre>
</div>
<script type="module">
    import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.esm.min.mjs';
    await mermaid.run();
</script>
"""
# 2-3) Colab/Jupyter 환경에서 HTML 코드를 실행하여 다이어그램을 출력합니다.
from IPython.display import display, HTML
display(HTML(html_code))


## 3. Agent 실행 및 결과 확인
# 1) Agent에게 전달할 초기 입력값입니다.
inputs = {"company_name": "삼성전자"}

# 2) app.stream()을 통해 각 단계의 실행 과정을 실시간으로 확인합니다.
for event in app.stream(inputs):
    pass
# Out:
# <div style="background-color: white; border: 1px solid #ddd; padding: 10px; border-radius: 5px;">
#     <pre class="mermaid">---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	stock_price_search(stock_price_search)
# 	news_search(news_search)
# 	analysis(analysis)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> stock_price_search;
# 	news_search --> analysis;
# 	stock_price_search --> news_search;
# 	analysis --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
# </pre>
# </div>
# <script type="module">
#     import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.esm.min.mjs';
#     await mermaid.run();
# </script>
# --- (1/3) 주가 정보 검색 중... ---
# --- (2/3) 관련 뉴스 검색 중... ---
# --- (3/3) 종합 분석 리포트 생성 중... ---
#
#
# --- [AI 주식 분석 리포트] ---
# ## 삼성전자 (005930) 투자 분석 리포트
#
# **본 리포트는 정보 제공 및 교육적 목적으로 작성되었으며, 실제 투자 권유가 아님을 명시합니다.**
#
# **1. 개요**
#
# 삼성전자(005930)는 현재 서울 증권 거래소에서 107,500원에 거래되고 있으며, 1.38%의 배당수익률을 제공합니다.  최근 2025년 3분기 실적 발표에서 역대 최대 분기 매출을 기록하며 긍정적인 신호를 보냈습니다.  29명의 애널리스트가 매수 의견을 제시하고 있으며, 12개월 목표주가 평균은 112,220원으로, 현재 주가 대비 4.39%의 상승 여력이 있다고 평가됩니다.
#
# **2. 긍정적 요인**
#
# *   **역대 최대 분기 매출**: 2025년 3분기 실적 발표에서 전사 매출이 전분기 대비 15% 증가하며 역대 최대 분기 매출을 기록했습니다. 이는 삼성전자의 강력한 시장 경쟁력과 사업 다각화를 입증하는 긍정적인 신호입니다.
# *   **메모리 부문의 성장**: DS 부문은 HBM3E 및 서버 SSD 판매 확대로 분기 최대 메모리 매출을 달성했습니다. 특히 HBM3E는 전 고객 대상으로 양산 판매 중이며, HBM4도 샘플 출하를 시작하며 고성능 메모리 시장에서의 선두 자리를 굳건히 하고 있습니다.
# *   **DX 부문의 성장**: 폴더블 신모델 출시 효과와 견조한 플래그십 스마트폰 판매 등으로 DX 부문 매출이 전분기 대비 11% 성장했습니다.  이는 삼성전자의 스마트폰 시장에서의 경쟁력과 혁신적인 제품 출시 전략이 효과를 거두고 있음을 보여줍니다.
# *   **AI 팩토리 구축**: 엔비디아와의 협력을 통해 "업계 최고 수준 반도체 AI 팩토리" 구축을 발표했습니다. 이는 반도체 제조 기술 경쟁력 강화와 미래 성장 동력 확보에 기여할 것으로 예상됩니다.
# *   **지속적인 R&D 투자**: 3분기 누계 기준 역대 최대 26.9조원의 연구개발비를 집행하며 미래 기술 경쟁력 확보에 대한 의지를 보여주고 있습니다.
#
# **3. 부정적 요인**
#
# *   **거시경제 불확실성**: 전반적인 경제 상황의 불확실성은 반도체 및 IT 제품 수요에 영향을 미칠 수 있습니다.
# *   **경쟁 심화**:  글로벌 반도체 시장 경쟁이 치열해짐에 따라, 기술 우위 유지를 위한 지속적인 노력이 필요합니다.
# *   **지속적인 변동성**: 52주 변동폭이 49,900 ~ 108,600으로, 주가 변동성이 존재합니다.
#
# **4. 종합 의견 및 투자 전략**
#
# 삼성전자는 긍정적인 실적 발표와 기술 경쟁력 강화 노력을 통해 긍정적인 성장 모멘텀을 확보하고 있습니다. 특히, HBM 시장에서의 선전과 AI 팩토리 구축, 그리고 지속적인 R&D 투자는 장기적인 성장 가능성을 높이는 요인입니다.  다만, 거시경제 불확실성과 경쟁 심화 등은 주의해야 할 리스크 요인입니다.
#
# **투자 의견: 매수**
#
# **투자 전략:**
#
# *   **장기 투자 관점**: 삼성전자는 장기적인 성장 잠재력이 높은 기업으로 판단됩니다.  단기적인 주가 변동에 일희일비하지 않고, 장기적인 관점에서 꾸준히 투자하는 전략을 추천합니다.
# *   **분할 매수**:  주가 변동성에 대비하여, 목표 가격을 정하고 분할 매수를 통해 리스크를 관리하는 것이 좋습니다.
# *   **포트폴리오 분산**:  삼성전자 외에도 다양한 산업 분야의 우량주에 분산 투자하여, 포트폴리오의 안정성을 확보하는 것이 중요합니다.
# *   **실적 발표 및 관련 뉴스 지속적인 모니터링**: 삼성전자의 분기별 실적 발표와 주요 뉴스에 대한 지속적인 모니터링을 통해 투자 결정을 보완하는 것이 필요합니다.
#
# **Disclaimer:** 본 리포트는 투자 판단의 참고 자료이며, 투자 결과에 대한 책임을 지지 않습니다. 투자 결정은 본인의 판단과 책임 하에 신중하게 이루어져야 합니다.
# ---------------------------

# %% [markdown]
# # 📜 MCP 서버 스크립트 정의 (`search_server.py`)
#
# 이 스크립트는 **MCP(Model Context Protocol)**를 사용하여 금융 정보 검색 **도구(Tool)**들을 마이크로서비스 형태로 제공하는 **Python 서버**입니다. `search_server.py`라는 파일로 저장되며, 독립적으로 실행하여 다른 애플리케이션이나 Agent가 네트워크를 통해 이 도구들을 호출할 수 있도록 합니다.
#
# #### 📝 제공하는 핵심 도구들
#
# 서버가 제공하는 핵심 도구는 다음과 같으며, 모두 LangChain의 `@tool` 데코레이터를 사용하여 표준화되었습니다.
#
#   * **`get_stock_price`**: 특정 회사의 현재 주가를 검색합니다.
#   * **`get_latest_news`**: 회사와 관련된 최신 뉴스를 검색합니다. `topic`을 지정하여 검색 주제를 좁힐 수 있습니다.
#   * **`get_company_overview`**: 회사가 어떤 사업을 하는지 등 전반적인 개요를 검색합니다.
#   * **`get_analyst_opinions`**: 해당 회사에 대한 증권사 애널리스트들의 최신 투자 의견을 검색합니다.
#
# #### ⚙️ 서버 구성 방식
#
# 정의된 LangChain 도구들을 `langchain-mcp-adapters`를 통해 MCP 사양을 따르는 `FastMCP` 서버에 탑재합니다. 스크립트가 직접 실행되면(`if __name__ == "__main__":`), `streamable-http` 전송 방식으로 서버가 구동됩니다.

# %%
# %%writefile /content/search_server.py
# ==================================
# Part 1: 라이브러리 임포트
# ==================================
from langchain_core.tools import tool
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_mcp_adapters.tools import to_fastmcp
from mcp.server.fastmcp import FastMCP
from typing import Optional

# ==================================
# Part 2: 핵심 도구 초기화 및 정의
# ==================================
# Tavily 검색 엔진 초기화 (최대 1개 결과만 사용)
tavily_search = TavilySearchResults(max_results=1)

@tool
def get_stock_price(company_name: str) -> str:
    """
    특정 회사의 현재 실시간 주가를 검색합니다.
    '삼성전자'와 같이 회사 이름만 정확히 입력해야 합니다.
    """
    print(f"Executing get_stock_price for: {company_name}")
    return tavily_search.invoke({"query": f"{company_name} 현재 주가"})

@tool
def get_latest_news(company_name: str, topic: Optional[str] = None) -> str:
    """
    특정 회사와 관련된 최신 뉴스를 검색합니다.
    더 구체적인 뉴스를 원할 경우 '실적', '신제품' 등 관련 주제(topic)를 지정할 수 있습니다.
    """
    search_query = f"{company_name} {topic or '최신'} 뉴스"
    print(f"Executing get_latest_news with query: {search_query}")
    return tavily_search.invoke({"query": search_query})

@tool
def get_company_overview(company_name: str) -> str:
    """
    특정 회사가 어떤 사업을 하는지, 주요 제품은 무엇인지 등 사업의 전반적인 개요를 검색합니다.
    """
    print(f"Executing get_company_overview for: {company_name}")
    return tavily_search.invoke({"query": f"{company_name} 사업 개요 what they do"})

@tool
def get_analyst_opinions(company_name: str) -> str:
    """
    특정 회사에 대한 증권사 애널리스트들의 최신 리포트나 투자 의견을 검색합니다.
    """
    print(f"Executing get_analyst_opinions for: {company_name}")
    return tavily_search.invoke({"query": f"{company_name} 증권사 애널리스트 리포트 요약"})

# ==================================
# Part 3: MCP 서버 설정 및 실행
# ==================================
# 정의된 모든 도구들을 리스트로 취합
all_tools = [
    get_stock_price,
    get_latest_news,
    get_company_overview,
    get_analyst_opinions,
]

# LangChain 도구를 FastMCP 형식으로 변환
fastmcp_tools = [to_fastmcp(t) for t in all_tools]

# FastMCP 서버 인스턴스 생성
mcp = FastMCP(
    "FinancialInfoProvider",  # 서비스 이름
    tools=fastmcp_tools,
)

# 스크립트가 직접 실행될 때 서버를 구동
if __name__ == "__main__":
    mcp.run(transport="streamable-http")
# Out:
# Overwriting /content/search_server.py

# %% [markdown]
# # 🚀 금융 정보 MCP 서버 시작
#
# 앞서 작성한 `search_server.py` 스크립트를 백그라운드에서 실행하여 **MCP 서버**를 시작합니다. 이 서버는 Agent가 네트워크를 통해 금융 정보 도구를 호출할 수 있는 엔드포인트 역할을 합니다.
#
# #### 📝 실행 명령어 분석
#
# 아래 셀은 서버를 안정적으로 시작하기 위해 여러 명령어를 조합하여 사용합니다. 각 부분의 역할은 다음과 같습니다.
#
#   * **`lsof -ti tcp:8000 | xargs -r kill`**: 만약 이전에 실행된 서버가 **포트 8000**을 사용하고 있다면, 해당 프로세스를 찾아 먼저 종료시킵니다. 이는 포트 충돌을 방지합니다.
#   * **`rm -f search_server.log`**: 이전 실행에서 남은 로그 파일이 있다면 삭제하여 깨끗한 상태에서 시작합니다.
#   * **`nohup python ... &`**: **`nohup`**과 **`&`**를 사용하여 `search_server.py`를 **백그라운드 프로세스**로 실행합니다. 이렇게 하면 노트북의 다른 셀을 계속 실행하거나 터미널 연결이 끊어져도 서버는 계속 동작합니다.
#   * **`> search_server.log 2>&1`**: 서버 실행 중 발생하는 모든 출력(로그, 에러)을 `search_server.log` 파일에 저장합니다.
#   * **`time.sleep(3)`**: 서버가 완전히 시작될 때까지 잠시(3초) 기다려주는 역할을 합니다.

# %%
import os
import time

def start_and_check_search_server():
    """
    금융 정보 MCP 서버(search_server.py)를 시작하고,
    로그 파일을 폴링하여 서버가 성공적으로 시작되었는지 확인합니다.
    """

    print("🚀 금융 정보 MCP 서버를 시작합니다...")

    # 포트 8000을 사용하는 기존 프로세스를 종료하고, 백그라운드에서 새 서버를 실행합니다.
    server_command = "lsof -ti tcp:8000 | xargs -r kill; rm -f search_server.log; nohup python -u search_server.py > search_server.log 2>&1 &"
    os.system(server_command)

    # --- 서버 로그 파일 확인 및 상태 출력 ---
    timeout_seconds = 30  # 최대 대기 시간 (초)
    check_interval = 2   # 로그 확인 주기 (초)
    start_time = time.time()

    server_status = "PENDING"
    log_content = ""

    print(f"⏱️  서버 시작 대기 중... (최대 {timeout_seconds}초)")

    while time.time() - start_time < timeout_seconds:
        try:
            with open('search_server.log', 'r') as f:
                log_content = f.read()

            # 비교를 위해 로그 전체를 소문자로 변경
            log_content_lower = log_content.lower()

            # 성공 조건 확인
            if "uvicorn running on" in log_content_lower and "application startup complete" in log_content_lower:
                server_status = "SUCCESS"
                break

            # 실패 조건 확인
            if "traceback" in log_content_lower or "error" in log_content_lower:
                server_status = "FAILED"
                break

            print("   ...로그 파일 확인 중...")
            time.sleep(check_interval)

        except FileNotFoundError:
            # 로그 파일이 아직 생성되지 않았을 수 있으므로 잠시 대기
            print("   ...로그 파일 생성 대기 중...")
            time.sleep(check_interval)
        except Exception as e:
            print(f"로그 파일 읽기 중 예외 발생: {e}")
            log_content = f"로그 파일 읽기 오류: {e}"
            server_status = "FAILED"
            break

    # --- 최종 결과 출력 ---
    print("-" * 30)

    if server_status == "SUCCESS":
        print("✅ 금융 정보 MCP 서버가 성공적으로 시작되어 실행 중입니다.")
        print(f"   (로그 파일: {os.getcwd()}/search_server.log)")

    elif server_status == "FAILED":
        print("❌ 로그 확인 결과: 서버 실행 중 오류가 발생했습니다. 아래 로그를 확인하세요.")
        print("-" * 20)
        print(log_content)
        print("-" * 20)

    else: # PENDING (Timeout)
        print(f"🤔 {timeout_seconds}초 내에 서버 시작 메시지를 확인하지 못했습니다.")
        print("   서버가 느리게 시작 중이거나, 확인 문자열이 로그에 없는 것 같습니다.")
        print("\n   [현재 search_server.log 내용]")
        print("-" * 20)
        print(log_content if log_content else "[로그 파일이 비어 있거나 생성되지 않았습니다]")
        print("-" * 20)

# --- 함수 실행 ---
start_and_check_search_server()
# Out:
# 🚀 금융 정보 MCP 서버를 시작합니다...
# ⏱️  서버 시작 대기 중... (최대 30초)
#    ...로그 파일 생성 대기 중...
#    ...로그 파일 확인 중...
#    ...로그 파일 확인 중...
# ------------------------------
# ✅ 금융 정보 MCP 서버가 성공적으로 시작되어 실행 중입니다.
#    (로그 파일: /content/search_server.log)

# %% [markdown]
# # 🤖 자율(ReAct) Agent 워크플로우
#
# 이번에는 이전의 순차적 그래프에서 더 나아가, **ReAct (Reasoning and Acting) 패턴**을 따르는 자율적인 Agent를 구축합니다. 이 Agent는 **스스로 판단하여 도구를 반복적으로 호출**하고, 모든 정보가 수집되었다고 판단되면 최종 리포트를 생성하는 동적인 워크플로우를 가집니다.
#
# ### 1\. Agent 아키텍처
#
# Agent는 다음과 같은 핵심 구성 요소로 이루어집니다.
#
#   * **MCP 클라이언트**: 원격 서버에 접속하여 도구들을 불러옵니다.
#   * **Agent 상태 (`AutonomousState`)**: 대화 기록(`messages`)과 실행 횟수(`turn_count`)를 저장합니다.
#   * **핵심 노드 (Nodes)**: `agent_node` (판단), `tool_node` (실행), `report_node` (보고)로 역할을 나눕니다.
#   * **조건부 라우터 (`agent_router`)**: `agent_node`의 판단에 따라 다음 작업으로 동적으로 분기합니다.
#
# -----
#
# ### 2\. Agent 상태(`AutonomousState`) 정의
#
# Agent의 대화 기록(`messages`)과 함께, 무한 루프를 방지하기 위해 **실행 횟수를 기록하는 `turn_count`**를 상태에 추가합니다.
#
# ```python
# class AutonomousState(TypedDict):
#     # 대화 기록이 계속 추가되도록 설정
#     messages: Annotated[list[BaseMessage], operator.add]
#     # Agent의 판단(turn) 횟수 기록
#     turn_count: int
# ```
#
# -----
#
# ### 3\. Agent 그래프 생성 (`create_financial_agent_graph`)
#
# Agent를 생성하는 전체 로직을 하나의 비동기 함수(`async def`) 안에 캡슐화하여 코드의 재사용성과 가독성을 높입니다.
#
# ```python
# async def create_financial_agent_graph():
#     # 1. 클라이언트 설정 및 모델 준비
#     # 2. 핵심 노드 함수 정의
#     # 3. 조건부 라우터 함수 정의
#     # 4. 그래프 구성 및 컴파일
#     return workflow.compile()
# ```
#
# #### 3.1. 클라이언트 및 모델 준비
#
# MCP 서버에 접속하여 **원격 도구들을 로드**합니다. 또한, **도구 호출을 위한 Agent용 모델**과 **리포트 작성을 위한 Reporter용 모델**을 별도로 정의하여 역할을 분리합니다.
#
# ```python
# # MCP 서버에 접속하여 도구 로드
# client = MultiServerMCPClient(...)
# tools = await client.get_tools()
#
# # 역할에 따라 두 개의 모델 준비
# agent_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", temperature=0).bind_tools(tools)
# reporting_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.7)
# ```
#
# #### 3.2. 핵심 노드 정의
#
# `agent_node`(판단), `tool_node`(실행), `report_node`(보고) 세 가지 핵심 노드 함수를 정의합니다.
#
# ```python
# def agent_node(state: AutonomousState):
#     # ... LLM을 호출하여 다음 행동 결정 ...
#     return {"messages": [response], "turn_count": ...}
#
# # ToolNode는 LangGraph에서 제공하는 기본 도구 실행 노드
# tool_node = ToolNode(tools)
#
# def report_node(state: AutonomousState):
#     # ... 수집된 정보로 최종 리포트 작성 ...
#     return {"messages": [response]}
# ```
#
# #### 3.3. 조건부 라우터(Router) 및 그래프 구성
#
# **`agent_router`** 함수는 Agent의 마지막 메시지를 보고 **도구를 추가로 호출할지, 아니면 리포트 생성을 시작할지** 동적으로 결정합니다. 이 라우터를 `add_conditional_edges`에 연결하여 그래프의 흐름을 제어합니다.
#
# ```python
# def agent_router(state: AutonomousState):
#     # ... 최대 반복 횟수 체크 (안전장치) ...
#     if state["messages"][-1].tool_calls:
#         return "call_tool"  # 도구 호출
#     else:
#         return "generate_report" # 리포트 생성
#
# # 그래프 구성
# workflow = StateGraph(AutonomousState)
# workflow.add_node("agent", agent_node)
# workflow.add_node("tools", tool_node)
# workflow.add_node("reporter", report_node)
#
# # agent 노드의 결과에 따라 동적으로 분기하도록 설정
# workflow.add_conditional_edges("agent", agent_router, {
#     "call_tool": "tools",
#     "generate_report": "reporter"
# })
# ```
#
# -----
#
# ### 4\. Agent 실행 및 시각화 (`main`)
#
# `main` 함수에서 생성된 그래프(`app`)를 **실행하고, 그 구조를 시각화**합니다. **`app.astream()`**을 사용하여 Agent의 각 단계를 실시간으로 관찰합니다.
#
# ```python
# async def main():
#     # 1. 그래프 생성 함수를 호출하여 app을 받음
#     app = await create_financial_agent_graph()
#
#     # 2. 그래프 구조를 다이어그램으로 시각화
#     display(Image(app.get_graph().draw_mermaid_png()))
#
#     # 3. 입력을 정의하고 Agent 실행
#     inputs = {"messages": [HumanMessage(content="...")]}
#     async for update in app.astream(inputs):
#         # ... 각 단계의 결과 출력 ...
#
# # 메인 함수 실행
# await main()
# ```

# %%
# --- 1. 필요한 모든 모듈 임포트 ---
import asyncio
import operator
import textwrap
from typing import List, TypedDict, Annotated

from IPython.display import HTML, display
from langchain_core.messages import BaseMessage, HumanMessage, SystemMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_mcp_adapters.client import MultiServerMCPClient
from langgraph.graph import StateGraph, END
from langgraph.prebuilt import ToolNode


# --- 2. Agent의 상태(State) 정의 ---
class AutonomousState(TypedDict):
    """
    자율 Agent의 상태를 정의합니다.
    - messages: 대화 기록이 누적됩니다.
    - turn_count: Agent의 실행 횟수를 기록하여 무한 루프를 방지합니다.
    """
    messages: Annotated[List[BaseMessage], operator.add]
    turn_count: int


# --- 3. 금융 정보 Agent 그래프 생성 함수 ---
async def create_financial_agent_graph():
    """
    금융 정보 분석 ReAct Agent의 실행 가능한 그래프(app)를 생성하고 반환합니다.
    이 함수는 클라이언트 설정, 모델 준비, 노드 정의, 그래프 구성을 모두 포함합니다.
    """
    # --- 3-1. MCP 클라이언트 설정 및 도구/모델 준비 ---
    print("📡 MCP 클라이언트를 HTTP 방식으로 설정합니다...")
    client = MultiServerMCPClient(
        {"financial_service": {"transport": "streamable_http", "url": "http://localhost:8000/mcp/"}}
    )
    tools = await client.get_tools()
    print(f"✅ 로딩된 도구: {[tool.name for tool in tools]}")

    # 도구 호출에 특화된 모델
    agent_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", temperature=0).bind_tools(tools)
    # 리포트 생성에 특화된 모델
    reporting_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.7)

    # --- 3-2. 핵심 노드 함수 정의 ---
    def agent_node(state: AutonomousState):
        """사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정하는 노드"""
        current_turn = state.get("turn_count", 0)
        print(f"\n++++++++++ 🤖 FINANCIAL AGENT (Turn {current_turn + 1}) ++++++++++")
        print("사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...")
        system_prompt = SystemMessage(
            content="""당신은 사용자의 요청을 해결하기 위해 필요한 도구를 호출하는 역할만 수행합니다. 절대로 중간에 답변이나 요약을 생성하지 마세요. 오직 다음으로 호출할 단 하나의 도구를 결정하고 tool_calls를 생성하세요. 만약 모든 정보가 수집되었다고 생각되면, tool_calls 없이 '모든 정보 수집 완료'라고만 답변하세요."""
        )
        messages_with_system_prompt = [system_prompt, *state["messages"]]
        response = agent_model.invoke(messages_with_system_prompt)
        return {"messages": [response], "turn_count": current_turn + 1}

    def report_node(state: AutonomousState):
        """수집된 모든 정보를 종합하여 최종 리포트를 작성하는 노드"""
        print("\n++++++++++ ✍️ FINANCIAL REPORTER ++++++++++")
        print("수집된 모든 정보를 종합하여 최종 리포트를 작성합니다...")
        report_history = [msg for msg in state["messages"] if not isinstance(msg, HumanMessage)]
        search_history = textwrap.dedent("\n".join([msg.pretty_repr() for msg in report_history]))
        report_prompt = f"당신은 전문 애널리스트입니다. 아래 정보 수집 기록을 바탕으로 사용자의 초기 질문에 대한 최종 투자 리포트를 작성해주세요.\n\n[정보 수집 기록]\n{search_history}"
        response = reporting_model.invoke(report_prompt)
        return {"messages": [response]}

    # --- 3-3. 조건부 엣지(Edge) 함수 정의 ---
    MAX_TURNS = 5
    def agent_router(state: AutonomousState):
        """Agent의 응답에 따라 다음 경로를 결정하는 라우터"""
        print("\n----- 🚦 ROUTER -----")
        if state.get("turn_count", 0) >= MAX_TURNS:
            print(f"⚠️ Safety Guard: 최대 반복 횟수({MAX_TURNS}회)를 초과하여 강제로 리포트를 생성합니다.\n")
            return "generate_report"

        last_message = state["messages"][-1]
        if last_message.tool_calls:
            print("분기: [call_tool] -> TOOLS 노드로 이동합니다.\n")
            return "call_tool"
        else:
            print("분기: [generate_report] -> REPORTER 노드로 이동합니다.\n")
            return "generate_report"

    # --- 3-4. 그래프 구성 및 컴파일 ---
    workflow = StateGraph(AutonomousState)
    workflow.add_node("agent", agent_node)
    workflow.add_node("tools", ToolNode(tools))
    workflow.add_node("reporter", report_node)

    workflow.set_entry_point("agent")
    workflow.add_conditional_edges("agent", agent_router, {"call_tool": "tools", "generate_report": "reporter"})
    workflow.add_edge("tools", "agent")
    workflow.add_edge("reporter", END)

    return workflow.compile()


# --- 4. 메인 실행 함수 ---
async def main():
    """그래프 생성, 시각화, 실행을 총괄하는 비동기 메인 함수"""
    # --- 4-1. 그래프 생성 함수 호출 ---
    app = await create_financial_agent_graph()
    print("✅ 그래프가 성공적으로 컴파일되었습니다.")

    # --- 4-2. 시각화 ---
    mermaid_syntax = app.get_graph().draw_mermaid()
    display(HTML(f"""
    <div style="background-color: white; border: 1px solid #ddd; padding: 10px; border-radius: 5px;"><pre class="mermaid">{mermaid_syntax}</pre></div>
    <script type="module">import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.esm.min.mjs';await mermaid.run();</script>
    """))

    # --- 4-3. Agent 실행 ---
    print("\n================ ReAct Agent 모델 실행 ================")
    inputs = {"messages": [HumanMessage(content="엔비디아(NVIDIA)에 대한 종합 투자 리포트를 작성해줘. 최신 주가, 사업 개요, 그리고 'AI 칩'과 관련된 최신 뉴스를 포함해서 분석해줘.")], "turn_count": 0}

    # 사용자 입력을 먼저 출력
    print("\n++++++++++ 🙋‍♂️ USER INPUT ++++++++++")
    inputs["messages"][0].pretty_print()

    # stream_mode="updates"를 사용하여 각 노드의 출력을 순서대로 처리
    async for update in app.astream(inputs, stream_mode="updates"):
        # update는 {'node_name': {'key': 'value'}} 형태의 딕셔너리
        node_name = list(update.keys())[0]
        node_output = list(update.values())[0]

        if node_name == "agent":
            # agent 노드의 AiMessage를 출력
            node_output['messages'][-1].pretty_print()
        elif node_name == "tools":
            # tools 노드는 ToolMessage 리스트를 반환
            for tool_message in node_output['messages']:
                tool_message.pretty_print()
        elif node_name == "reporter":
            # reporter 노드의 최종 결과 AiMessage를 출력
            node_output['messages'][-1].pretty_print()

    print("\n✅ 에이전트 실행이 완료되었습니다.")


# --- 5. 비동기 메인 함수 실행 ---
await main()
# Out:
# 📡 MCP 클라이언트를 HTTP 방식으로 설정합니다...
# ✅ 로딩된 도구: ['get_stock_price', 'get_latest_news', 'get_company_overview', 'get_analyst_opinions']
# ✅ 그래프가 성공적으로 컴파일되었습니다.
#     <div style="background-color: white; border: 1px solid #ddd; padding: 10px; border-radius: 5px;"><pre class="mermaid">---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	agent(agent)
# 	tools(tools)
# 	reporter(reporter)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> agent;
# 	agent -. &nbsp;generate_report&nbsp; .-> reporter;
# 	agent -. &nbsp;call_tool&nbsp; .-> tools;
# 	tools --> agent;
# 	reporter --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
# </pre></div>
#     <script type="module">import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.esm.min.mjs';await mermaid.run();</script>
# ================ ReAct Agent 모델 실행 ================
#
# ++++++++++ 🙋‍♂️ USER INPUT ++++++++++
# ================================ Human Message =================================
#
# 엔비디아(NVIDIA)에 대한 종합 투자 리포트를 작성해줘. 최신 주가, 사업 개요, 그리고 'AI 칩'과 관련된 최신 뉴스를 포함해서 분석해줘.
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 1) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
# ================================== Ai Message ==================================
# Tool Calls:
#   get_stock_price (ef00ed88-b19f-4233-b883-1204ea1cb0a5)
#  Call ID: ef00ed88-b19f-4233-b883-1204ea1cb0a5
#   Args:
#     company_name: NVIDIA
#   get_company_overview (08601184-fed9-46d3-af3e-0f1d1b313bc8)
#  Call ID: 08601184-fed9-46d3-af3e-0f1d1b313bc8
#   Args:
#     company_name: NVIDIA
#   get_latest_news (32d08966-7a9b-4aa5-b860-16531700653a)
#  Call ID: 32d08966-7a9b-4aa5-b860-16531700653a
#   Args:
#     topic: AI 칩
#     company_name: NVIDIA
# ================================= Tool Message =================================
# Name: get_stock_price
#
# {
#   "title": "엔비디아 주가 (Nvidia) | 오늘의 실시간 NVDA 티커 - Investing.com",
#   "url": "https://kr.investing.com/equities/nvidia-corp",
#   "content": "### 엔비디아(NVDA)의 현재 거래는 어떤가요?\n\n2025년 10월 17일 기준, 엔비디아(NVDA)은(는) 183.22 가격에 거래되고 있으며 이전 종가는 181.81입니다. 일간 범위는 179.75~184.10이고, 52주 범위는 86.62~195.62입니다.\n\n### 엔비디아(NVDA)의 애널리스트 목표주가는 얼마인가요?\n\n엔비디아의 12개월 목표주가 평균은 USD218.51368입니다. 목표주가 최고치 USD320, 최저치는 USD100입니다. 58명의 애널리스트는 매수 의견, 1명은 매도 의견을 제시했으며, 전반적인 투자의견 등급은 적극 매수입니다. 이 주식은 +19.26% 상승 여력 있음 잠재력이 있습니다.\n\n주식 중개업체(브로커) 찾기\n\n외환 지수 원자재 주식\n\n1일\n\n1주\n\n1달\n\n6달\n\n1년\n\n5년\n\n최대\n\n (F)\")\n\n523.35\n\n-1.25\n\n-0.24%\n\nUS 500\")\n\n6,672.90\n\n+43.8\n\n+0.66%\n\nUS Tech 100\") [...] 주식 스크리너\n       FED 금리 모니터링 도구\n       환율 변환기\n       피보나치 계산기\n\n더보기\n\n       외환 상관관계\n       피봇 포인트 계산기\n       이익계산기\n       마진 계산기\n       통화 히트맵\n       외환 변동성\n       선물환 환율 계산기\n       모기지 계산기\n\n   교육 \n   알림 \n   경제 캘린더주식 스크리너\n   \n\nNVIDIA Corporation 주가가 실시간인 경우 이 페이지에는 NASDAQ NVDA 증권 거래소 데이터가 표시됩니다. 개장 전 NVDA 주가를 확인하거나 시간 외 시세를 확인할 수 있습니다. 아래 NVIDIA Corporation 실시간 주가 차트에서 어제 종가 183.22 등 최신 움직임을 모니터링하세요. \n\nNVIDIA Corporation의 오늘 주가는?\n\n NVIDIA Corporation의 오늘 주가는 183.22입니다. [...] AMZN\n\n-0.67%\n\n자주 묻는 질문\n\n### 오늘 엔비디아 (NVDA)의 주가는?\n\n오늘 엔비디아 주가는 183.22입니다.\n\n### 엔비디아은(는) 어떤 증권 거래소에서 거래되나요?\n\n엔비디아은(는) 나스닥 증권 거래소 증권 거래소에 상장되어 거래되고 있습니다.\n\n### 엔비디아의 주식 티커는?\n\n엔비디아의 주식 티커는 “NVDA”입니다.\n\n### 엔비디아은(는) 배당을 지급하나요? 현재 배당수익률은 얼마인가요?\n\n엔비디아 배당수익률은 0.02%입니다.\n\n### 엔비디아 시가총액은 얼마인가요?\n\n오늘 현재 엔비디아 시가총액은 4.45T입니다.\n\n### 엔비디아의 주당순이익(TTM)은 얼마인가요?\n\n엔비디아의 EPS(TTM)는 3.51입니다.\n\n### 엔비디아의 다음 실적 발표일은 언제인가요?\n\n엔비디아은(는) 2025년 11월 18일에 다음 실적 보고서를 발표할 예정입니다.\n\n### 엔비디아에는 몇 명의 직원이 있나요?\n\n엔비디아의 직원은 36000명입니다.",
#   "score": 0.8945781
# }
# ================================= Tool Message =================================
# Name: get_company_overview
#
# {
#   "title": "Nvidia - Wikipedia",
#   "url": "https://en.wikipedia.org/wiki/Nvidia",
#   "content": "Nvidia Corporation( (/ɛ n ˈ v ɪ d i ə/_en-VID-ee-ə_) is an American technology company headquartered in Santa Clara, California. Founded in 1993 by Jensen Huang (who remains president and CEO), Chris Malachowsky, and Curtis Priem, it develops graphics processing units (GPUs), systems on chips (SoCs), and application programming interfaces (APIs) for data science, high-performance computing, and mobile and automotive applications.( Nvidia is considered part of the Big Tech group, alongside [...] Nvidia uses external suppliers for all phases of manufacturing, including wafer fabrication, assembly, testing, and packaging. Nvidia thus avoids most of the investment and production costs and risks associated with chip manufacturing, although it does sometimes directly procure some components and materials used in the production of its products (e.g., memory and substrates). Nvidia focuses its own resources on product design, quality assurance, marketing, and customer support.( [...] Originally focused on GPUs for video gaming, Nvidia broadened their use into other markets, including artificial intelligence (AI), professional visualization, and supercomputing. The company's product lines include GeForce GPUs for gaming and creative workloads, and professional GPUs for edge computing, scientific research, and industrial applications. As of the first quarter of 2025, Nvidia held a 92% share of the discrete desktop and laptop GPU market.(",
#   "score": 0.71687365
# }
# ================================= Tool Message =================================
# Name: get_latest_news
#
# {
#   "title": "NVIDIA: 인공 지능 컴퓨팅의 세계적인 리더",
#   "url": "https://www.nvidia.com/ko-kr/",
#   "content": "### 업계 선도 기업, 새로운 추론 모델로 더 스마트한 AI 에이전트 구축\n\n엔터프라이즈와 피지컬 AI를 위해 설계된 새로운 NVIDIA Nemotron™ 및 Cosmos™ 추론 모델은 더 빠른 사고, 향상된 추론 능력, 그리고 낮은 추론 비용을 제공합니다.\n\n인공 지능 | 발표 사항\n\n### 도시와 산업 인프라에 피지컬 AI 도입\n\nNVIDIA Metropolis의 고급 Blueprint, 비전 언어 모델, 그리고 합성 데이터 생성 확장 기능이 다양한 환경에서 생산성을 높이고 안전성을 향상시킵니다.\n\n인공지능 | News\n\n### 비디오 검색 및 요약 에이전트 구축\n\n이제 비디오 검색 및 요약(VSS)을 위한 NVIDIA AI Blueprint를 일반 사용자에게 제공합니다.\n\n인공지능 | 블로그\n\n### 미래의 업무 환경을 위해 AI 에이전트를 연결하는 새로운 AI-Q Blueprint\n\n추론을 사용하고 엔터프라이즈 데이터에 연결할 수 있는 에이전틱 시스템을 개발하십시오. [...] ### NVIDIA AI 팩토리 디지털 트윈: 새로운 에코시스템 및 도구\n\nAI 팩토리 설계 및 운영을 위해 확장된 NVIDIA Omniverse Blueprint, AI 팩토리 전력, 냉각 및 네트워킹 생태계 전반에 걸쳐 더욱 심층적인 통합을 제공\n\n시뮬레이션 | 발표 내용\n\n### NVIDIA RTX PRO Blackwell 세대 소개\n\n데스크톱 및 모바일 워크스테이션용 새로운 NVIDIA RTX PRO Blackwell 세대 GPU가 AI와 뉴럴 렌더링 워크플로우의 새로운 시대를 열어갑니다.\n\n시뮬레이션 | 블로그\n\n### NVIDIA, 물리 AI 발전을 위해 개방형 물리 AI 데이터세트 공개 및 최대 규모의 합성 데이터세트 출시\n\n시뮬레이션에 즉시 활용 가능한 실제 데이터 및 합성 생성 데이터 모음이 이제 오픈 소스로 제공됩니다.\n\n시뮬레이션 | 발표 내용\n\n### NVIDIA Omniverse, 물리 AI 도입 확산으로 생태계 확장",
#   "score": 0.80126834
# }
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 2) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [generate_report] -> REPORTER 노드로 이동합니다.
#
# ================================== Ai Message ==================================
#
# 모든 정보 수집 완료
#
# ++++++++++ ✍️ FINANCIAL REPORTER ++++++++++
# 수집된 모든 정보를 종합하여 최종 리포트를 작성합니다...
# ================================== Ai Message ==================================
#
# ## 엔비디아(NVIDIA) 투자 리포트: AI 시대의 핵심 인프라 제공자
#
# **작성일:** 2025년 10월 17일
#
# ---
#
# ### 1. 요약 (Executive Summary)
#
# 엔비디아(NVIDIA, NVDA)는 그래픽 처리 장치(GPU)와 시스템 온 칩(SoC)을 개발하는 미국의 선도적인 기술 기업으로, 특히 인공지능(AI) 컴퓨팅 시장에서 독보적인 위치를 차지하고 있습니다. 2025년 10월 17일 현재 주가는 183.22 USD이며, 58명의 애널리스트가 매수 의견을 제시하는 등 전반적인 투자의견은 **"적극 매수(Strong Buy)"**입니다. 애널리스트들의 12개월 평균 목표주가는 218.51 USD로, 현재 주가 대비 약 19.26%의 상승 여력을 가지고 있습니다.
#
# 엔비디아는 게이밍을 넘어 데이터 과학, 고성능 컴퓨팅, 모바일, 자동차 애플리케이션 등 다양한 시장으로 GPU의 활용 범위를 확장했으며, 특히 AI 부문에서 Nemotron, Cosmos와 같은 새로운 추론 모델과 Metropolis, Omniverse를 통한 피지컬 AI 및 디지털 트윈 생태계 구축에 주력하며 강력한 성장 동력을 확보하고 있습니다. 이러한 기술 리더십과 압도적인 시장 점유율을 바탕으로 엔비디아는 AI 시대의 핵심 인프라 제공자로서 장기적인 성장 잠재력이 매우 높은 기업으로 평가됩니다.
#
# ---
#
# ### 2. 기업 개요 (Company Overview)
#
# *   **기업명:** NVIDIA Corporation (나스닥 티커: NVDA)
# *   **본사:** 미국 캘리포니아 산타클라라
# *   **설립:** 1993년 (젠슨 황, 크리스 말라코스키, 커티스 프림)
# *   **주요 사업:** 그래픽 처리 장치(GPU), 시스템 온 칩(SoC), 애플리케이션 프로그래밍 인터페이스(API) 개발
# *   **핵심 시장:** 데이터 과학, 고성능 컴퓨팅(HPC), 모바일, 자동차, 게임, 전문 시각화, AI, 슈퍼컴퓨팅
# *   **사업 모델:** 팹리스(Fabless) 모델 – 반도체 설계에 집중하고 제조는 외부 파운드리(TSMC 등)에 위탁하여 투자 및 생산 위험 최소화.
# *   **주요 제품 라인:**
#     *   **GeForce GPU:** 게이밍 및 크리에이티브 워크로드용
#     *   **전문가용 GPU:** 엣지 컴퓨팅, 과학 연구, 산업 애플리케이션용
# *   **시장 지위:** 2025년 1분기 기준, 외장형 데스크톱 및 노트북 GPU 시장 점유율 92%로 압도적인 시장 지배력 보유.
#
# ---
#
# ### 3. 산업 및 시장 분석 (Industry & Market Analysis)
#
# 엔비디아는 AI, 고성능 컴퓨팅, 게이밍 산업의 핵심 동력인 GPU 기술을 선도하며 관련 시장 성장을 견인하고 있습니다. 특히 AI 시대가 도래하면서 딥러닝, 머신러닝 연산에 필수적인 GPU의 수요가 폭발적으로 증가하고 있으며, 엔비디아는 CUDA 플랫폼을 통해 강력한 소프트웨어 생태계를 구축하여 경쟁 우위를 더욱 공고히 하고 있습니다.
#
# 최근에는 AI 에이전트, 피지컬 AI, 디지털 트윈과 같은 차세대 AI 기술 개발에 집중하며 단순한 하드웨어 공급을 넘어 AI 솔루션 제공 기업으로 진화하고 있습니다. 도시 및 산업 인프라에 적용되는 NVIDIA Metropolis, AI 팩토리 설계 및 운영을 위한 NVIDIA Omniverse Blueprint 등은 엔비디아의 기술이 실제 산업 현장에 미치는 영향력을 보여줍니다. 이러한 광범위한 적용 가능성은 엔비디아의 시장 확대 잠재력을 높이고 있습니다.
#
# ---
#
# ### 4. 재무 및 주가 분석 (Financial & Stock Analysis)
#
# *   **현재 주가 (2025.10.17):** 183.22 USD
# *   **이전 종가:** 181.81 USD
# *   **일간 범위:** 179.75 ~ 184.10 USD
# *   **52주 범위:** 86.62 ~ 195.62 USD
# *   **시가총액:** 4.45조 USD
# *   **주당순이익 (EPS, TTM):** 3.51 USD
# *   **배당수익률:** 0.02% (매우 낮은 수준으로, 성장을 위한 재투자 비중이 높음)
# *   **애널리스트 목표주가 (12개월 평균):** 218.51 USD
#     *   최고 목표가: 320 USD
#     *   최저 목표가: 100 USD
#     *   현재 주가 대비 상승 여력: +19.26%
# *   **애널리스트 투자의견:** 59명 중 58명 "매수", 1명 "매도" (전반적인 투자의견 등급: **적극 매수**)
# *   **다음 실적 발표일:** 2025년 11월 18일
#
# 엔비디아의 주가는 지난 52주 동안 상당한 변동성을 보였지만, AI 산업의 성장에 대한 기대감으로 꾸준히 우상향하는 모습을 보였습니다. 현재 시가총액은 4.45조 USD로 매우 높은 수준이며, 이는 시장이 엔비디아의 미래 성장 가능성을 높게 평가하고 있음을 시사합니다. EPS는 3.51 USD로 견조한 수익성을 보여주고 있습니다.
#
# ---
#
# ### 5. 최근 동향 및 성장 동력 (Recent Developments & Growth Drivers)
#
# 엔비디아는 AI 및 시뮬레이션 기술 혁신을 통해 지속적인 성장 동력을 확보하고 있습니다.
#
# *   **AI 에이전트 및 추론 모델 강화:**
#     *   엔터프라이즈 및 피지컬 AI를 위한 새로운 **NVIDIA Nemotron™ 및 Cosmos™ 추론 모델**을 공개하여 더 빠르고 향상된 추론 능력과 낮은 추론 비용을 제공합니다. 이는 스마트한 AI 에이전트 구축을 가능하게 합니다.
# *   **피지컬 AI 및 디지털 트윈 확장:**
#     *   **NVIDIA Metropolis:** 도시 및 산업 인프라에 피지컬 AI를 도입하기 위한 고급 Blueprint, 비전 언어 모델, 합성 데이터 생성 기능을 확장하여 생산성과 안전성을 향상시킵니다.
#     *   **NVIDIA AI 팩토리 디지털 트윈:** 확장된 Omniverse Blueprint와 AI 팩토리 전력, 냉각, 네트워킹 생태계 전반의 심층적인 통합을 통해 AI 팩토리 설계 및 운영을 지원합니다.
#     *   **개방형 물리 AI 데이터세트:** 물리 AI 발전을 위해 시뮬레이션에 즉시 활용 가능한 실제 및 합성 생성 데이터 모음을 오픈 소스로 공개하여 생태계 확장을 가속화하고 있습니다.
# *   **신규 GPU 및 AI 워크플로우 지원:**
#     *   데스크톱 및 모바일 워크스테이션용 새로운 **NVIDIA RTX PRO Blackwell 세대 GPU**를 소개하며 AI 및 뉴럴 렌더링 워크플로우의 새로운 시대를 열고 있습니다.
# *   **AI 소프트웨어 및 플랫폼 강화:**
#     *   비디오 검색 및 요약(VSS)을 위한 NVIDIA AI Blueprint, 미래 업무 환경을 위해 AI 에이전트를 엔터프라이즈 데이터에 연결하는 AI-Q Blueprint 등을 제공하여 AI 개발 및 배포를 용이하게 합니다.
#
# ---
#
# ### 6. 리스크 요인 (Risk Factors)
#
# *   **경쟁 심화:** AMD, Intel 등 기존 경쟁사들의 AI 칩 시장 진출 가속화 및 구글, 아마존 등 빅테크 기업들의 자체 AI 칩 개발로 인한 경쟁 심화.
# *   **경기 둔화 및 수요 감소:** 글로벌 경기 둔화 또는 특정 산업(예: 데이터센터 투자, 게이밍)의 수요 감소는 엔비디아의 실적에 부정적인 영향을 미칠 수 있습니다.
# *   **규제 리스크:** AI 기술 및 첨단 반도체에 대한 각국 정부의 수출 통제, 규제 강화 등 지정학적 리스크가 존재합니다.
# *   **공급망 위험:** 팹리스 모델의 특성상 외부 파운드리 및 부품 공급업체에 대한 의존도가 높아 공급망 교란 시 생산에 차질이 발생할 수 있습니다.
# *   **높은 밸류에이션:** AI 산업의 높은 성장 기대감이 이미 주가에 상당 부분 반영되어 있어, 기대에 미치지 못하는 실적 발표 시 주가 조정 가능성이 있습니다.
#
# ---
#
# ### 7. 투자 의견 및 목표 주가 (Investment Recommendation & Price Target)
#
# *   **투자 의견:** **적극 매수 (Strong Buy)**
# *   **목표 주가 (12개월):** **218.51 USD**
#
# 엔비디아는 AI 시대의 가장 중요한 기술 인프라를 제공하는 기업으로서 독보적인 시장 지위와 기술 리더십을 보유하고 있습니다. GPU 하드웨어뿐만 아니라 CUDA 플랫폼, AI 에이전트, 피지컬 AI, 디지털 트윈 등 소프트웨어 및 솔루션 생태계 확장을 통해 지속적인 성장 동력을 확보하고 있습니다.
#
# 비록 현재 높은 밸류에이션 부담과 경쟁 심화, 규제 리스크가 존재하지만, AI 기술의 발전과 적용 범위 확장은 엔비디아의 장기적인 성장을 견인할 것으로 판단됩니다. 애널리스트들의 강력한 매수 의견과 목표주가 상승 여력을 고려할 때, 엔비디아는 장기적인 관점에서 매력적인 투자 기회를 제공할 것으로 보입니다.
#
# ---
#
# ### 8. 결론 (Conclusion)
#
# 엔비디아는 AI 혁명의 최전선에서 핵심적인 역할을 수행하며 기술 산업의 미래를 선도하고 있습니다. 강력한 GPU 시장 지배력, 혁신적인 AI 소프트웨어 및 플랫폼 개발, 그리고 피지컬 AI 및 디지털 트윈과 같은 차세대 기술에 대한 지속적인 투자는 엔비디아의 장기적인 성장 잠재력을 확고히 합니다. 단기적인 시장 변동성에 대한 주의가 필요하지만, AI 시대의 도래와 함께 엔비디아는 앞으로도 지속적인 수혜를 받을 것으로 예상되며, 적극적인 투자를 권고합니다.
#
# ✅ 에이전트 실행이 완료되었습니다.

# %% [markdown]
# # 🛑 금융 정보 MCP 서버 종료
#
# 모든 작업이 완료된 후, 백그라운드에서 실행되던 **MCP 서버 프로세스를 종료**하여 시스템 자원을 정리합니다.
#
#   * **`lsof -ti tcp:8000`**: 네트워크 **포트 8000**을 사용 중인 프로세스의 ID(PID)를 찾습니다.
#   * **`| xargs -r kill`**: 찾아낸 프로세스 ID를 `kill` 명령어에 전달하여 해당 프로세스를 안전하게 종료시킵니다.

# %%
# !lsof -ti tcp:8000 | xargs -r kill; echo "✅ 금융 정보 MCP Server shutdown complete"
# Out:
# ✅ 금융 정보 MCP Server shutdown complete

# %% [markdown]
# # 📜 포트폴리오 MCP 서버 스크립트 (db_server.py)
#
# 이 스크립트는 **SQLite 데이터베이스와 상호작용**하는 도구들을 제공하는 **두 번째 MCP 서버**를 생성합니다. `db_server.py` 파일로 저장되며, Agent가 주식 포트폴리오 데이터를 조회하고 분석할 수 있도록 SQL 쿼리 관련 기능들을 API 형태로 노출하는 역할을 합니다.
#
# ### 1\. 주요 기능 및 아키텍처
#
#   * **데이터베이스 생성**: 스크립트 실행 시, `my_portfolio`라는 테이블을 가진 예제용 SQLite 데이터베이스(`portfolio.db`)를 자동으로 생성하고 샘플 데이터를 삽입합니다.
#
#     ```sql
#     CREATE TABLE my_portfolio (
#         id INTEGER PRIMARY KEY AUTOINCREMENT,
#         ticker TEXT NOT NULL UNIQUE,
#         company_name TEXT NOT NULL,
#         shares_owned INTEGER NOT NULL,
#         purchase_price REAL NOT NULL
#     )
#     ```
#
#   * **`SQLDatabaseToolkit` 활용**: 이 스크립트의 핵심은 LangChain의 \*\*`SQLDatabaseToolkit`\*\*입니다. 이 툴킷은 데이터베이스 연결 정보(`db`)와 LLM만 제공하면, 해당 데이터베이스와 상호작용하는 데 필요한 표준 도구들을 **자동으로 생성**해주는 강력한 기능입니다.
#
#   * **자동 생성 도구 목록**: `SQLDatabaseToolkit`은 다음과 같은 유용한 도구들을 만들어냅니다.
#
#       * **`sql_db_list_tables`**: 데이터베이스 내의 모든 테이블 목록을 조회합니다.
#       * **`sql_db_schema`**: 특정 테이블의 스키마(구조) 정보를 보여줍니다.
#       * **`sql_db_query`**: 실제 SQL 쿼리를 실행하고 결과를 가져옵니다.
#       * **`sql_db_query_checker`**: 실행하기 전에 SQL 쿼리에 문법적 오류가 없는지 확인합니다.
#
#   * **서버 실행**: 자동으로 생성된 DB 도구들을 `FastMCP` 서버에 탑재하여 **포트 8001**에서 실행합니다. (기존 서버와의 충돌 방지)
#
#     ```python
#     if __name__ == "__main__":
#         # 1. DB 생성 및 초기화
#         setup_portfolio_database()
#         # 2. MCP 서버 실행
#         mcp.run(transport="streamable-http")
#     ```
#
# ### 2\. `SQLDatabaseToolkit` 사용법
#
# 툴킷을 사용하는 과정은 매우 간단합니다. 데이터베이스 경로를 지정하여 `SQLDatabase` 객체를 만들고, 이를 `SQLDatabaseToolkit`에 `db`와 `llm` 인자와 함께 전달하면 됩니다.
#
# ```python
# # 데이터베이스 연결
# db = SQLDatabase.from_uri("sqlite:///portfolio.db")
#
# # LLM과 DB 연결 정보를 제공하여 툴킷 생성
# toolkit = SQLDatabaseToolkit(db=db, llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash"))
#
# # 툴킷에서 자동으로 생성된 도구 목록 가져오기
# db_tools = toolkit.get_tools()
# ```

# %%
# %%writefile /content/db_server.py
# SQLite 데이터베이스와 상호작용하는 도구를 제공하는 MCP 서버입니다.

# --- 1. 라이브러리 임포트 ---
import sqlite3
import uvicorn
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.utilities import SQLDatabase
from langchain_community.agent_toolkits import SQLDatabaseToolkit
from langchain_mcp_adapters.tools import to_fastmcp
from mcp.server.fastmcp import FastMCP


# --- 2. 데이터베이스 설정 및 생성 함수 ---
DB_PATH = "portfolio.db"

def setup_portfolio_database():
    """개인 포트폴리오 예제용 SQLite 데이터베이스를 생성하고 초기화합니다."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    cursor.execute("DROP TABLE IF EXISTS my_portfolio")
    cursor.execute("""
    CREATE TABLE my_portfolio (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        ticker TEXT NOT NULL UNIQUE,
        company_name TEXT NOT NULL,
        shares_owned INTEGER NOT NULL,
        purchase_price REAL NOT NULL
    )
    """)
    portfolio_data = [
        ('NVDA', 'NVIDIA Corp', 50, 120.50),
        ('AAPL', 'Apple Inc', 100, 185.75),
        ('TSLA', 'Tesla Inc', 30, 250.00)
    ]
    cursor.executemany("INSERT INTO my_portfolio (ticker, company_name, shares_owned, purchase_price) VALUES (?, ?, ?, ?)", portfolio_data)
    conn.commit()
    conn.close()
    print(f"✅ 포트폴리오 데이터베이스 '{DB_PATH}'가 성공적으로 생성 및 초기화되었습니다.")


# --- 3. LangChain SQL 툴킷을 사용하여 DB용 도구 생성 ---
# 데이터베이스 연결 객체 생성
db = SQLDatabase.from_uri(f"sqlite:///{DB_PATH}")

# SQL 툴킷 생성 (LLM과 DB 정보를 제공)
# 이 툴킷이 DB와 상호작용하는 표준 도구들을 자동으로 생성합니다.
toolkit = SQLDatabaseToolkit(db=db, llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash"))

# 툴킷에서 도구 목록 가져오기 (sql_db_query, sql_db_schema, sql_db_list_tables 등)
db_tools = toolkit.get_tools()
print(f"🛠️  자동 생성된 DB 도구: {[tool.name for tool in db_tools]}")


# --- 4. MCP 서버 설정 ---
# LangChain 도구를 MCP 서버가 이해할 수 있는 형식으로 변환
fastmcp_tools = [to_fastmcp(t) for t in db_tools]

# MCP 서버 인스턴스 생성 (포트 8001 사용)
mcp = FastMCP("PortfolioDBService", tools=fastmcp_tools, port=8001)


# --- 5. 서버 실행 ---
if __name__ == "__main__":
    # 서버 실행 전, 데이터베이스가 준비되도록 함수 호출
    setup_portfolio_database()

    # streamable-http 방식으로 서버를 실행
    mcp.run(transport="streamable-http")
# Out:
# Overwriting /content/db_server.py

# %% [markdown]
# # 🚀 포트폴리오 MCP 서버 시작
#
# 앞서 작성한 `db_server.py` 스크립트를 백그라운드에서 실행하여 **데이터베이스 도구를 제공하는 두 번째 MCP 서버**를 시작합니다. 이 서버는 **포트 8001**에서 실행되어, 기존 금융 정보 서버(포트 8080)와 충돌 없이 동시에 작동합니다.
#
# #### 📝 실행 명령어 분석
#
#   * **`lsof -ti tcp:8001 | xargs -r kill`**: **포트 8001**을 사용 중인 기존 프로세스를 찾아 종료시킵니다. (포트 충돌 방지)
#   * **`rm -f db_server.log`**: 이전 실행에서 남은 로그 파일을 삭제합니다.
#   * **`nohup python ... &`**: `db_server.py`를 **백그라운드 프로세스**로 실행하여, 노트북 작업과 독립적으로 계속 동작하도록 합니다.
#   * **`> db_server.log 2>&1`**: DB 서버의 모든 실행 기록을 `db_server.log` 파일에 저장합니다.

# %%
import os
import time

def start_and_check_mcp_server():
    """
    포트폴리오 MCP 서버를 시작하고, 로그 파일을 폴링하여
    서버가 성공적으로 시작되었는지 확인합니다.
    """

    print("🚀 포트폴리오 MCP 서버를 시작합니다...")

    # 포트 8001을 사용하는 기존 프로세스를 종료하고, 백그라운드에서 새 DB 서버를 실행합니다.
    server_command = "lsof -ti tcp:8001 | xargs -r kill; rm -f db_server.log; nohup python -u db_server.py > db_server.log 2>&1 &"
    os.system(server_command)

    # --- DB 서버 로그 파일 확인 및 상태 출력 ---
    timeout_seconds = 30  # 최대 대기 시간 (초)
    check_interval = 2   # 로그 확인 주기 (초)
    start_time = time.time()

    server_status = "PENDING"
    log_content = ""

    print(f"⏱️  DB 서버 시작 대기 중... (최대 {timeout_seconds}초)")

    while time.time() - start_time < timeout_seconds:
        try:
            with open('db_server.log', 'r') as f:
                log_content = f.read()

            # 비교를 위해 로그 전체를 소문자로 변경
            log_content_lower = log_content.lower()

            # 성공 조건 확인
            if "uvicorn running on" in log_content_lower and "application startup complete" in log_content_lower:
                server_status = "SUCCESS"
                break

            # 실패 조건 확인
            if "traceback" in log_content_lower or "error" in log_content_lower:
                server_status = "FAILED"
                break

            print("   ...로그 파일 확인 중...")
            time.sleep(check_interval)

        except FileNotFoundError:
            # 로그 파일이 아직 생성되지 않았을 수 있으므로 잠시 대기
            print("   ...로그 파일 생성 대기 중...")
            time.sleep(check_interval)
        except Exception as e:
            print(f"로그 파일 읽기 중 예외 발생: {e}")
            log_content = f"로그 파일 읽기 오류: {e}"
            server_status = "FAILED"
            break

    # --- 최종 결과 출력 ---
    print("-" * 30)

    if server_status == "SUCCESS":
        print("✅ 포트폴리오 MCP 서버가 성공적으로 시작되어 실행 중입니다.")
        print(f"   (로그 파일: {os.getcwd()}/db_server.log)")

    elif server_status == "FAILED":
        print("❌ 로그 확인 결과: 포트폴리오 MCP 서버 실행 중 오류가 발생했습니다. 아래 로그를 확인하세요.")
        print("-" * 20)
        print(log_content)
        print("-" * 20)

    else: # PENDING (Timeout)
        print(f"🤔 {timeout_seconds}초 내에 서버 시작 메시지를 확인하지 못했습니다.")
        print("   서버가 느리게 시작 중이거나, 확인 문자열이 로그에 없는 것 같습니다.")
        print("\n   [현재 db_server.log 내용]")
        print("-" * 20)
        print(log_content if log_content else "[로그 파일이 비어 있거나 생성되지 않았습니다]")
        print("-" * 20)

# --- 함수 실행 ---
start_and_check_mcp_server()
# Out:
# 🚀 포트폴리오 MCP 서버를 시작합니다...
# ⏱️  DB 서버 시작 대기 중... (최대 30초)
#    ...로그 파일 확인 중...
#    ...로그 파일 확인 중...
#    ...로그 파일 확인 중...
#    ...로그 파일 확인 중...
#    ...로그 파일 확인 중...
#    ...로그 파일 확인 중...
# ------------------------------
# ✅ 포트폴리오 MCP 서버가 성공적으로 시작되어 실행 중입니다.
#    (로그 파일: /content/db_server.log)

# %% [markdown]
# # 🗃️ 포트폴리오 DB 조회 Agent 워크플로우
#
# 마지막으로, **데이터베이스 조회에만 특화**된 자율 Agent를 구축합니다. 이 Agent는 이전의 범용 Agent와 달리, 오직 DB 관련 도구만 사용하여 사용자의 질문에 답변하는 전문가 역할을 수행합니다.
#
# ### 1\. Agent 아키텍처 및 특징
#
#   * **전용 클라이언트**: Agent는 금융 정보 서버가 아닌, **DB 서버(포트 8001)**에만 연결하는 전용 `MultiServerMCPClient`를 사용합니다. 이를 통해 Agent가 사용할 수 있는 도구를 DB 관련 기능(`sql_db_query` 등)으로 제한합니다.
#
#     ```python
#     client = MultiServerMCPClient({
#         "database_service": {
#             "transport": "streamable_http",
#             "url": "http://localhost:8001/mcp/",
#         }
#     })
#     db_tools = await client.get_tools()
#     ```
#
#   * **체계적 사고를 위한 시스템 프롬프트**: 이 Agent의 가장 큰 특징은 **명확한 행동 지침**을 담은 `SystemMessage`를 받는다는 점입니다. Agent는 이 지침에 따라 체계적으로 사고하고 행동합니다.
#
#     ```python
#     system_prompt = """
#     당신은 ... 데이터베이스 전문가입니다.
#
#     **행동 지침:**
#     1. 가장 먼저 `sql_db_list_tables`를 호출하여 ... 테이블을 확인하세요.
#     2. 그 다음, `sql_db_schema`를 호출하여 ... 구조를 파악하세요.
#     3. 마지막으로, `sql_db_query`를 실행하여 ... 답을 찾으세요.
#     """
#     ```
#
#   * **단순화된 그래프 구조**: 이전 Agent와 달리 별도의 `report_node`가 없습니다. `agent_node`가 도구 호출(Reasoning)과 최종 답변 생성을 모두 담당하여 구조가 더 단순해졌습니다. 라우터 역시 **도구를 호출할지(`call_tool`), 아니면 프로세스를 종료할지(`end`)**만 결정합니다.
#
#     ```python
#     # 라우터의 분기 로직
#     def agent_router(state: AutonomousState):
#         if state["messages"][-1].tool_calls:
#             return "call_tool"
#         else:
#             return "end"
#
#     # 그래프 구성
#     workflow.add_conditional_edges("agent", agent_router, {
#         "call_tool": "tools",
#         "end": END
#     })
#     ```
#
# ### 2\. 실행 및 결과 확인
#
# `main` 함수에서 생성된 DB 조회 Agent를 실행하고, 사용자의 질문("내 포트폴리오의 모든 종목 티커와 보유 수량을 알려줘")에 대해 Agent가 어떻게 단계별로 DB 도구를 사용하여 답변을 찾아가는지 실시간으로 확인할 수 있습니다.

# %%
# --- 1. 필요한 모든 모듈 임포트 ---
import asyncio
import operator
import textwrap
from typing import List, TypedDict, Annotated

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_mcp_adapters.client import MultiServerMCPClient
from langgraph.graph import StateGraph, END
from langgraph.prebuilt import ToolNode
from langchain_core.messages import BaseMessage, HumanMessage, SystemMessage
from IPython.display import display, HTML


# --- 2. Agent의 상태(State) 정의 ---
class AutonomousState(TypedDict):
    messages: Annotated[List[BaseMessage], operator.add]
    turn_count: int


# --- 3. DB 조회 Agent 그래프 생성 함수 ---
async def create_db_agent_graph():
    """
    DB 조회 ReAct Agent의 실행 가능한 그래프(app)를 생성하고 반환합니다.
    """
    # --- 3-1. DB 서버 클라이언트 설정 및 도구/모델 준비 ---
    print("📡 DB 서버에만 연결하는 MCP 클라이언트를 설정합니다...")
    client = MultiServerMCPClient(
        {"database_service": {"transport": "streamable_http", "url": "http://localhost:8001/mcp/"}}
    )
    db_tools = await client.get_tools()
    print(f"✅ 포트폴리오 Agent용 도구 로딩 완료: {[tool.name for tool in db_tools]}")

    agent_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", temperature=0).bind_tools(db_tools)

    # --- 3-2. 핵심 노드 함수 정의 ---
    def agent_node(state: AutonomousState):
        current_turn = state.get("turn_count", 0)
        print(f"\n++++++++++ 🤖 PORTFOLIO AGENT (Turn {current_turn + 1}) ++++++++++")
        print("DB 조회를 위해 다음 행동을 결정합니다...")

        system_prompt = """
        당신은 사용자의 포트폴리오 데이터베이스를 조회하여 질문에 답변하는 데이터베이스 전문가입니다.

        **행동 지침:**
        1. 가장 먼저 `sql_db_list_tables`를 호출하여 사용 가능한 테이블을 확인하세요.
        2. 그 다음, `sql_db_schema`를 호출하여 관련된 테이블의 구조를 파악하세요.
        3. 마지막으로, 알아낸 테이블과 스키마 정보를 바탕으로 `sql_db_query`를 실행하여 질문에 대한 답을 찾으세요.
        """
        messages_with_system_prompt = [SystemMessage(content=system_prompt), *state["messages"]]

        response = agent_model.invoke(messages_with_system_prompt)
        # 도구 호출이 아닌, 최종 답변일 경우에만 제목을 추가합니다.
        if not response.tool_calls:
            response.content = "## 포트폴리오 조회 결과\n\n" + response.content

        return {"messages": [response], "turn_count": current_turn + 1}

    tool_node = ToolNode(db_tools)

    # --- 3-3. 조건부 엣지(Edge) 함수 정의 ---
    MAX_TURNS = 5
    def agent_router(state: AutonomousState):
        print("\n----- 🚦 ROUTER -----")
        if state.get("turn_count", 0) >= MAX_TURNS:
            print(f"⚠️ Safety Guard: 최대 반복 횟수({MAX_TURNS}회)를 초과하여 강제로 종료합니다.\n")
            return "end"

        last_message = state["messages"][-1]
        if last_message.tool_calls:
            print("분기: [call_tool] -> TOOLS 노드로 이동합니다.\n")
            return "call_tool"
        else:
            print("분기: [end] -> 최종 답변이 생성되어 종료합니다.\n")
            return "end"

    # --- 3-4. 그래프 구성 및 컴파일 ---
    workflow = StateGraph(AutonomousState)
    workflow.add_node("agent", agent_node)
    workflow.add_node("tools", tool_node)

    workflow.set_entry_point("agent")
    workflow.add_conditional_edges("agent", agent_router, {"call_tool": "tools", "end": END})
    workflow.add_edge("tools", "agent")

    return workflow.compile()


# --- 4. 메인 실행 함수 ---
async def main():
    # --- 4-1. 그래프 생성 함수 호출 ---
    app = await create_db_agent_graph()
    print("✅ 포트폴리오 Agent 그래프가 성공적으로 컴파일되었습니다.")

    # --- 4-2. 시각화 ---
    mermaid_syntax = app.get_graph().draw_mermaid()
    display(HTML(f"""
    <div style="background-color: white; border: 1px solid #ddd; padding: 10px; border-radius: 5px;"><pre class="mermaid">{mermaid_syntax}</pre></div>
    <script type="module">import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.esm.min.mjs';await mermaid.run();</script>
    """))

    # --- 4-3. Agent 실행 ---
    print("\n================ PortfolioAgent 테스트 실행 ================")
    inputs = {"messages": [HumanMessage(content="내 포트폴리오에 있는 모든 종목의 티커와 보유 수량을 알려줘.")], "turn_count": 0}

    async for event in app.astream(inputs, stream_mode="values"):
        last_message = event["messages"][-1]
        if isinstance(last_message, HumanMessage):
            print("\n++++++++++ 🙋‍♂️ USER INPUT ++++++++++")
            last_message.pretty_print()
        else:
            last_message.pretty_print()

# --- 5. 비동기 메인 함수 실행 ---
await main()
# Out:
# 📡 DB 서버에만 연결하는 MCP 클라이언트를 설정합니다...
# ✅ 포트폴리오 Agent용 도구 로딩 완료: ['sql_db_query', 'sql_db_schema', 'sql_db_list_tables', 'sql_db_query_checker']
# ✅ 포트폴리오 Agent 그래프가 성공적으로 컴파일되었습니다.
#     <div style="background-color: white; border: 1px solid #ddd; padding: 10px; border-radius: 5px;"><pre class="mermaid">---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	agent(agent)
# 	tools(tools)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> agent;
# 	agent -. &nbsp;end&nbsp; .-> __end__;
# 	agent -. &nbsp;call_tool&nbsp; .-> tools;
# 	tools --> agent;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
# </pre></div>
#     <script type="module">import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.esm.min.mjs';await mermaid.run();</script>
# ================ PortfolioAgent 테스트 실행 ================
#
# ++++++++++ 🙋‍♂️ USER INPUT ++++++++++
# ================================ Human Message =================================
#
# 내 포트폴리오에 있는 모든 종목의 티커와 보유 수량을 알려줘.
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 1) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_list_tables (c89913c1-5fbd-464d-9a92-b31abc508030)
#  Call ID: c89913c1-5fbd-464d-9a92-b31abc508030
#   Args:
#     tool_input:
# ================================= Tool Message =================================
# Name: sql_db_list_tables
#
# my_portfolio
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 2) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_schema (67d1e2f5-35e1-4a4e-972b-a30aa1ca5385)
#  Call ID: 67d1e2f5-35e1-4a4e-972b-a30aa1ca5385
#   Args:
#     table_names: my_portfolio
# ================================= Tool Message =================================
# Name: sql_db_schema
#
#
# CREATE TABLE my_portfolio (
# 	id INTEGER,
# 	ticker TEXT NOT NULL,
# 	company_name TEXT NOT NULL,
# 	shares_owned INTEGER NOT NULL,
# 	purchase_price REAL NOT NULL,
# 	PRIMARY KEY (id),
# 	UNIQUE (ticker)
# )
#
# /*
# 3 rows from my_portfolio table:
# id	ticker	company_name	shares_owned	purchase_price
# 1	NVDA	NVIDIA Corp	50	120.5
# 2	AAPL	Apple Inc	100	185.75
# 3	TSLA	Tesla Inc	30	250.0
# */
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 3) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_query_checker (ef03e1ac-99a7-4449-8ad0-1831018a41f5)
#  Call ID: ef03e1ac-99a7-4449-8ad0-1831018a41f5
#   Args:
#     query: SELECT ticker, shares_owned FROM my_portfolio
# ================================= Tool Message =================================
# Name: sql_db_query_checker
#
# ```sql
# SELECT ticker, shares_owned FROM my_portfolio
# ```
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 4) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_query (4e19001a-a61f-4bb7-a3c9-76518451ddb9)
#  Call ID: 4e19001a-a61f-4bb7-a3c9-76518451ddb9
#   Args:
#     query: SELECT ticker, shares_owned FROM my_portfolio
# ================================= Tool Message =================================
# Name: sql_db_query
#
# [('NVDA', 50), ('AAPL', 100), ('TSLA', 30)]
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 5) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# ⚠️ Safety Guard: 최대 반복 횟수(5회)를 초과하여 강제로 종료합니다.
#
# ================================== Ai Message ==================================
#
# ## 포트폴리오 조회 결과
#
# 포트폴리오에 있는 모든 종목의 티커와 보유 수량은 다음과 같습니다.
#
# * NVDA: 50주
# * AAPL: 100주
# * TSLA: 30주

# %% [markdown]
# # 🛑 포트폴리오 MCP 서버 종료
#
# 모든 작업이 완료되었으므로, 백그라운드에서 실행되던 **DB 서버(포트 8001)** 프로세스를 종료하여 시스템 자원을 정리합니다.
#
#   * **`lsof -ti tcp:8001`**: 네트워크 **포트 8001**을 사용 중인 프로세스의 ID(PID)를 찾습니다.
#   * **`| xargs -r kill`**: 찾아낸 프로세스 ID를 `kill` 명령어에 전달하여 해당 프로세스를 안전하게 종료시킵니다.

# %%
# !lsof -ti tcp:8001 | xargs -r kill; echo "✅ 포트폴리오 MCP Server shutdown complete"
# Out:
# ✅ 포트폴리오 MCP Server shutdown complete

# %% [markdown]
# # 👑 Orchestrator: 전문가 Agent들을 지휘하는 상위 Agent
#
# 지금까지 만든 `금융 정보 Agent`와 `포트폴리오 DB 조회 Agent`를 각각의 전문가로 보고, 이 전문가들을 총괄하여 복잡한 임무를 수행하게 할 **`상위 Agent(Orchestrator)`**를 구축합니다. 이는 **단일 Agent로는 해결하기 어려운 복잡한 문제를 여러 개의 단순한 하위 문제로 나누어 해결**할 수 있게 해주는 매우 강력한 계층적 접근 방식입니다.
#
# ### 1\. 하위 Agent를 '도구(Tool)'로 추상화
#
# 가장 핵심적인 아이디어는, 앞서 만든 두 전문가 Agent를 **하나의 '도구(함수)'처럼** 만드는 것입니다. 상위 Agent가 이 도구를 호출하면, 내부적으로는 해당 하위 Agent의 전체 워크플로우가 실행되고 그 최종 결과만 반환됩니다.
#
# ```python
# @tool
# async def financial_info_agent_tool(query: str) -> str:
#     """금융 정보 분석 전문가 Agent를 호출하는 도구"""
#     # 1. 하위 Agent 그래프 생성
#     app = await create_financial_agent_graph()
#     # 2. 하위 Agent 실행 및 결과 반환
#     response = await app.ainvoke({"messages": [HumanMessage(content=query)], ...})
#     return response['messages'][-1].content
# ```
#
# ### 2\. 상위 Agent (Orchestrator) 워크플로우
#
# 상위 Agent는 '계획을 세우는 Agent'와 '최종 보고서를 작성하는 Reporter'의 역할로 나뉩니다.
#
# #### 2.1. 마스터 Agent (`orchestrator_agent_node`)
#
# 사용자의 복잡한 질문을 받고, **어떤 전문가 Agent(도구)를 어떤 순서로 호출할지 계획**을 세우는 '마스터 Agent' 역할을 합니다. **한 번에 하나의 도구만 호출**하도록 규칙을 설정하여 신중하게 작업을 수행합니다.
#
# ```python
# system_prompt = """
# 당신은 전문가 팀을 이끄는 마스터 Agent입니다. 당신의 임무는 사용자의 복잡한 요청을 해결하기 위해, 가장 적합한 전문가 Agent(도구)를 순서대로 호출하는 것입니다.
# **매우 중요한 규칙:**
# 1. 당신은 도구를 반드시 **한 번에 하나씩만** 순서대로 호출해야 합니다.
# 2. **모든 정보 수집이 완료되었다고 판단되면, ... '모든 정보 수집 완료'라고만 답변하세요.**
# """
# ```
#
# #### 2.2. 최고 투자 책임자 (`orchestrator_report_node`)
#
# 모든 하위 Agent들의 작업이 끝나면, 각 전문가가 가져온 정보들을 모두 모아 **'최고 투자 책임자(CIO)'의 관점에서 최종 종합 리포트를 작성**합니다.
#
# ```python
# report_prompt = f"""
# 당신은 최고 투자 책임자(CIO)입니다. 아래는 각 팀(하위 Agent)이 수집하고 분석한 투자 정보입니다.
#
# [각 팀의 분석 보고 내용]
# {dedented_history}
#
# ... 최종 종합 투자 리포트를 상세하고 명확하게 작성해주세요.
# """
# ```
#
# ### 3\. 실행 및 결과 확인
#
# 복잡한 사용자 질문("내 포트폴리오의 모든 종목에 대해 최신 주가와 부정적 뉴스를 종합해서 리포트 해줘")이 입력되면, 상위 Agent는 다음과 같이 행동합니다.
#
# 1.  **포트폴리오 DB 조회 Agent**를 호출하여 포트폴리오에 어떤 종목이 있는지 파악합니다.
# 2.  알아낸 각 종목에 대해 **금융 정보 Agent**를 순서대로 호출하여 주가와 뉴스를 분석합니다.
# 3.  모든 정보가 취합되면, 최종 리포트 노드가 **종합적인 투자 리포트를 생성**하며 프로세스를 완료합니다.

# %%
# --- 1. 금융 정보 MCP 서버 시작 및 확인 (Port 8000) ---
start_and_check_search_server()
print("\n" + "="*40 + "\n")

# --- 2. 포트폴리오 MCP 서버 시작 및 확인 (Port 8001) ---
start_and_check_mcp_server()
print("\n" + "="*40)

print("✅ 모든 MCP 서버 시작 작업이 완료되었습니다.")
print("   각 서버의 최종 상태를 위 로그에서 확인하세요.")
# Out:
# 🚀 금융 정보 MCP 서버를 시작합니다...
# ⏱️  서버 시작 대기 중... (최대 30초)
#    ...로그 파일 확인 중...
#    ...로그 파일 확인 중...
# ------------------------------
# ✅ 금융 정보 MCP 서버가 성공적으로 시작되어 실행 중입니다.
#    (로그 파일: /content/search_server.log)
#
# ========================================
#
# 🚀 포트폴리오 MCP 서버를 시작합니다...
# ⏱️  DB 서버 시작 대기 중... (최대 30초)
#    ...로그 파일 확인 중...
#    ...로그 파일 확인 중...
#    ...로그 파일 확인 중...
#    ...로그 파일 확인 중...
#    ...로그 파일 확인 중...
#    ...로그 파일 확인 중...
# ------------------------------
# ✅ 포트폴리오 MCP 서버가 성공적으로 시작되어 실행 중입니다.
#    (로그 파일: /content/db_server.log)
#
# ========================================
# ✅ 모든 MCP 서버 시작 작업이 완료되었습니다.
#    각 서버의 최종 상태를 위 로그에서 확인하세요.

# %%
# --- 1. 필요한 모든 모듈 임포트 ---
import asyncio
import operator
import textwrap
from typing import List, TypedDict, Annotated

from langchain_core.tools import tool
from langchain_core.messages import BaseMessage, HumanMessage, SystemMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph, END
from langgraph.prebuilt import ToolNode


# --- 2. 하위 Agent를 호출하는 '도구(Tool)' 함수 정의 ---
@tool
async def financial_info_agent_tool(query: str) -> str:
    """
    특정 회사에 대한 최신 주가, 뉴스, 사업 개요 등 금융 정보를 상세히 분석하고 리포트를 작성할 때 사용합니다.
    예: '삼성전자 주가와 최신 AI 관련 뉴스 알려줘'
    """
    print(f"\n>>>> [호출] 금융 정보 Agent (입력: {query})")
    app = await create_financial_agent_graph() # 이전 단계에서 정의한 금융 정보 조회 에이전트를 재사용합니다.
    response = await app.ainvoke({"messages": [HumanMessage(content=query)], "turn_count": 0})
    print("<<<< [완료] 금융 정보 Agent")
    return response["messages"][-1].content

@tool
async def portfolio_db_agent_tool(query: str) -> str:
    """
    사용자의 개인 주식 포트폴리오 데이터베이스를 조회할 때 사용합니다.
    보유 종목, 수량, 매수 가격 등의 정보를 확인할 수 있습니다.
    예: '내 포트폴리오에 있는 모든 종목 알려줘'
    """
    print(f"\n>>>> [호출] DB 조회 Agent (입력: {query})")
    app = await create_db_agent_graph() # 이전 단계에서 정의한 포트폴리오 DB 조회 에이전트를 재사용합니다.
    response = await app.ainvoke({"messages": [HumanMessage(content=query)], "turn_count": 0})
    print("<<<< [완료] DB 조회 Agent")
    return response["messages"][-1].content



# --- 3. 상위 Agent (Orchestrator) 워크플로우 구축 ---
async def create_orchestrator_graph():
    """
    'Agent + Reporter' 구조를 가진 상위 Orchestrator 그래프를 생성합니다.
    """
    # 상위 Agent가 사용할 도구 목록
    orchestrator_tools = [financial_info_agent_tool, portfolio_db_agent_tool]

    # 상위 Agent용 LLM 설정
    orchestrator_llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0).bind_tools(orchestrator_tools)
    reporting_llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.5)

    # 상위 Agent의 상태 정의
    class OrchestratorState(TypedDict):
        messages: Annotated[List[BaseMessage], operator.add]
        turn_count: int

    # --- 노드 정의 ---
    def orchestrator_agent_node(state: OrchestratorState):
        """Orchestrator의 계획 및 도구 호출 담당 노드"""
        current_turn = state.get("turn_count", 0)
        print(f"\n\n++++++++++ 👑 ORCHESTRATOR AGENT (Turn {current_turn + 1}) ++++++++++")
        print("사용자의 복합 질문을 분석하고, 어떤 전문가 Agent를 호출할지 계획을 세웁니다...")
        system_prompt = """
        당신은 전문가 팀을 이끄는 마스터 Agent입니다. 당신의 임무는 사용자의 복잡한 요청을 해결하기 위해, 가장 적합한 전문가 Agent(도구)를 순서대로 호출하는 것입니다.
        **매우 중요한 규칙:**
        1. 당신은 도구를 반드시 **한 번에 하나씩만** 순서대로 호출해야 합니다.
        2. **포트폴리오의 모든 종목에 대한 정보 수집이 완료되었다고 판단되면, 더 이상 도구를 호출하지 말고 '모든 정보 수집 완료'라고만 답변하세요.**
        """
        response = orchestrator_llm.invoke([SystemMessage(content=system_prompt), *state["messages"]])
        return {"messages": [response], "turn_count": current_turn + 1}

    def orchestrator_report_node(state: OrchestratorState):
        """모든 하위 Agent의 결과물을 종합하여 최종 리포트를 생성하는 노드"""
        print("\n\n++++++++++ 💎 ORCHESTRATOR REPORTER ++++++++++")
        print("모든 전문가 Agent의 분석 결과를 종합하여 최종 리포트를 작성합니다...")
        report_history = [msg for msg in state["messages"] if not isinstance(msg, HumanMessage)]
        history_str = "\n".join([msg.pretty_repr() for msg in report_history])
        dedented_history = textwrap.dedent(history_str)
        initial_query = state["messages"][0].content

        report_prompt = f"""
        당신은 최고 투자 책임자(CIO)입니다. 아래는 각 팀(하위 Agent)이 수집하고 분석한 투자 정보입니다.

        [각 팀의 분석 보고 내용]
        {dedented_history}

        [초기 사용자 요청]
        {initial_query}

        위 정보를 모두 종합하여, 사용자의 초기 요청에 대한 최종 종합 투자 리포트를 상세하고 명확하게 작성해주세요.
        각 종목별 분석 내용을 먼저 요약하고, 마지막에 종합적인 결론과 투자 전략을 제시해주세요.
        """
        final_report = reporting_llm.invoke(report_prompt)
        return {"messages": [final_report]}

    # --- 라우터 정의 ---
    MAX_ORCHESTRATOR_TURNS = 10 # Orchestrator의 최대 실행 횟수 정의
    def orchestrator_router(state: OrchestratorState):
        """Orchestrator Agent의 다음 행동을 결정하는 라우터"""
        print("\n----- 🚦 ORCHESTRATOR ROUTER -----")

        # 최대 실행 횟수를 초과했는지 먼저 확인합니다.
        if state.get("turn_count", 0) >= MAX_ORCHESTRATOR_TURNS:
            print(f"⚠️ Safety Guard: 최대 반복 횟수({MAX_ORCHESTRATOR_TURNS}회)를 초과하여 강제로 리포트 생성을 시작합니다.\n")
            return "generate_report"

        last_message = state["messages"][-1]
        if last_message.tool_calls:
            print("분기: [call_tool] -> 하위 Agent(Tool)를 호출합니다.\n")
            return "call_tool"
        else:
            print("분기: [generate_report] -> 최종 리포트 생성을 시작합니다.\n")
            return "generate_report"

    # --- 그래프 구성 ---
    workflow = StateGraph(OrchestratorState)
    workflow.add_node("agent", orchestrator_agent_node)
    workflow.add_node("tools", ToolNode(orchestrator_tools))
    workflow.add_node("reporter", orchestrator_report_node)

    workflow.set_entry_point("agent")
    workflow.add_edge("tools", "agent")
    workflow.add_edge("reporter", END)

    # agent의 결과에 따라 tools로 가거나 reporter로 가도록 조건부 엣지 설정
    workflow.add_conditional_edges(
        "agent",
        orchestrator_router,
        {"call_tool": "tools", "generate_report": "reporter"}
    )

    orchestrator_app = workflow.compile()
    print("\n🎉 'Agent + Reporter' 구조의 상위 Agent가 성공적으로 컴파일되었습니다.")
    return orchestrator_app


# --- 4. 상위 Agent 실행 ---
async def run_orchestrator():
    print("\n🚀 상위 Agent 실행을 시작합니다...")
    orchestrator_app = await create_orchestrator_graph()

    # --- 4-2. 시각화 ---
    mermaid_syntax = orchestrator_app.get_graph().draw_mermaid()
    display(HTML(f"""
    <div style="background-color: white; border: 1px solid #ddd; padding: 10px; border-radius: 5px;"><pre class="mermaid">{mermaid_syntax}</pre></div>
    <script type="module">import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.esm.min.mjs';await mermaid.run();</script>
    """))

    complex_query = "내 포트폴리오에 있는 모든 종목의 현재 상황에 대해 알려줘. 종목별 최신 주가와 부정적인 뉴스가 있는지 각각 확인해서 종합 리포트를 작성해줘."
    inputs = {"messages": [HumanMessage(content=complex_query)], "turn_count": 0}

    print("\n\n================ Orchestrator Agent 모델 실행 ================")
    print("\n++++++++++ 🙋‍♂️ USER INPUT ++++++++++")
    inputs["messages"][0].pretty_print()

    # 각 노드의 출력을 순서대로 처리
    async for update in orchestrator_app.astream(inputs, stream_mode="updates"):
        # update는 {'node_name': {'key': 'value'}} 형태의 딕셔너리
        node_name = list(update.keys())[0]
        node_output = list(update.values())[0]

        if node_name == "agent":
            # agent 노드의 AiMessage (계획 또는 최종 답변)를 출력
            print(f"\n--- 👑 ORCHESTRATOR AGENT ---")
            node_output['messages'][-1].pretty_print()

        elif node_name == "tools":
            # tools 노드는 ToolMessage 리스트를 반환
            print("\n--- 🛠️ TOOLS ---")
            for tool_message in node_output['messages']:
                tool_message.pretty_print()

        elif node_name == "reporter":
            # reporter 노드의 최종 결과 AiMessage를 출력
            print("\n--- 💎 ORCHESTRATOR REPORTER ---")
            node_output['messages'][-1].pretty_print()

    print("\n✅ Orchestrator 실행이 완료되었습니다.")

# 비동기 함수 실행
await run_orchestrator()
# Out:
# 🚀 상위 Agent 실행을 시작합니다...
#
# 🎉 'Agent + Reporter' 구조의 상위 Agent가 성공적으로 컴파일되었습니다.
#     <div style="background-color: white; border: 1px solid #ddd; padding: 10px; border-radius: 5px;"><pre class="mermaid">---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	agent(agent)
# 	tools(tools)
# 	reporter(reporter)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> agent;
# 	agent -. &nbsp;generate_report&nbsp; .-> reporter;
# 	agent -. &nbsp;call_tool&nbsp; .-> tools;
# 	tools --> agent;
# 	reporter --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
# </pre></div>
#     <script type="module">import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.esm.min.mjs';await mermaid.run();</script>
# ================ Orchestrator Agent 모델 실행 ================
#
# ++++++++++ 🙋‍♂️ USER INPUT ++++++++++
# ================================ Human Message =================================
#
# 내 포트폴리오에 있는 모든 종목의 현재 상황에 대해 알려줘. 종목별 최신 주가와 부정적인 뉴스가 있는지 각각 확인해서 종합 리포트를 작성해줘.
#
#
# ++++++++++ 👑 ORCHESTRATOR AGENT (Turn 1) ++++++++++
# 사용자의 복합 질문을 분석하고, 어떤 전문가 Agent를 호출할지 계획을 세웁니다...
#
# ----- 🚦 ORCHESTRATOR ROUTER -----
# 분기: [call_tool] -> 하위 Agent(Tool)를 호출합니다.
#
#
# --- 👑 ORCHESTRATOR AGENT ---
# ================================== Ai Message ==================================
# Tool Calls:
#   portfolio_db_agent_tool (1a15a308-2805-40ec-8a37-305f16ae0990)
#  Call ID: 1a15a308-2805-40ec-8a37-305f16ae0990
#   Args:
#     query: 내 포트폴리오에 있는 모든 종목 알려줘
#
# >>>> [호출] DB 조회 Agent (입력: 내 포트폴리오에 있는 모든 종목 알려줘)
# 📡 DB 서버에만 연결하는 MCP 클라이언트를 설정합니다...
# ✅ 포트폴리오 Agent용 도구 로딩 완료: ['sql_db_query', 'sql_db_schema', 'sql_db_list_tables', 'sql_db_query_checker']
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 1) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 2) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 3) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [end] -> 최종 답변이 생성되어 종료합니다.
#
# <<<< [완료] DB 조회 Agent
#
# --- 🛠️ TOOLS ---
# ================================= Tool Message =================================
# Name: portfolio_db_agent_tool
#
# ## 포트폴리오 조회 결과
#
# 내 포트폴리오에는 NVDA, AAPL, TSLA 세 종목이 있습니다.
#
#
# ++++++++++ 👑 ORCHESTRATOR AGENT (Turn 2) ++++++++++
# 사용자의 복합 질문을 분석하고, 어떤 전문가 Agent를 호출할지 계획을 세웁니다...
#
# ----- 🚦 ORCHESTRATOR ROUTER -----
# 분기: [call_tool] -> 하위 Agent(Tool)를 호출합니다.
#
#
# --- 👑 ORCHESTRATOR AGENT ---
# ================================== Ai Message ==================================
# Tool Calls:
#   financial_info_agent_tool (3137c9b5-fe80-4d3f-bcbd-5e2e6e99c7bc)
#  Call ID: 3137c9b5-fe80-4d3f-bcbd-5e2e6e99c7bc
#   Args:
#     query: NVDA 최신 주가와 부정적인 뉴스 알려줘
#
# >>>> [호출] 금융 정보 Agent (입력: NVDA 최신 주가와 부정적인 뉴스 알려줘)
# 📡 MCP 클라이언트를 HTTP 방식으로 설정합니다...
# ✅ 로딩된 도구: ['get_stock_price', 'get_latest_news', 'get_company_overview', 'get_analyst_opinions']
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 1) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 2) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [generate_report] -> REPORTER 노드로 이동합니다.
#
#
# ++++++++++ ✍️ FINANCIAL REPORTER ++++++++++
# 수집된 모든 정보를 종합하여 최종 리포트를 작성합니다...
# <<<< [완료] 금융 정보 Agent
#
# --- 🛠️ TOOLS ---
# ================================= Tool Message =================================
# Name: financial_info_agent_tool
#
# ## 엔비디아(NVIDIA, NVDA) 투자 리포트
#
# **작성일:** 2025년 10월 17일
#
# ---
#
# ### 1. 요약 (Executive Summary)
#
# 엔비디아(NVIDIA)는 현재 $183.22에 거래되고 있으며, 애널리스트들의 '적극 매수' 의견과 평균 목표주가 $218.51(약 19.26% 상승 여력)는 긍정적인 투자 전망을 제시합니다. 시가총액 4.45조 달러의 거대 기업으로서 강력한 시장 지위를 가지고 있습니다. 그러나 과거 그래픽 칩셋 결함 은폐 의혹, 리눅스 드라이버 지원 문제, 그리고 경쟁사 제품 배척 의혹 등 다수의 부정적 사건 및 논란 기록은 잠재적 투자 리스크로 작용할 수 있습니다. 장기적인 성장 잠재력은 높으나, 과거의 부정적 이슈들이 기업의 평판 및 규제 리스크로 이어질 가능성을 염두에 둔 신중한 접근이 필요합니다.
#
# ---
#
# ### 2. 회사 개요
#
# 엔비디아(NVIDIA Corporation, 티커: NVDA)는 그래픽 처리 장치(GPU) 설계 및 제조 분야의 세계적인 선두 기업입니다. 게임, 전문 시각화, 데이터 센터, 자동차 등 다양한 산업에 걸쳐 혁신적인 기술을 제공하며, 특히 인공지능(AI) 및 딥러닝 분야에서 핵심적인 역할을 하고 있습니다. 나스닥 증권 거래소에 상장되어 있습니다.
#
# ---
#
# ### 3. 주가 현황 및 재무 분석 (2025년 10월 17일 기준)
#
# *   **현재 주가:** $183.22
# *   **이전 종가:** $181.81
# *   **일간 범위:** $179.75 ~ $184.10
# *   **52주 범위:** $86.62 ~ $195.62
# *   **애널리스트 목표주가 (평균):** $218.51
#     *   최고치: $320
#     *   최저치: $100
#     *   현재 주가 대비 상승 여력: +19.26%
# *   **애널리스트 투자의견:**
#     *   매수: 58명
#     *   매도: 1명
#     *   종합 투자의견: 적극 매수
# *   **시가총액:** 4.45조 달러
# *   **주당순이익 (EPS, TTM):** $3.51
# *   **배당수익률:** 0.02%
# *   **다음 실적 발표 예정일:** 2025년 11월 18일
# *   **직원 수:** 36,000명
#
# 엔비디아는 강력한 시장 지위를 바탕으로 높은 애널리스트 평가를 받고 있으며, 상당한 주가 상승 여력을 보유하고 있습니다. 그러나 배당수익률은 매우 낮은 수준입니다.
#
# ---
#
# ### 4. 긍정적 투자 요인
#
# *   **강력한 시장 지배력:** GPU 시장, 특히 AI 및 데이터 센터 분야에서 독보적인 기술력과 시장 점유율을 보유하고 있습니다.
# *   **높은 성장 잠재력:** 인공지능, 메타버스, 자율주행 등 미래 핵심 기술 분야의 성장에 직접적으로 연관되어 있어 장기적인 성장 동력이 풍부합니다.
# *   **애널리스트의 긍정적 평가:** 대다수의 애널리스트가 '적극 매수' 의견을 제시하고 있으며, 현재 주가 대비 약 19% 이상의 상승 여력을 예측하고 있습니다.
# *   **견고한 재무 상태:** 4.45조 달러에 달하는 시가총액은 기업의 안정성과 시장 내 영향력을 보여줍니다.
#
# ---
#
# ### 5. 부정적 투자 요인 및 리스크
#
# *   **과거 결함 은폐 의혹 및 소송:** HP, Dell, Apple 등 주요 노트북 제조사들이 엔비디아의 그래픽 칩셋 결함으로 인해 소송을 제기했으며, 엔비디아가 이를 부인했음에도 불구하고 각 제조사들의 조사 결과 결함이 확인되었습니다. 이는 고객 신뢰도 하락 및 잠재적 추가 소송 리스크로 작용할 수 있습니다.
# *   **주주들의 사기죄 혐의 소송:** 엔비디아의 투자자들이 GPU 땜납 문제 가능성을 인지하고도 이를 주주들에게 은폐하여 손실을 끼쳤다는 혐의로 소송을 제기했습니다. 이는 기업의 투명성 및 지배구조에 대한 우려를 낳을 수 있습니다.
# *   **리눅스 생태계와의 마찰:** 구형 그래픽카드의 리눅스 공식 드라이버 지원 중단 및 Wayland 지원 미흡으로 리눅스 사용자들로부터 비판을 받고 있습니다. 이는 특정 사용자층의 불만으로 이어져 브랜드 이미지에 부정적인 영향을 줄 수 있습니다.
# *   **리마킹 GPU 및 허위매물 파동:** 과거 리마킹 GPU(성능을 속여 판매) 및 허위매물 논란이 있었다는 기록은 기업의 윤리적 문제와 관련하여 잠재적 리스크로 남아있습니다.
# *   **경쟁사 제품 배척 의혹:** '배트맨: 아캄 어사일럼' 게임에서 AMD GPU의 AA(안티 앨리어싱) 기능을 의도적으로 제한했다는 의혹은 반경쟁적 행위로 비춰질 수 있으며, 향후 규제 당국의 조사를 받을 가능성을 내포합니다.
#
# ---
#
# ### 6. 종합 의견 및 투자 제언
#
# 엔비디아는 AI 시대의 핵심 기술 기업으로서 높은 성장 잠재력과 견고한 시장 지위를 바탕으로 애널리스트들의 강력한 '적극 매수' 추천을 받고 있습니다. 평균 목표주가까지의 상승 여력 또한 매력적입니다.
#
# 하지만, 과거 여러 차례 불거졌던 제품 결함 은폐 의혹, 주주 소송, 반경쟁적 행위 논란 등은 기업의 장기적인 평판과 브랜드 가치에 부정적인 영향을 미칠 수 있는 중요한 리스크 요인입니다. 이러한 부정적 이슈들은 잠재적으로 법적 분쟁, 규제 강화, 소비자 및 투자자 신뢰 하락으로 이어질 수 있습니다.
#
# **투자 제언:**
# 장기적인 관점에서 엔비디아의 기술 혁신 능력과 시장 선도적 지위는 여전히 유효하며, AI 산업의 성장에 힘입어 꾸준한 성장을 기대할 수 있습니다. 그러나 과거의 부정적 사건들이 재발하거나 현재 진행 중인 소송 및 의혹들이 기업 실적이나 평판에 실제적인 타격을 줄 가능성을 간과해서는 안 됩니다.
#
# **보수적인 투자자라면:** 현재의 높은 성장 잠재력에도 불구하고, 과거 논란들이 완전히 해소되기 전까지는 관망하거나 투자 비중을 조절하는 것을 고려해 볼 수 있습니다.
# **적극적인 투자자라면:** 엔비디아의 기술력과 시장 지배력에 대한 신뢰를 바탕으로 투자하되, 기업의 투명성 강화 노력과 잠재적 리스크 요인들의 진행 상황을 지속적으로 모니터링해야 합니다.
#
# 결론적으로, 엔비디아는 매력적인 성장 동력을 가진 기업이지만, 과거의 부정적 이슈들이 내포하는 리스크를 충분히 인지하고 신중하게 접근하는 것이 현명한 투자 전략이 될 것입니다.
#
#
# ++++++++++ 👑 ORCHESTRATOR AGENT (Turn 3) ++++++++++
# 사용자의 복합 질문을 분석하고, 어떤 전문가 Agent를 호출할지 계획을 세웁니다...
#
# ----- 🚦 ORCHESTRATOR ROUTER -----
# 분기: [call_tool] -> 하위 Agent(Tool)를 호출합니다.
#
#
# --- 👑 ORCHESTRATOR AGENT ---
# ================================== Ai Message ==================================
# Tool Calls:
#   financial_info_agent_tool (f3132d1e-b320-4cfd-a5b5-0fe8258a6220)
#  Call ID: f3132d1e-b320-4cfd-a5b5-0fe8258a6220
#   Args:
#     query: AAPL 최신 주가와 부정적인 뉴스 알려줘
#
# >>>> [호출] 금융 정보 Agent (입력: AAPL 최신 주가와 부정적인 뉴스 알려줘)
# 📡 MCP 클라이언트를 HTTP 방식으로 설정합니다...
# ✅ 로딩된 도구: ['get_stock_price', 'get_latest_news', 'get_company_overview', 'get_analyst_opinions']
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 1) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 2) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [generate_report] -> REPORTER 노드로 이동합니다.
#
#
# ++++++++++ ✍️ FINANCIAL REPORTER ++++++++++
# 수집된 모든 정보를 종합하여 최종 리포트를 작성합니다...
# <<<< [완료] 금융 정보 Agent
#
# --- 🛠️ TOOLS ---
# ================================= Tool Message =================================
# Name: financial_info_agent_tool
#
# ## AAPL 투자 리포트: 주요 리스크 및 전망 분석
#
# **작성일:** 2024년 10월 27일 (정보 수집 기록 기준)
# **분석 대상:** Apple Inc. (NASDAQ: AAPL)
# **작성자:** 전문 애널리스트
#
# ---
#
# ### **1. 총평 및 핵심 요약**
#
# Apple (AAPL) 주가는 최근 몇 주간 꾸준히 상승하며 사상 최고치에 근접한 $271.40를 기록하고 있습니다. 이는 전문 트레이더들의 긍정적인 시장 심리와 견조한 지지선($200)에 기반한 것으로 보입니다. 그러나 이러한 상승세에도 불구하고, 중국 시장에서의 압박 심화, 관세로 인한 비용 증가, 그리고 연초 대비 저조한 주가 수익률(-15.7% vs. 나스닥100 +6.5%) 등 상당한 역풍에 직면해 있습니다.
#
# 오는 10월 30일(미국 현지 시간) 예정된 2025년 회계연도 4분기 실적 발표는 이러한 긍정적 모멘텀과 부정적 리스크 요인 사이의 균형을 가늠할 중요한 분수령이 될 것입니다. 현재 시장은 낙관적인 전망을 유지하고 있으나, 중국 관련 불확실성과 관세 영향이 실적에 미치는 구체적인 결과에 따라 주가 변동성이 확대될 수 있습니다.
#
# ### **2. 현재 주가 및 시장 동향**
#
# *   **현재가:** $271.40 USD (24시간 동안 0.63% 상승)
# *   **최근 추세:** 지난 몇 주간 꾸준히 상승하여 사상 최고치에 근접.
# *   **애널리스트 목표가 (TradingView 기준):**
#     *   방향: LONG (매수)
#     *   목표가: T1 = $275.00, T2 = $285.00
#     *   손절가: S1 = $258.00, S2 = $252.00
# *   **주요 이벤트:** 2025년 회계연도 4분기 실적 발표 (10월 30일 예정)
#
# ### **3. 주요 긍정적 요인**
#
# *   **견고한 상승 모멘텀:** 시장의 역풍에도 불구하고 주가는 견조한 상승세를 유지하며 사상 최고치에 근접하고 있습니다. 이는 투자자들의 지속적인 신뢰를 반영합니다.
# *   **강력한 지지선:** $200선에서 강력한 지지선을 형성하며 주가 하방 경직성을 확보하고 있습니다.
# *   **전문 트레이더들의 긍정적 심리:** 다수의 전문 트레이더 및 시장 전문가들의 분석은 합의적으로 긍정적인 전망을 제시하고 있습니다.
#
# ### **4. 주요 부정적 요인 및 리스크**
#
# *   **중국 시장 압박:**
#     *   **경제 둔화 우려:** 중국 경제의 지속적인 압박은 애플의 성장에 대한 우려를 낳고 있습니다.
#     *   **자국 브랜드 선호도 증가:** 중국 현지 소비자들의 자국 브랜드 선호도가 높아지면서 애플의 시장 점유율에 부정적인 영향을 미치고 있습니다.
#     *   **정부 규제:** 중국 공무원들의 아이폰 사용 규제는 애플에 추가적인 역풍으로 작용하고 있습니다.
# *   **관세 부담 증가:**
#     *   팀 쿡 CEO는 1분기 관세 영향은 제한적이었으나, 2분기에는 약 9억 달러에 달하는 비용 증가를 초래했을 것으로 예상했습니다. 이는 다가오는 실적 발표의 핵심 요인이 될 것입니다.
# *   **연초 대비 저조한 성과:** 올해 연초 대비 애플 주가는 15.7% 하락하여, 같은 기간 나스닥100 인덱스의 6.5% 상승과는 대조적인 모습을 보였습니다. 이는 시장 전반의 긍정적인 흐름을 따라가지 못하고 있다는 신호입니다.
#
# ### **5. 향후 전망 및 투자 권고**
#
# Apple은 강력한 브랜드 가치와 혁신 역량을 바탕으로 견고한 팬덤을 유지하고 있으나, 현재 직면한 거시경제적 및 지정학적 리스크는 단기적인 주가 변동성을 높일 수 있습니다.
#
# *   **단기 전망:** 10월 30일 발표될 4분기 실적은 중국 시장에서의 성과와 관세 영향에 대한 구체적인 정보를 제공하며, 이는 향후 주가 방향을 결정하는 중요한 지표가 될 것입니다. 시장의 기대치를 충족시키지 못할 경우, 최근의 상승 랠리가 꺾일 가능성도 배제할 수 없습니다.
# *   **장기 전망:** 장기적으로 애플의 펀더멘털은 여전히 견고하다고 판단되지만, 중국 시장의 회복 여부와 글로벌 공급망 및 관세 정책 변화에 대한 대응이 핵심 과제가 될 것입니다.
#
# **투자 권고:**
#
# *   **기존 투자자:** 현재 주가는 사상 최고치에 근접해 있으므로, 단기적으로는 관망하며 10월 30일 실적 발표를 예의주시할 것을 권고합니다. 특히 중국 관련 매출 및 마진율 변화에 주목해야 하며, 제시된 손절가($258.00, $252.00)를 고려하여 리스크 관리에 만전을 기해야 합니다.
# *   **신규 투자자:** 현재 가격 수준은 단기적인 리스크를 내포하고 있으므로, 실적 발표 이후 중국 시장 불확실성 및 관세 부담에 대한 보다 명확한 그림이 그려질 때까지 기다리거나, 조정 시점을 활용하여 분할 매수를 고려하는 것이 현명할 수 있습니다.
#
# ---
# **Disclaimer:** 본 리포트는 제공된 정보 수집 기록을 바탕으로 작성되었으며, 투자 권유를 목적으로 하지 않습니다. 투자 결정은 투자자 본인의 판단과 책임 하에 이루어져야 합니다.
#
#
# ++++++++++ 👑 ORCHESTRATOR AGENT (Turn 4) ++++++++++
# 사용자의 복합 질문을 분석하고, 어떤 전문가 Agent를 호출할지 계획을 세웁니다...
#
# ----- 🚦 ORCHESTRATOR ROUTER -----
# 분기: [call_tool] -> 하위 Agent(Tool)를 호출합니다.
#
#
# --- 👑 ORCHESTRATOR AGENT ---
# ================================== Ai Message ==================================
# Tool Calls:
#   financial_info_agent_tool (5889232e-2cc7-4585-9a59-377fd9780ca3)
#  Call ID: 5889232e-2cc7-4585-9a59-377fd9780ca3
#   Args:
#     query: TSLA 최신 주가와 부정적인 뉴스 알려줘
#
# >>>> [호출] 금융 정보 Agent (입력: TSLA 최신 주가와 부정적인 뉴스 알려줘)
# 📡 MCP 클라이언트를 HTTP 방식으로 설정합니다...
# ✅ 로딩된 도구: ['get_stock_price', 'get_latest_news', 'get_company_overview', 'get_analyst_opinions']
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 1) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 2) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [generate_report] -> REPORTER 노드로 이동합니다.
#
#
# ++++++++++ ✍️ FINANCIAL REPORTER ++++++++++
# 수집된 모든 정보를 종합하여 최종 리포트를 작성합니다...
# <<<< [완료] 금융 정보 Agent
#
# --- 🛠️ TOOLS ---
# ================================= Tool Message =================================
# Name: financial_info_agent_tool
#
# ## TSLA (테슬라) 투자 리포트
#
# **작성일:** 2024년 12월 18일 (정보 수집 시점 기준)
# **분석 대상:** Tesla Inc. (TSLA)
#
# ### 1. 개요
#
# 본 리포트는 테슬라(TSLA)의 최근 주가 동향 및 관련 뉴스를 바탕으로 투자 관점에서 분석한 내용입니다. 현재 테슬라는 높은 변동성을 보이며, 특히 최고 경영자의 거취 문제와 정치적 리스크가 부각되고 있어 투자에 신중한 접근이 요구됩니다.
#
# ### 2. 현재 주가 및 시장 동향 (정보 수집 시점 기준)
#
# *   **현재가:** $461.51 (장중 +0.2084% 상승)
# *   **시작가:** $462.50
# *   **일중 최고/최저:** $465.70 / $452.65
# *   **전일 종가:** $460.55
# *   **52주 최고가:** $488.54 (2024년 12월 18일 기록)
# *   **52주 최저가:** $214.25 (2025년 4월 7일 기록)
#     *   *참고: 52주 최저가 날짜(2025년 4월 7일)가 현재 분석 시점(2024년 12월 18일)보다 미래로 표기되어 있어 데이터 입력 오류 가능성이 있으나, 제공된 정보를 그대로 반영합니다.*
#
# 테슬라의 주가는 최근 52주 최고가에 근접한 수준을 기록하며 강세를 보였으나, 일중 변동성이 큰 편입니다.
#
# ### 3. 주요 부정적 뉴스 및 리스크 요인
#
# 최근 테슬라와 관련하여 다음과 같은 부정적인 뉴스가 확인되었습니다.
#
# *   **엘론 머스크의 잠재적 퇴임 리스크:** 주주들이 엘론 머스크의 보상 계획에 반대하면서 그의 잠재적 퇴임 가능성이 제기되고 있습니다. 최고 경영자의 리더십 공백 또는 변화는 기업의 전략 방향과 투자 심리에 큰 불확실성을 초래할 수 있습니다.
# *   **정치적 행동의 판매 영향:** 한 연구에 따르면, 엘론 머스크의 정치적 행동이 테슬라의 판매에 부정적인 영향을 미치고 있으며, 특히 민주당 지지 지역에서 이러한 경향이 두드러지는 것으로 나타났습니다. 이는 브랜드 이미지와 소비자층 확장에 제약을 줄 수 있는 요인입니다.
#
# ### 4. 투자 판단 고려 사항
#
# *   **단기 변동성:** 현재 주가는 52주 최고가에 근접해 있지만, 최고 경영자 리스크와 판매 감소 우려가 복합적으로 작용하여 단기적인 주가 변동성이 확대될 수 있습니다.
# *   **장기 성장 동력 vs. 리스크:** 테슬라는 전기차 시장의 선두 주자로서 장기적인 성장 잠재력을 가지고 있으나, 엘론 머스크 관련 리스크는 기업의 안정적인 성장을 저해할 수 있는 주요 장애물로 작용할 수 있습니다. 특히 머스크의 거취 문제는 시장의 투자 심리에 매우 민감하게 반응할 것으로 예상됩니다.
# *   **외부 환경 변화:** 금리 인상, 경기 침체 우려, 경쟁 심화 등 거시 경제 및 산업 환경 변화 또한 테슬라 주가에 영향을 미칠 수 있는 요인입니다.
#
# ### 5. 결론 및 권고
#
# 테슬라(TSLA)는 혁신적인 기술력과 시장 지배력을 바탕으로 높은 성장 잠재력을 보유하고 있습니다. 그러나 최근 보도된 엘론 머스크의 잠재적 퇴임 가능성과 그의 정치적 행동이 판매에 미치는 부정적 영향은 투자 결정에 있어 중요한 리스크 요인으로 작용합니다.
#
# **현재 시점에서는 다음과 같은 투자 전략을 권고합니다:**
#
# *   **신중한 접근:** 단기적인 불확실성이 높은 만큼, 신규 투자는 보류하거나 매우 신중하게 접근하는 것이 바람직합니다.
# *   **리스크 관리:** 이미 투자 중인 투자자는 최고 경영자 관련 뉴스와 판매 동향을 면밀히 주시하며, 필요시 리스크 관리 차원의 포트폴리오 조정도 고려해야 합니다.
# *   **장기적 관점의 재평가:** 엘론 머스크의 거취 문제와 그에 따른 기업 전략 변화가 명확해질 때까지는 장기적인 관점에서 기업 가치를 재평가하는 기간이 필요할 것으로 판단됩니다.
#
# **면책 조항:** 본 리포트는 제공된 정보에 기반한 전문 애널리스트의 의견이며, 투자 결정에 대한 최종 책임은 투자자 본인에게 있습니다. 투자를 결정하기 전에 추가적인 시장 조사와 전문가의 조언을 구하는 것을 강력히 권고합니다.
#
#
# ++++++++++ 👑 ORCHESTRATOR AGENT (Turn 5) ++++++++++
# 사용자의 복합 질문을 분석하고, 어떤 전문가 Agent를 호출할지 계획을 세웁니다...
#
# ----- 🚦 ORCHESTRATOR ROUTER -----
# 분기: [generate_report] -> 최종 리포트 생성을 시작합니다.
#
#
# --- 👑 ORCHESTRATOR AGENT ---
# ================================== Ai Message ==================================
#
# 모든 정보 수집 완료
#
#
# ++++++++++ 💎 ORCHESTRATOR REPORTER ++++++++++
# 모든 전문가 Agent의 분석 결과를 종합하여 최종 리포트를 작성합니다...
#
# --- 💎 ORCHESTRATOR REPORTER ---
# ================================== Ai Message ==================================
#
# ## 최고 투자 책임자(CIO) 종합 투자 리포트
#
# **작성일:** 2025년 10월 17일 (각 정보 수집일 기준)
# **대상 포트폴리오:** NVDA, AAPL, TSLA
#
# ---
#
# ### **1. 서론**
#
# 본 리포트는 귀하의 포트폴리오에 포함된 엔비디아(NVDA), 애플(AAPL), 테슬라(TSLA) 세 종목에 대한 최신 주가 현황, 주요 긍정적/부정적 요인 및 잠재적 리스크를 종합적으로 분석하여 투자 전략 수립에 필요한 정보를 제공합니다. 각 종목별 상세 분석 후, 포트폴리오 전반에 대한 종합적인 결론과 투자 제언을 제시합니다.
#
# ---
#
# ### **2. 종목별 분석**
#
# #### **2.1. 엔비디아 (NVIDIA, NVDA)**
#
# *   **현재 주가 (2025년 10월 17일 기준):** $183.22
# *   **애널리스트 평균 목표주가:** $218.51 (현재 주가 대비 약 19.26% 상승 여력)
# *   **종합 투자의견:** 적극 매수
#
# **요약 및 분석:**
# 엔비디아는 AI 및 데이터 센터 GPU 시장에서 독보적인 기술력과 시장 지배력을 가진 선두 기업입니다. 인공지능, 메타버스, 자율주행 등 미래 핵심 기술 분야의 성장과 직접적으로 연관되어 있어 장기적인 성장 잠재력이 매우 높습니다. 대다수의 애널리스트가 '적극 매수' 의견을 제시하며 긍정적인 전망을 내놓고 있습니다.
#
# **부정적 요인 및 리스크:**
# 그러나 과거 그래픽 칩셋 결함 은폐 의혹, 주주들의 사기죄 혐의 소송, 리눅스 드라이버 지원 문제, 리마킹 GPU 논란, 경쟁사 제품 배척 의혹 등 다수의 부정적 사건 및 논란 기록이 존재합니다. 이러한 과거 이슈들은 기업의 평판, 고객 신뢰도, 그리고 잠재적인 규제 및 법적 리스크로 작용할 수 있습니다.
#
# **투자 제언:**
# 엔비디아는 강력한 성장 동력을 가지고 있지만, 과거의 윤리적 및 법적 리스크가 재발하거나 현재 진행 중인 의혹들이 현실화될 경우 기업 가치에 부정적인 영향을 미칠 수 있습니다. 장기적인 관점에서 접근하되, 기업의 투명성 강화 노력과 잠재적 리스크 요인들의 진행 상황을 지속적으로 모니터링하는 신중한 접근이 필요합니다.
#
# #### **2.2. 애플 (Apple Inc., AAPL)**
#
# *   **현재 주가 (2024년 10월 27일 기준):** $271.40
# *   **애널리스트 목표가 (TradingView 기준):** T1 = $275.00, T2 = $285.00
# *   **주요 이벤트:** 2025년 회계연도 4분기 실적 발표 (10월 30일 예정)
#
# **요약 및 분석:**
# 애플 주가는 최근 몇 주간 꾸준히 상승하며 사상 최고치에 근접했습니다. 이는 전문 트레이더들의 긍정적인 시장 심리와 $200선에서의 강력한 지지선에 기반한 것으로 보입니다. 강력한 브랜드 가치와 팬덤을 바탕으로 견고한 시장 위치를 유지하고 있습니다.
#
# **부정적 요인 및 리스크:**
# 중국 시장에서의 압박이 심화되고 있습니다. 중국 경제 둔화 우려, 자국 브랜드 선호도 증가, 중국 정부의 아이폰 사용 규제 등이 애플의 중국 내 성장에 부정적인 영향을 미치고 있습니다. 또한, 관세 부담 증가로 인해 2분기 약 9억 달러의 비용 증가가 예상되는 등 실적에 미치는 영향이 우려됩니다. 연초 대비 주가 수익률(-15.7%)이 나스닥100(+6.5%) 대비 저조한 점도 약점으로 지적됩니다.
#
# **투자 제언:**
# 애플은 견고한 펀더멘털을 가지고 있으나, 중국 시장 불확실성과 관세 부담이 단기적인 주가 변동성을 높일 수 있습니다. 10월 30일 예정된 4분기 실적 발표에서 중국 관련 매출과 마진율 변화를 면밀히 주시해야 합니다. 신규 투자는 실적 발표 이후 불확실성이 해소되거나 조정 시점을 활용하는 것이 현명하며, 기존 투자자는 제시된 손절가를 고려하여 리스크 관리에 만전을 기해야 합니다.
#
# #### **2.3. 테슬라 (Tesla Inc., TSLA)**
#
# *   **현재 주가 (2024년 12월 18일 기준):** $461.51
# *   **52주 최고가:** $488.54 (최고가 근접)
#
# **요약 및 분석:**
# 테슬라는 전기차 시장의 선두 주자로서 혁신적인 기술력과 시장 지배력을 바탕으로 높은 성장 잠재력을 보유하고 있습니다. 최근 주가는 52주 최고가에 근접하는 강세를 보였습니다.
#
# **부정적 요인 및 리스크:**
# 최고 경영자인 엘론 머스크의 잠재적 퇴임 리스크가 주주들의 보상 계획 반대로 인해 제기되고 있습니다. 이는 기업의 리더십 공백과 전략 방향에 대한 큰 불확실성을 초래할 수 있습니다. 또한, 엘론 머스크의 정치적 행동이 테슬라 판매에 부정적인 영향을 미치고 있다는 연구 결과도 있어, 브랜드 이미지와 소비자층 확장에 제약을 줄 수 있습니다.
#
# **투자 제언:**
# 테슬라는 장기적인 성장 동력을 가지고 있지만, 엘론 머스크 관련 리스크가 매우 크며, 이는 단기적인 주가 변동성을 확대시키고 장기적인 기업 안정성에 대한 우려를 낳을 수 있습니다. 신규 투자는 불확실성이 높은 만큼 보류하거나 매우 신중하게 접근해야 합니다. 기존 투자자는 최고 경영자 거취 관련 뉴스와 판매 동향을 면밀히 주시하며, 필요시 리스크 관리 차원의 포트폴리오 조정을 고려해야 합니다.
#
# ---
#
# ### **3. 종합 결론 및 투자 전략**
#
# 귀하의 포트폴리오는 현재 기술 혁신을 주도하는 세 거대 기업으로 구성되어 있어 높은 성장 잠재력을 내포하고 있습니다. 그러나 각 종목이 가진 고유한 리스크 요인들을 면밀히 인지하고 관리하는 것이 중요합니다.
#
# *   **성장 동력은 강력하나, 개별 리스크가 뚜렷함:**
#     *   **NVDA:** AI 시대의 핵심 기업으로 강력한 성장 모멘텀을 가졌으나, 과거의 윤리적/법적 이슈가 잠재적 리스크로 남아있습니다.
#     *   **AAPL:** 견고한 브랜드 파워와 시장 지지력을 보이지만, 중국 시장의 역풍과 관세 부담이 단기 실적에 영향을 미칠 수 있습니다.
#     *   **TSLA:** 전기차 시장의 선두주자로서 혁신성을 인정받지만, 엘론 머스크 개인의 리스크가 기업 가치에 큰 불확실성을 더하고 있습니다.
#
# *   **포트폴리오 전반의 리스크 관리:**
#     현재 포트폴리오의 세 종목 모두 각기 다른 형태의 중대한 리스크를 안고 있습니다. 특히 애플과 테슬라는 단기적인 불확실성(실적 발표, CEO 리스크)이 큰 상황입니다.
#
# **최종 투자 전략 제언:**
#
# 1.  **지속적인 모니터링:** 각 기업의 실적 발표, 리스크 요인(법적 분쟁, 규제, CEO 관련 뉴스, 시장 동향)의 진행 상황을 면밀히 주시해야 합니다.
# 2.  **리스크 조정:** 현재 포트폴리오가 높은 성장 잠재력과 함께 상당한 개별 리스크를 포함하고 있으므로, 각 종목의 비중을 재검토하여 리스크 허용 범위 내에서 조정하는 것을 고려해야 합니다. 특히 테슬라와 애플은 단기 불확실성이 해소될 때까지 보수적인 접근이 필요합니다.
# 3.  **다각화 고려:** 현재 포트폴리오가 기술주에 집중되어 있어 특정 산업 또는 거시 경제 변화에 취약할 수 있습니다. 장기적인 관점에서 포트폴리오의 안정성을 높이기 위해 다른 산업 섹터나 자산군으로의 다각화를 점진적으로 고려하는 것이 바람직합니다.
# 4.  **장기적 관점 유지:** 세 기업 모두 혁신성과 시장 지배력을 바탕으로 장기적인 성장 가능성이 높습니다. 단기적인 시장 변동성과 리스크에 일희일비하기보다는, 기업의 본질적인 가치와 장기 성장 동력을 믿고 꾸준히 투자하되, 앞서 언급된 리스크 요인들이 기업의 펀더멘털을 훼손하는지 여부를 지속적으로 평가해야 합니다.
#
# 본 리포트는 제공된 정보를 바탕으로 한 종합적인 분석이며, 투자 결정은 투자자 본인의 판단과 책임 하에 이루어져야 합니다. 추가적인 시장 조사와 전문가의 조언을 구하는 것을 권고합니다.
#
# ✅ Orchestrator 실행이 완료되었습니다.

# %%
# !lsof -ti tcp:8000 | xargs -r kill; echo "✅ 금융 정보 MCP Server shutdown complete"
# !lsof -ti tcp:8001 | xargs -r kill; echo "✅ 포트폴리오 MCP Server shutdown complete"
# Out:
# ✅ 금융 정보 MCP Server shutdown complete
# ✅ 포트폴리오 MCP Server shutdown complete
