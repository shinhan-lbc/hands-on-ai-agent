# %% [markdown]
# # ⚙️ 환경 설정 및 라이브러리 설치
#
# 프로젝트 실행에 필요한 파이썬 라이브러리들을 설치합니다. 각 라이브러리의 역할은 다음과 같습니다.
#
#   * **`langchain`, `langgraph`, `langchain-community`**: LangChain 및 LangGraph의 핵심 기능을 사용하기 위한 라이브러리입니다.
#   * **`langchain-google-genai`**: Google Gemini와 같은 생성형 AI 모델을 LangChain과 연동합니다.
#   * **`tavily-python`**: 실시간 정보 검색을 위한 Tavily 검색 도구를 추가합니다.
#   * **`langchain-mcp-adapters`**: 특정 어댑터(MCP)를 사용하기 위해 필요합니다.
#
# 아래 셀을 실행하여 모든 라이브러리를 한 번에 설치하세요.

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
# !pip install langchain==0.3.27 langgraph==0.6.6 langchain-google-genai==2.1.9 langchain-community==0.3.27 langchain-mcp-adapters==0.1.9 tavily-python==0.7.11
# Out:
# Requirement already satisfied: langchain==0.3.27 in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Requirement already satisfied: langgraph==0.6.6 in /usr/local/lib/python3.12/dist-packages (0.6.6)
# Requirement already satisfied: langchain-google-genai==2.1.9 in /usr/local/lib/python3.12/dist-packages (2.1.9)
# Requirement already satisfied: langchain-community==0.3.27 in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Requirement already satisfied: langchain-mcp-adapters==0.1.9 in /usr/local/lib/python3.12/dist-packages (0.1.9)
# Requirement already satisfied: tavily-python==0.7.11 in /usr/local/lib/python3.12/dist-packages (0.7.11)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (0.3.79)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (0.4.38)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (2.11.10)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (2.0.44)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.27) (6.0.3)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph==0.6.6) (2.1.2)
# Requirement already satisfied: langgraph-prebuilt<0.7.0,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from langgraph==0.6.6) (0.6.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from langgraph==0.6.6) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph==0.6.6) (3.6.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai==2.1.9) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.18 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai==2.1.9) (0.6.18)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community==0.3.27) (3.13.1)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community==0.3.27) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community==0.3.27) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community==0.3.27) (2.11.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community==0.3.27) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community==0.3.27) (2.0.2)
# Requirement already satisfied: mcp>=1.9.2 in /usr/local/lib/python3.12/dist-packages (from langchain-mcp-adapters==0.1.9) (1.19.0)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from langchain-mcp-adapters==0.1.9) (4.15.0)
# Requirement already satisfied: tiktoken>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tavily-python==0.7.11) (0.12.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from tavily-python==0.7.11) (0.28.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.27) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.27) (0.9.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (2.28.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (5.29.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain==0.3.27) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain==0.3.27) (25.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph==0.6.6) (1.11.0)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph==0.6.6) (3.11.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->tavily-python==0.7.11) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx->tavily-python==0.7.11) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->tavily-python==0.7.11) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx->tavily-python==0.7.11) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->tavily-python==0.7.11) (0.16.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain==0.3.27) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain==0.3.27) (0.25.0)
# Requirement already satisfied: jsonschema>=4.20.0 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (4.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (0.49.1)
# Requirement already satisfied: uvicorn>=0.31.1 in /usr/local/lib/python3.12/dist-packages (from mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (0.38.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.27) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.27) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.27) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.27) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain==0.3.27) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain==0.3.27) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.3.27) (3.2.4)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.5.1->tavily-python==0.7.11) (2024.11.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx->tavily-python==0.7.11) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (1.71.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (4.9.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain==0.3.27) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (0.28.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.27) (1.1.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.31.1->mcp>=1.9.2->langchain-mcp-adapters==0.1.9) (8.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (0.6.1)

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
import os
import time
import textwrap
from pprint import pprint
from typing import Dict, Any

from IPython.display import display, HTML
from langchain_core.messages import HumanMessage, BaseMessage

# ----------------------------------------------------
# ### ⚙️ 1. MCP 서버 관리 공통 함수 ###
# ----------------------------------------------------

def start_mcp_server(script_name: str, port: int, log_file: str, service_name: str) -> bool:
    """
    공통 MCP 서버 시작 및 확인 함수

    Args:
        script_name: 실행할 Python 스크립트 파일명 (예: "search_server.py")
        port: 사용할 포트 번호 (예: 8000)
        log_file: 저장할 로그 파일명 (예: "search_server.log")
        service_name: 로그 출력 시 사용할 서비스 이름 (예: "금융 정보")
    """
    print(f"🚀 {service_name} MCP 서버를 시작합니다... (Port: {port})")

    # 포트를 사용하는 기존 프로세스 종료 및 새 서버 시작
    server_command = (
        f"lsof -ti tcp:{port} | xargs -r kill; "  # 기존 프로세스 종료
        f"rm -f {log_file}; "                       # 이전 로그 파일 삭제
        f"nohup python -u {script_name} > {log_file} 2>&1 &"  # 백그라운드 실행
    )
    os.system(server_command)

    # --- 서버 로그 파일 확인 및 상태 출력 ---
    timeout_seconds = 30  # 최대 대기 시간 (초)
    check_interval = 2   # 로그 확인 주기 (초)
    start_time = time.time()
    server_status = "PENDING"
    log_content = ""

    print(f"⏱️  서버 시작 대기 중... (최대 {timeout_seconds}초)")

    while time.time() - start_time < timeout_seconds:
        try:
            with open(log_file, 'r') as f:
                log_content = f.read()

            log_content_lower = log_content.lower()

            # 성공 조건 확인
            if "uvicorn running on" in log_content_lower and "application startup complete" in log_content_lower:
                server_status = "SUCCESS"
                break
            # 실패 조건 확인
            if "traceback" in log_content_lower or "error" in log_content_lower:
                server_status = "FAILED"
                break

            time.sleep(check_interval)

        except FileNotFoundError:
            time.sleep(check_interval)
        except Exception as e:
            print(f"로그 파일 읽기 중 예외 발생: {e}")
            log_content = f"로그 파일 읽기 오류: {e}"
            server_status = "FAILED"
            break

    # --- 최종 결과 출력 ---
    print("-" * 30)
    if server_status == "SUCCESS":
        print(f"✅ {service_name} MCP 서버가 성공적으로 시작되어 실행 중입니다.")
        print(f"   (로그 파일: {os.getcwd()}/{log_file})")
        return server_status
    elif server_status == "FAILED":
        print(f"❌ {service_name} 서버 실행 중 오류가 발생했습니다. 아래 로그를 확인하세요.")
        print("-" * 20)
        print(log_content)
        print("-" * 20)
    else: # PENDING (Timeout)
        print(f"🤔 {timeout_seconds}초 내에 {service_name} 서버 시작 메시지를 확인하지 못했습니다.")
        print("\n   [현재 로그 파일 내용]")
        print("-" * 20)
        print(log_content if log_content else "[로그 파일 비어 있거나 생성되지 않았습니다]")
        print("-" * 20)

    return server_status

def stop_mcp_server(port: int, service_name: str):
    """지정된 포트의 MCP 서버를 종료합니다."""
    print(f"\n🛑 {service_name} MCP 서버(Port: {port})를 종료합니다...")
    os.system(f"lsof -ti tcp:{port} | xargs -r kill")
    print(f"✅ {service_name} 서버가 종료되었습니다.")

# ----------------------------------------------------
# ### 📊 2. Mermaid 그래프 시각화 공통 함수 ###
# ----------------------------------------------------

def display_mermaid_graph(app: Any, title: str = "Agent 워크플로우"):
    """
    컴파일된 LangGraph app의 Mermaid 다이어그램을 Colab에 시각화합니다.

    Args:
        app: LangGraph.compile()로 생성된 실행 가능한 객체
        title: 다이어그램 위에 표시할 제목
    """
    print(f"\n📊 [ {title} ]")

    # 1. app 객체에서 Mermaid 다이어그램 문법(텍스트)을 생성합니다.
    mermaid_syntax = app.get_graph().draw_mermaid()

    # 2. 이 Mermaid 텍스트를 HTML과 Javascript로 감싸서 렌더링할 준비를 합니다.
    html_code = f"""
    <div style="background-color: white; border: 1px solid #ddd; padding: 10px; border-radius: 5px;">
        <pre class="mermaid">{textwrap.dedent(mermaid_syntax)}</pre>
    </div>
    <script type="module">
        import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.esm.min.mjs';
        await mermaid.run();
    </script>
    """

    # 3. Colab/Jupyter 환경에서 HTML 코드를 실행하여 다이어그램을 출력합니다.
    display(HTML(html_code))
    print()

# %% [markdown]
# # API 키 설정 가이드
#
# API를 사용하기 위한 키 설정 방법을 안내합니다. 각 서비스별로 아래 절차를 따라주세요.
#
# <br>
#
# ## ✨ Gemini API 키 설정
#
# 1.  **API 키 발급받기**
#     Gemini API를 사용하려면 먼저 API 키가 필요합니다. Google AI Studio에서 클릭 한 번으로 간편하게 키를 생성하세요.
#
#     <a class="button button-primary" href="https://makersuite.google.com/app/apikey" target="_blank" rel="noopener noreferrer">API 키 받기</a>
#
# 2.  **Colab에 키 저장하기**
#     Colab의 왼쪽 패널에서 "🔑" 아이콘(보안 비밀)을 열어, 발급받은 키를 **`GOOGLE_API_KEY`** 라는 이름으로 저장하세요.
#
# 3.  **코드에서 키 사용하기**
#     SDK는 **환경 변수**로 저장된 키를 자동으로 인식하여 사용합니다. Colab 보안 비밀에 저장한 키는 아래와 같이 불러올 수 있습니다.
#
#     ```python
#     # SDK가 자동으로 키를 인식합니다
#     os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")
#     ```
#
# <br>
#
# ## 🔍 Tavily API 키 설정
#
# 1.  **API 키 발급받기**
#     Tavily 검색 API를 사용하려면 API 키를 발급받아야 합니다. Tavily 대시보드에서 키를 생성하고 복사하세요.
#
#     <a class="button button-primary" href="https://app.tavily.com" target="_blank" rel="noopener noreferrer">Tavily API 키 받기</a>
#
#     > ✅ **참고:** Tavily는 무료 플랜을 제공하여 간단한 테스트나 소규모 프로젝트를 부담 없이 시작할 수 있습니다.
#
# 2.  **Colab에 키 저장하기**
#     Colab의 "🔑" 아이콘(보안 비밀)을 열어, 발급받은 키를 **`TAVILY_API_KEY`** 라는 이름으로 저장하세요.
#
# 3.  **코드에서 키 사용하기**
#     Tavily SDK 역시 **환경 변수**로 저장된 키를 자동으로 찾아 사용합니다.
#
#     ```python
#     # SDK가 자동으로 키를 인식합니다
#     os.environ["TAVILY_API_KEY"] = userdata.get("TAVILY_API_KEY")
#     ```

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
import os
from google.colab import userdata

# Gemini API 키 설정
os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

# Tavily API 키 설정
os.environ["TAVILY_API_KEY"] = userdata.get("TAVILY_API_KEY")

print("API 키 설정이 완료되었습니다.")
# Out:
# API 키 설정이 완료되었습니다.

# %% [markdown]
# # 🔍 검색 도구(Tavily) 정의 및 테스트
#
# 이 단계에서는 **Tavily 검색 API**를 사용하는 LangChain 검색 도구를 정의하고, 정상적으로 작동하는지 테스트합니다.<br>
# Tavily 도구는 Agent가 외부 최신 정보에 접근해야 할 때 사용됩니다.
#
#   * **도구 정의**: `TavilySearchResults`를 가져와 `search_tool`이라는 이름의 도구를 생성합니다.
#   * **결과 수 제한**: `max_results=3` 파라미터를 설정하여, 검색 시 최대 3개의 관련성 높은 결과만 반환하도록 제한합니다.
#   * **테스트 실행**: `"삼성전자 현재 주가"`와 같은 실제 검색어를 입력하여 도구가 외부 정보를 잘 가져오는지 확인합니다.

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from pprint import pprint

# Tavily 검색 도구를 정의하고, 반환 결과의 수를 3개로 제한합니다.
search_tool = TavilySearchResults(max_results=3)

# 정의된 도구가 잘 작동하는지 'invoke'를 통해 테스트합니다.
results = search_tool.invoke({"query": "삼성전자 현재 주가"})
pprint(results)
# Out:
# [{'content': 'PLTR\n'
#              '\n'
#              '+3.04%\n'
#              '\n'
#              '## 자주 묻는 질문\n'
#              '\n'
#              '### 오늘 삼성전자 (005930)의 주가는?\n'
#              '\n'
#              '오늘 삼성전자 주가는 107,500입니다.\n'
#              '\n'
#              '### 삼성전자은(는) 어떤 증권 거래소에서 거래되나요?\n'
#              '\n'
#              '삼성전자은(는) 서울 증권 거래소 증권 거래소에 상장되어 거래되고 있습니다.\n'
#              '\n'
#              '### 삼성전자의 주식 티커는?\n'
#              '\n'
#              '삼성전자의 주식 티커는 “005930”입니다.\n'
#              '\n'
#              '### 삼성전자은(는) 배당을 지급하나요? 현재 배당수익률은 얼마인가요?\n'
#              '\n'
#              '삼성전자 배당수익률은 1.38%입니다.\n'
#              '\n'
#              '### 삼성전자 시가총액은 얼마인가요?\n'
#              '\n'
#              '오늘 현재 삼성전자 시가총액은 700.06T입니다.\n'
#              '\n'
#              '### 삼성전자의 주당순이익(TTM)은 얼마인가요?\n'
#              '\n'
#              '삼성전자의 EPS(TTM)는 4,606.36입니다.\n'
#              '\n'
#              '### 삼성전자의 다음 실적 발표일은 언제인가요?\n'
#              '\n'
#              '삼성전자은(는) 2026년 1월 28일에 다음 실적 보고서를 발표할 예정입니다.\n'
#              '\n'
#              '### 삼성전자에는 몇 명의 직원이 있나요? [...] 삼성전자의 직원은 128735명입니다.\n'
#              '\n'
#              '### 삼성전자(005930)의 현재 거래는 어떤가요?\n'
#              '\n'
#              '2025년 10월 31일 기준, 삼성전자(005930)은(는) 107,500 가격에 거래되고 있으며 이전 종가는 '
#              '104,100.00입니다. 일간 범위는 103,300~108,600이고, 52주 범위는 '
#              '49,900~108,600입니다.\n'
#              '\n'
#              '### 삼성전자(005930)의 애널리스트 목표주가는 얼마인가요?\n'
#              '\n'
#              '삼성전자의 12개월 목표주가 평균은 KRW112219.64706입니다. 목표주가 최고치 KRW150000, 최저치는 '
#              'KRW58500입니다. 29명의 애널리스트는 매수 의견, 1명은 매도 의견을 제시했으며, 전반적인 투자의견 등급은 '
#              '매수입니다. 이 주식은 +4.39% 상승 여력 있음 잠재력이 있습니다.\n'
#              '\n'
#              '주식 중개업체(브로커) 찾기\n'
#              '\n'
#              '1일\n'
#              '\n'
#              '1주\n'
#              '\n'
#              '1달\n'
#              '\n'
#              '6달\n'
#              '\n'
#              '1년\n'
#              '\n'
#              '5년\n'
#              '\n'
#              '최대\n'
#              '\n'
#              '코스피지수\n'
#              '\n'
#              '4,107.50\n'
#              '\n'
#              '+20.61\n'
#              '\n'
#              '+0.50%\n'
#              '\n'
#              '코스피200 선물 (F) (F)") [...] 적극 매수\n'
#              '\n'
#              '적극 매도\n'
#              '\n'
#              '매도\n'
#              '\n'
#              '중립\n'
#              '\n'
#              '매수\n'
#              '\n'
#              '적극 매수\n'
#              '\n'
#              '애널리스트 센티멘트\n'
#              '\n'
#              '매수\n'
#              '\n'
#              '목표 주가 \n'
#              '\n'
#              '112,220\n'
#              '\n'
#              '상승 여력 있음\n'
#              '\n'
#              '+4.39%\n'
#              '\n'
#              '유저들의 센티멘트\n'
#              '\n'
#              '하락\n'
#              '\n'
#              '상승\n'
#              '\n'
#              'ProTips\n'
#              '\n'
#              '복잡한 금융 데이터를 간결하고 실행 가능한 투자 통찰력으로 추출하는 팁.\n'
#              '\n'
#              '16개 모두 확인\n'
#              '\n'
#              '대차대조표에 부채보다 현금을 더 많이 보유하고 있음\n'
#              '\n'
#              '적정가치\n'
#              '\n'
#              '현금흐름 할인법, 동종업계 밸류에이션 멀티플, 배당할인모형 등 가치평가 모형을 기반으로 산출한 주식의 실제 가격 '
#              '추정치입니다.\n'
#              '\n'
#              '가치 공개\n'
#              '\n'
#              '금일 변동\n'
#              '\n'
#              '103,300108,600\n'
#              '\n'
#              '52주 변동폭\n'
#              '\n'
#              '49,900108,600\n'
#              '\n'
#              '주요 통계\n'
#              '\n'
#              '편집하기\n'
#              '\n'
#              '005930의 지표 더 보기\n'
#              '\n'
#              '매수/매도\n'
#              ':   107,500.00 / 107,600.00\n'
#              '\n'
#              '전일 종가\n'
#              ':   104,100\n'
#              '\n'
#              '금일 시가\n'
#              ':   105,000\n'
#              '\n'
#              '금일 변동\n'
#              ':   103,300-108,600\n'
#              '\n'
#              '52주 변동폭\n'
#              ':   49,900-108,600',
#   'score': 0.90102744,
#   'title': '삼성전자 (005930) - 인베스팅닷컴',
#   'url': 'https://kr.investing.com/equities/samsung-electronics-co-ltd'},
#  {'content': '메인 메뉴로 바로가기 본문으로 바로가기\n'
#              '\n'
#              '# 네이버 페이 증권\n'
#              '\n'
#              ' 증권 홈\n'
#              ' 국내증시선택됨\n'
#              ' 해외증시\n'
#              ' 시장지표\n'
#              ' 리서치\n'
#              ' 뉴스\n'
#              ' MY\n'
#              '\n'
#              '종목 시세 정보\n'
#              ':   2025년 10월 30일 14시 03분 기준 장중\n'
#              ':   종목명 삼성전자\n'
#              ':   종목코드 005930 코스피\n'
#              ':   현재가 103,800 전일대비 상승 3,300 플러스 3.28 퍼센트\n'
#              ':   전일가 100,500\n'
#              ':   시가 102,400\n'
#              ':   고가 105,800\n'
#              ':   상한가 130,600\n'
#              ':   저가 102,000\n'
#              ':   하한가 70,400\n'
#              ':   거래량 28,805,126\n'
#              ':   거래대금 2,992,087백만\n'
#              '\n'
#              '## 삼성전자\n'
#              '\n'
#              '005930 날짜  2025.10.30 14:03 기준(KRX 장중)   실시간   기업개요\n'
#              '\n'
#              '#### 기업개요\n'
#              '\n'
#              '동사는 1969년 설립된 글로벌 전자 기업이며, DX 부문 9개, DS 부문 5개 해외 지역총괄과 230개 '
#              '종속기업으로 구성되어 있음. [...] 넥스트레이드(NXT)\n'
#              '\n'
#              '넥스트레이드(NXT) 넥스트레이드(NXT)란 대한민국 최초의 대체거래소(ATS, Alternative Trading '
#              'System)입니다.\n'
#              '\n'
#              '삼성전자\n'
#              ':   오늘의시세 103,800 포인트\n'
#              ':   3,300 포인트 상승\n'
#              ':   3.28% 플러스\n'
#              '\n'
#              '103,800 103,800\n'
#              '\n'
#              '전일대비  상승 3,300 3,300  l  + 3.28 3.28 %\n'
#              '\n'
#              '주요 시세\n'
#              '\n'
#              '     | 전일  100,500 100,500 | 고가  105,800105,800  (상한가  '
#              '130,600130,600  ) | 거래량  28,805,126 28,805,126 |\n'
#              '| 시가  102,400102,400 | 저가  102,000102,000  (하한가  70,400  ) | '
#              '거래대금  2,992,087 2,992,087  백만 |\n'
#              '\n'
#              '삼성전자\n'
#              ':   오늘의시세 103,750 포인트\n'
#              ':   3,250 포인트 상승\n'
#              ':   3.23% 플러스\n'
#              '\n'
#              '103,750 103,750 [...] | 종목명 | 삼성전자\\005930 | SK하이닉스\\000660 | '
#              '한미반도체\\042700 | 리노공업058470 | 원익IPS\\240810 |\n'
#              '| 현재가 | 103,800 | 570,000 | 142,100 | 57,800 | 64,600 |\n'
#              '| 전일대비 | 상향 3,300 | 상향 12,000 | 상향 3,900 | 하향 600 | 하향 1,200 |\n'
#              '| 등락률 | 상향 +3.28% | 상향 +2.15% | 상향 +2.82% | 하향 -1.03% | 하향 '
#              '-1.82% |\n'
#              '| 시가총액(억) | 6,144,584 | 4,149,613 | 135,438 | 44,050 | 31,708 |\n'
#              '| 외국인비율(%) | 52.26 | 54.60 | 7.75 | 34.42 | 27.07 |\n'
#              '| 매출액(억) | 745,663 | 222,320 | 1,800 | 1,125 | 2,422 |\n'
#              '| 영업이익(억) | 46,761 | 92,129 | 863 | 534 | 365 |',
#   'score': 0.87166095,
#   'title': '삼성전자(005930) - 네이버 금융 - NAVER',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005930'},
#  {'content': '일정 부분의 회사 소유권 및 보유한 주식 수에 해당하는 회사 자산과 이익의 지분을 주장할 권리입니다.\n'
#              '\n'
#              'KR에 본사 소재\n'
#              '\n'
#              '대한민국 경기도 수원시에 본사가 있습니다.\n'
#              '\n'
#              '전일 종가\n'
#              '\n'
#              '전일 마감 종가입니다.\n'
#              '\n'
#              '₩69,600.00\n'
#              '\n'
#              '일일 변동폭\n'
#              '\n'
#              '전일 최고가와 최저가 사이의 범위입니다.\n'
#              '\n'
#              '₩69,700.00 - ₩70,500.00\n'
#              '\n'
#              '52주 변동폭\n'
#              '\n'
#              '지난 52주 동안 최고가와 최저가 사이의 범위입니다.\n'
#              '\n'
#              '₩49,900.00 - ₩75,000.00\n'
#              '\n'
#              '시가총액\n'
#              '\n'
#              '회사의 주가와 총 발행 주식 수를 곱한 평가 방법입니다.\n'
#              '\n'
#              '465.68조 KRW\n'
#              '\n'
#              '평균 거래량\n'
#              '\n'
#              '지난 30일 동안 매일 거래된 평균 주식 수입니다.\n'
#              '\n'
#              '1,743.06만\n'
#              '\n'
#              '주가수익률\n'
#              '\n'
#              '현재 주가 대 12개월 후행 EPS의 비율로서 주가가 다른 주식과 비교하여 높거나 낮은지 나타냅니다.\n'
#              '\n'
#              '15.54\n'
#              '\n'
#              '배당수익률\n'
#              '\n'
#              '연간 배당금 대 현재 주가의 비율로서 주식의 배당수익을 추정합니다.\n'
#              '\n'
#              '2.09%\n'
#              '\n'
#              '정보\n'
#              '\n'
#              '\ue316\n'
#              '\ue313',
#   'score': 0.8386933,
#   'title': '삼성전자(005930) 주가 및 뉴스 - Google Finance',
#   'url': 'https://www.google.com/finance/quote/005930:KRX?hl=ko&ref=thepickool.com'}]

# %% [markdown]
# # 🤖 Agent 설정 및 상태(State) 정의
#
# Agent의 핵심 구성 요소를 설정합니다.<br>
# Agent의 **'두뇌'** 역할을 하는 LLM(거대 언어 모델)과, 작업 흐름 전반에 걸쳐 정보를 저장하고 공유하는 **'메모리'** 역할의 상태(State)를 정의합니다.
#
#   * **LLM (두뇌) 설정** : Agent의 추론과 판단을 담당할 언어 모델로 Google의 `gemini-2.0-flash-lite`를 설정합니다. 이 모델은 빠른 응답 속도와 우수한 성능을 균형 있게 제공합니다.
#   * **AgentState (메모리) 정의** : Agent가 각 단계를 거치며 얻는 정보를 저장하고 공유할 데이터 구조인 `AgentState`를 정의합니다. LangGraph에서는 이 **상태(State)** 객체를 통해 각 노드(작업 단위)가 정보를 주고받습니다.

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph, END
from typing import TypedDict, List

# 1. Agent의 '두뇌' 역할을 할 LLM을 설정합니다.
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash-lite")

# 2. Agent의 작업 내용을 기억하고 공유할 '메모리' 구조(State)를 정의합니다.
class AgentState(TypedDict):
    """
    Agent의 상태를 정의합니다. 모든 노드는 이 상태를 공유하며 정보를 업데이트합니다.

    Attributes:
        company_name: 분석할 회사의 이름 (사용자 입력)
        stock_price: 검색된 주가 정보
        news: 검색된 관련 뉴스 목록
    """
    company_name: str
    stock_price: str
    news: List[str]

# %% [markdown]
# # 🧩 Agent 작업 노드(Node) 함수 정의
#
# Agent 워크플로우를 구성하는 각 노드(Node)의 실제 동작을 함수로 정의합니다.<br>
# 각 함수는 **`AgentState`** 를 입력받아 특정 작업을 수행하고, 그 결과를 다시 **`AgentState`** 에 저장하거나 최종 결과를 생성하는 역할을 합니다.
#
#   * **`stock_price_search_node`** : `AgentState`에서 **회사 이름**을 가져와 **주가**를 검색하고, 결과를 상태에 업데이트합니다.
#   * **`news_search_node`** : `AgentState`에서 **회사 이름**을 가져와 **최신 뉴스 3개**를 검색하고, 결과를 상태에 업데이트합니다.
#   * **`analysis_node`** : 모든 정보가 채워진 `AgentState`를 기반으로, **LLM에게 전달할 상세 프롬프트**를 생성합니다. LLM은 이 프롬프트를 바탕으로 최종 분석 리포트를 생성하며, 이 노드는 상태를 추가로 업데이트하지 않고 리포트를 출력하는 것으로 작업을 마칩니다.

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
def stock_price_search_node(state: AgentState):
    """주어진 회사 이름으로 현재 주가를 검색하는 노드"""
    print("--- (1/3) 주가 정보 검색 중... ---")
    company_name = state["company_name"]

    # Tavily 도구를 사용하여 주가 정보 검색
    stock_price = search_tool.invoke({"query": f"{company_name} 현재 주가"})
    return {"stock_price": stock_price}

def news_search_node(state: AgentState):
    """주어진 회사 이름으로 최신 뉴스를 검색하는 노드"""
    print("--- (2/3) 관련 뉴스 검색 중... ---")
    company_name = state["company_name"]

    # Tavily 도구를 사용하여 최신 뉴스 3개 검색
    news = search_tool.invoke({"query": f"{company_name} 최신 주요 뉴스 3개"})
    return {"news": news}

def analysis_node(state: AgentState):
    """수집된 정보를 바탕으로 종합 분석 리포트를 생성하는 노드"""
    print("--- (3/3) 종합 분석 리포트 생성 중... ---")
    company_name = state["company_name"]
    stock_price = state["stock_price"]
    news = state["news"]

    # Gemini LLM에게 전달할 프롬프트(지시문) 작성
    prompt = f"""
    당신은 전문 주식 애널리스트입니다. 다음 정보를 바탕으로 '{company_name}'에 대한 투자 분석 리포트를 작성해주세요.

    **[분석 정보]**
    1. **현재 주가**: {stock_price}
    2. **관련 최신 뉴스**: {news}

    **[리포트 작성 가이드라인]**
    - **개요**: 현재 상황을 간결하게 요약합니다.
    - **긍정적 요인**: 주가에 긍정적인 영향을 줄 수 있는 요소를 뉴스 내용에 기반하여 분석합니다.
    - **부정적 요인**: 주가에 부정적인 영향을 줄 수 있는 요소를 뉴스 내용에 기반하여 분석합니다.
    - **종합 의견 및 투자 전략**: 위 내용을 종합하여 최종 투자 의견과 간단한 전략을 제시해주세요. 전문가적이지만 이해하기 쉬운 톤으로 작성해주세요.

    **주의**: 이 리포트는 정보 제공 및 교육적 목적으로 작성되었으며, 실제 투자 권유가 아님을 반드시 명시해주세요.
    """

    # LLM을 호출하여 분석 리포트 생성
    response = llm.invoke(prompt)

    print("\n\n[AI 주식 분석 리포트]")
    print(response.content)
    print("\n")

    # 이 노드는 최종 출력을 담당하므로 state를 추가로 업데이트하지 않음
    return

# %% [markdown]
# # ⛓️ Agent 워크플로우 그래프 생성 및 실행
#
# 앞서 정의한 **노드(Node)** 함수들을 **LangGraph**를 사용하여 연결하고, 실행 가능한 **Agent**를 완성합니다.<br>
# 전체 과정은 **그래프 정의 → 컴파일 및 시각화 → 실행**의 3단계로 진행됩니다.
#
# <br>
#
# ### 1\. 워크플로우 정의
#
# 먼저 `StateGraph` 객체를 생성하고, `add_node`를 이용해 각 작업 함수를 노드로 추가합니다.<br>
# 그 후, `set_entry_point`로 시작 노드를 지정하고, `add_edge`로 노드들을 **주가 검색 → 뉴스 검색 → 분석** 순서로 연결하여 순차적인 워크플로우를 만듭니다.
#
# > ```python
# > # 노드 실행 순서를 정의합니다.
# > workflow.set_entry_point("stock_price_search")
# > workflow.add_edge("stock_price_search", "news_search")
# > workflow.add_edge("news_search", "analysis")
# > workflow.add_edge("analysis", END)
# > ```
#
# <br>
#
# ### 2\. 그래프 컴파일
#
# 정의된 워크플로우를 `compile()` 메서드를 통해 실행 가능한 애플리케이션(`app`)으로 만듭니다.
#
# > ```python
# > # 그래프를 실행 가능한 app으로 컴파일합니다.
# > app = workflow.compile()
# > ```
#
# <br>
#
# ### 3\. Agent 실행 및 결과 확인
#
# 컴파일된 `app`에 분석할 회사 이름을 입력하여 Agent를 실행합니다.<br>
# `app.stream()`을 사용하면 각 노드가 실행될 때마다 중간 결과와 상태 변화를 실시간으로 확인할 수 있어, Agent의 작동 과정을 단계별로 추적하는 데 유용합니다.
#
# > ```python
# > # app.stream()을 통해 각 단계의 실행 과정을 실시간으로 확인합니다.
# > for event in app.stream(inputs):
# >     ...
# > ```

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
## 1. 워크플로우 정의
# 그래프의 상태(State)는 AgentState로 정의합니다.
workflow = StateGraph(AgentState)

# 1) 정의한 함수들을 노드로 추가합니다.
workflow.add_node("stock_price_search", stock_price_search_node)
workflow.add_node("news_search", news_search_node)
workflow.add_node("analysis", analysis_node)

# 2) 노드 실행 순서를 정의합니다. (A -> B -> C -> 종료)
workflow.set_entry_point("stock_price_search") # 시작점
workflow.add_edge("stock_price_search", "news_search")
workflow.add_edge("news_search", "analysis")
workflow.add_edge("analysis", END) # 'analysis' 노드 실행 후 워크플로우를 종료합니다.

## 2. 그래프 컴파일 및 시각화
# 1) 그래프를 실행 가능한 app으로 컴파일합니다.
app = workflow.compile()

## 2) 공통 함수를 사용하여 그래프를 시각화합니다.
display_mermaid_graph(app, title="순차적 주식 분석 워크플로우")

## 3. Agent 실행 및 결과 확인
# 1) Agent에게 전달할 초기 입력값입니다.
inputs = {"company_name": "삼성전자"}

# 2) app.stream()을 통해 각 단계의 실행 과정을 실시간으로 확인합니다.
for event in app.stream(inputs):
    pass
# Out:
# 📊 [ 순차적 주식 분석 워크플로우 ]
#     <div style="background-color: white; border: 1px solid #ddd; padding: 10px; border-radius: 5px;">
#         <pre class="mermaid">---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	stock_price_search(stock_price_search)
# 	news_search(news_search)
# 	analysis(analysis)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> stock_price_search;
# 	news_search --> analysis;
# 	stock_price_search --> news_search;
# 	analysis --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
# </pre>
#     </div>
#     <script type="module">
#         import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.esm.min.mjs';
#         await mermaid.run();
#     </script>
# --- (1/3) 주가 정보 검색 중... ---
# --- (2/3) 관련 뉴스 검색 중... ---
# --- (3/3) 종합 분석 리포트 생성 중... ---
#
#
# [AI 주식 분석 리포트]
# ## 삼성전자 (005930) 투자 분석 리포트
#
# **[개요]**
#
# 삼성전자 (005930)는 현재 107,500원에 거래되고 있으며, 배당수익률은 1.38%입니다. 최근 주가는 상승세를 보이며, 12개월 목표주가는 112,220원으로 제시되고 있습니다. 긍정적인 애널리스트 의견이 다수 존재하며, 2026년 1월 28일에 다음 실적 발표가 예정되어 있습니다. 최근 뉴스에서는 엔비디아와의 협력을 통한 '반도체 AI 팩토리' 구축, 3분기 실적 발표, 14년 연속 '동반성장지수' 최우수 획득 등 다양한 소식이 전해지고 있습니다.
#
# **[긍정적 요인]**
#
# *   **AI 반도체 시장 성장 기대**: 삼성전자는 엔비디아와의 협력을 통해 '반도체 AI 팩토리'를 구축하며, AI 시장 성장에 발맞춰 관련 기술 경쟁력을 강화하고 있습니다. 이는 메모리 반도체 및 시스템 반도체 분야에서 긍정적인 영향을 미칠 것으로 예상됩니다.
# *   **견조한 실적**: 삼성전자는 2025년 3분기 실적 발표를 앞두고 있으며, 시장의 기대에 부응하는 실적을 발표할 경우 주가 상승의 모멘텀으로 작용할 수 있습니다.
# *   **지속적인 사회적 책임**: 14년 연속 '동반성장지수' 최우수 획득은 삼성전자의 지속 가능한 성장에 대한 긍정적인 신호로 해석될 수 있으며, 투자자들의 신뢰를 높이는 요인으로 작용할 수 있습니다.
# *   **긍정적인 애널리스트 전망**: 다수의 애널리스트가 삼성전자에 대해 매수 의견을 제시하고 있으며, 목표주가 또한 현재 주가보다 높게 형성되어 있어, 향후 주가 상승 가능성을 시사합니다.
#
# **[부정적 요인]**
#
# *   **글로벌 경제 불확실성**: 금리 인상, 인플레이션 등 글로벌 경제의 불확실성은 반도체 수요 감소 및 투자 심리 위축으로 이어져 주가에 부정적인 영향을 미칠 수 있습니다.
# *   **경쟁 심화**: 반도체 시장 경쟁 심화는 삼성전자의 수익성 악화 요인으로 작용할 수 있습니다. 특히, 메모리 반도체 시장에서 경쟁 업체들의 기술 발전 및 공격적인 투자는 삼성전자의 시장 점유율에 영향을 줄 수 있습니다.
# *   **환율 변동**: 원/달러 환율 변동은 삼성전자의 실적에 영향을 미치는 중요한 변수입니다. 환율 상승 시에는 긍정적인 효과가, 하락 시에는 부정적인 효과가 발생할 수 있습니다.
#
# **[종합 의견 및 투자 전략]**
#
# 삼성전자는 AI 반도체 시장 성장이라는 긍정적인 모멘텀과 견조한 실적, 긍정적인 애널리스트 전망 등 긍정적인 요인들을 가지고 있습니다. 반면, 글로벌 경제 불확실성, 경쟁 심화, 환율 변동 등 주가에 부정적인 영향을 미칠 수 있는 요인들도 존재합니다.
#
# **투자 의견:** **매수 (Buy)**
#
# 삼성전자는 장기적인 성장 잠재력이 높은 기업으로 판단됩니다. 다만, 단기적인 변동성에 유의하며, 분할 매수 전략을 통해 투자 리스크를 관리하는 것이 바람직합니다. 2026년 1월 실적 발표 시, 긍정적인 실적 발표 여부를 확인하고 추가적인 투자를 고려해 볼 수 있습니다. 또한, 반도체 시장의 경쟁 구도 및 글로벌 경제 상황을 지속적으로 주시하며 투자 결정을 내릴 필요가 있습니다.
#
# **[Disclaimer]**
#
# 본 리포트는 정보 제공 및 교육적 목적으로 작성되었으며, 실제 투자 권유가 아님을 명시합니다. 투자는 개인의 판단과 책임 하에 이루어져야 하며, 본 리포트는 투자 결정의 근거로 활용될 수 없습니다. 투자 결과에 대한 책임은 투자자 본인에게 있습니다.

# %% [markdown]
# # 📜 MCP 서버 스크립트 정의 (`search_server.py`)
#
# 이 스크립트는 MCP(Model Context Protocol)를 사용하여 금융 정보 검색 도구(Tool)들을 마이크로서비스 형태로 제공하는 **Python 서버**입니다.<br>
# `search_server.py`라는 파일로 저장되며, 독립적으로 실행하여 다른 애플리케이션이나 Agent가 네트워크를 통해 이 도구들을 호출할 수 있도록 합니다.
#
# <br>
#
# #### 📝 제공하는 핵심 도구들
#
# 서버가 제공하는 핵심 도구는 다음과 같으며, 모두 LangChain의 `@tool` 데코레이터를 사용하여 표준화되었습니다.
#
#   * **`get_stock_price`** : 특정 회사의 현재 주가를 검색합니다.
#   * **`get_latest_news`** : 회사와 관련된 최신 뉴스를 검색합니다. `topic`을 지정하여 검색 주제를 좁힐 수 있습니다.
#   * **`get_company_overview`** : 회사가 어떤 사업을 하는지 등 전반적인 개요를 검색합니다.
#   * **`get_analyst_opinions`** : 해당 회사에 대한 증권사 애널리스트들의 최신 투자 의견을 검색합니다.
#
# <br>
#
# #### ⚙️ 서버 구성 방식
#
# 정의된 LangChain 도구들을 `langchain-mcp-adapters`를 통해 MCP 사양을 따르는 `FastMCP` 서버에 탑재합니다.<br>
# 스크립트가 직접 실행되면(`if __name__ == "__main__":`), `streamable-http` 전송 방식으로 서버가 구동됩니다.

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
# %%writefile /content/search_server.py
# ==================================
# Part 1: 라이브러리 임포트
# ==================================
from langchain_core.tools import tool
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_mcp_adapters.tools import to_fastmcp
from mcp.server.fastmcp import FastMCP
from typing import Optional

# ==================================
# Part 2: 핵심 도구 초기화 및 정의
# ==================================
# Tavily 검색 엔진 초기화 (최대 1개 결과만 사용)
tavily_search = TavilySearchResults(max_results=1)

@tool
def get_stock_price(company_name: str) -> str:
    """
    특정 회사의 현재 실시간 주가를 검색합니다.
    '삼성전자'와 같이 회사 이름만 정확히 입력해야 합니다.
    """
    print(f"Executing get_stock_price for: {company_name}")
    return tavily_search.invoke({"query": f"{company_name} 현재 주가"})

@tool
def get_latest_news(company_name: str, topic: Optional[str] = None) -> str:
    """
    특정 회사와 관련된 최신 뉴스를 검색합니다.
    더 구체적인 뉴스를 원할 경우 '실적', '신제품' 등 관련 주제(topic)를 지정할 수 있습니다.
    """
    search_query = f"{company_name} {topic or '최신'} 뉴스"
    print(f"Executing get_latest_news with query: {search_query}")
    return tavily_search.invoke({"query": search_query})

@tool
def get_company_overview(company_name: str) -> str:
    """
    특정 회사가 어떤 사업을 하는지, 주요 제품은 무엇인지 등 사업의 전반적인 개요를 검색합니다.
    """
    print(f"Executing get_company_overview for: {company_name}")
    return tavily_search.invoke({"query": f"{company_name} 사업 개요 what they do"})

@tool
def get_analyst_opinions(company_name: str) -> str:
    """
    특정 회사에 대한 증권사 애널리스트들의 최신 리포트나 투자 의견을 검색합니다.
    """
    print(f"Executing get_analyst_opinions for: {company_name}")
    return tavily_search.invoke({"query": f"{company_name} 증권사 애널리스트 리포트 요약"})

# ==================================
# Part 3: MCP 서버 설정 및 실행
# ==================================
# 정의된 모든 도구들을 리스트로 취합
all_tools = [
    get_stock_price,
    get_latest_news,
    get_company_overview,
    get_analyst_opinions,
]

# LangChain 도구를 FastMCP 형식으로 변환
fastmcp_tools = [to_fastmcp(t) for t in all_tools]

# FastMCP 서버 인스턴스 생성
mcp = FastMCP(
    "FinancialInfoProvider",  # 서비스 이름
    tools=fastmcp_tools,
)

# 스크립트가 직접 실행될 때 서버를 구동
if __name__ == "__main__":
    mcp.run(transport="streamable-http")
# Out:
# Overwriting /content/search_server.py

# %% [markdown]
# # 🚀 금융 정보 MCP 서버 시작
#
# 앞서 작성한 `search_server.py` 스크립트를 백그라운드에서 실행하여 **MCP 서버**를 시작합니다.<br>
# 이 서버는 Agent가 네트워크를 통해 금융 정보 도구를 호출할 수 있는 엔드포인트 역할을 합니다.

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
# --- 금융 정보 MCP 서버 시작 (Port 8000) ---
start_mcp_server(
    script_name="search_server.py",
    port=8000,
    log_file="search_server.log",
    service_name="금융 정보"
)
# Out:
# 🚀 금융 정보 MCP 서버를 시작합니다... (Port: 8000)
# ⏱️  서버 시작 대기 중... (최대 30초)
# ------------------------------
# ✅ 금융 정보 MCP 서버가 성공적으로 시작되어 실행 중입니다.
#    (로그 파일: /content/search_server.log)
# 'SUCCESS'

# %% [markdown]
# # 🤖 자율(ReAct) Agent 워크플로우
#
# 이번에는 이전의 순차적 그래프에서 더 나아가, **ReAct (Reasoning and Acting) 패턴**을 따르는 자율적인 Agent를 구축합니다.<br>
# 이 Agent는 **스스로 판단하여 도구를 반복적으로 호출**하고, 모든 정보가 수집되었다고 판단되면 최종 리포트를 생성하는 동적인 워크플로우를 가집니다.
#
# <br>
#
# ### 1\. Agent 아키텍처
#
# Agent는 다음과 같은 핵심 구성 요소로 이루어집니다.
#
#   * **MCP 클라이언트** : 원격 서버에 접속하여 도구들을 불러옵니다.
#   * **Agent 상태 (`AutonomousState`)** : 대화 기록(`messages`)과 실행 횟수(`turn_count`)를 저장합니다.
#   * **핵심 노드 (Nodes)** : `agent_node` (판단), `tool_node` (실행), `report_node` (보고)로 역할을 나눕니다.
#   * **조건부 라우터 (`agent_router`)** : `agent_node`의 판단에 따라 다음 작업으로 동적으로 분기합니다.
#
# <br>
#
# ### 2\. Agent 상태(`AutonomousState`) 정의
#
# Agent의 대화 기록(`messages`)과 함께, 무한 루프를 방지하기 위해 실행 횟수를 기록하는 `turn_count`를 상태에 추가합니다.
#
# > ```python
# > class AutonomousState(TypedDict):
# >     # 대화 기록이 계속 추가되도록 설정
# >     messages: Annotated[list[BaseMessage], operator.add]
# >     # Agent의 판단(turn) 횟수 기록
# >     turn_count: int
# > ```
#
# <br>
#
# ### 3\. Agent 그래프 생성 (`create_financial_agent_graph`)
#
# Agent를 생성하는 전체 로직을 하나의 비동기 함수(`async def`) 안에 캡슐화하여 코드의 재사용성과 가독성을 높입니다.
#
# > ```python
# > async def create_financial_agent_graph():
# >     # 1. 클라이언트 설정 및 모델 준비
# >     # 2. 핵심 노드 함수 정의
# >     # 3. 조건부 라우터 함수 정의
# >     # 4. 그래프 구성 및 컴파일
# >     return workflow.compile()
# > ```
#
# > #### 3.1. 클라이언트 및 모델 준비
# >
# > MCP 서버에 접속하여 **원격 도구들을 로드**합니다.<br>
# > 또한, **도구 호출을 위한 Agent용 모델**과 **리포트 작성을 위한 Reporter용 모델**을 별도로 정의하여 역할을 분리합니다.
# >
# > > ```python
# > > # MCP 서버에 접속하여 도구 로드
# > > client = MultiServerMCPClient(...)
# > > tools = await client.get_tools()
# > >
# > > # 역할에 따라 두 개의 모델 준비
# > > agent_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", temperature=0).bind_tools(tools)
# > > reporting_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.7)
# > > ```
#
# > #### 3.2. 핵심 노드 정의
# >
# > `agent_node`(판단), `tool_node`(실행), `report_node`(보고) 세 가지 핵심 노드 함수를 정의합니다.
# >
# > > ```python
# > > def agent_node(state: AutonomousState):
# > >     # ... LLM을 호출하여 다음 행동 결정 ...
# > >     return {"messages": [response], "turn_count": ...}
# > >
# > > # ToolNode는 LangGraph에서 제공하는 기본 도구 실행 노드
# > > tool_node = ToolNode(tools)
# > >
# > > def report_node(state: AutonomousState):
# > >     # ... 수집된 정보로 최종 리포트 작성 ...
# > >     return {"messages": [response]}
# > > ```
#
# > #### 3.3. 조건부 라우터(Router) 및 그래프 구성
# >
# > **`agent_router`** 함수는 Agent의 마지막 메시지를 보고 **도구를 추가로 호출할지, 아니면 리포트 생성을 시작할지** 동적으로 결정합니다.<br>
# > 이 라우터를 `add_conditional_edges`에 연결하여 그래프의 흐름을 제어합니다.
# >
# > > ```python
# > > def agent_router(state: AutonomousState):
# > >     # ... 최대 반복 횟수 체크 (안전장치) ...
# > >     if state["messages"][-1].tool_calls:
# > >         return "call_tool"  # 도구 호출
# > >     else:
# > >         return "generate_report" # 리포트 생성
# > >
# > > # 그래프 구성
# > > workflow = StateGraph(AutonomousState)
# > > workflow.add_node("financial_analysis_agent", agent_node)
# > > workflow.add_node("search_tools", ToolNode(tools))
# > > workflow.add_node("reporter", report_node)
# > >
# > > # agent 노드의 결과에 따라 동적으로 분기하도록 설정
# > > workflow.add_conditional_edges("financial_analysis_agent", agent_router, {
# > >     "call_tool": "search_tools",
# > >     "generate_report": "reporter"
# > > })
# > > ```
#
# <br>
#
# > ### 4\. Agent 실행 및 시각화 (`main`)
# >
# > `main` 함수에서 생성된 그래프(`app`)를 **실행하고, 그 구조를 시각화**합니다.<br>
# > `app.astream()`을 사용하여 Agent의 각 단계를 실시간으로 관찰합니다.
# >
# > > ```python
# > > async def main():
# > >     # 1. 그래프 생성 함수를 호출하여 app을 받음
# > >     app = await create_financial_agent_graph()
# > >
# > >     # 2. 그래프 구조를 다이어그램으로 시각화
# > >     display_mermaid_graph(app, title="금융 정보 ReAct Agent")
# > >
# > >     # 3. 입력을 정의하고 Agent 실행
# > >     inputs = {"messages": [HumanMessage(content="...")]}
# > >     async for update in app.astream(inputs):
# > >         # ... 각 단계의 결과 출력 ...
# > >
# > > # 메인 함수 실행
# > > await main()
# > > ```

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
# --- 1. 필요한 모든 모듈 임포트 ---
import asyncio
import operator
import textwrap
from typing import List, TypedDict, Annotated

from IPython.display import HTML, display
from langchain_core.messages import BaseMessage, HumanMessage, SystemMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_mcp_adapters.client import MultiServerMCPClient
from langgraph.graph import StateGraph, END
from langgraph.prebuilt import ToolNode


# --- 2. Agent의 상태(State) 정의 ---
class AutonomousState(TypedDict):
    """
    자율 Agent의 상태를 정의합니다.
    - messages: 대화 기록이 누적됩니다.
    - turn_count: Agent의 실행 횟수를 기록하여 무한 루프를 방지합니다.
    """
    messages: Annotated[List[BaseMessage], operator.add]
    turn_count: int


# --- 3. 금융 정보 Agent 그래프 생성 함수 ---
async def create_financial_agent_graph():
    """
    금융 정보 분석 ReAct Agent의 실행 가능한 그래프(app)를 생성하고 반환합니다.
    이 함수는 클라이언트 설정, 모델 준비, 노드 정의, 그래프 구성을 모두 포함합니다.
    """
    # --- 3-1. MCP 클라이언트 설정 및 도구/모델 준비 ---
    print("📡 MCP 클라이언트를 HTTP 방식으로 설정합니다...")
    client = MultiServerMCPClient(
        {"financial_service": {"transport": "streamable_http", "url": "http://localhost:8000/mcp/"}}
    )
    tools = await client.get_tools()
    print(f"✅ 로딩된 도구: {[tool.name for tool in tools]}")

    # 도구 호출에 특화된 모델
    agent_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", temperature=0).bind_tools(tools)
    # 리포트 생성에 특화된 모델
    reporting_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.7)

    # --- 3-2. 핵심 노드 함수 정의 ---
    def agent_node(state: AutonomousState):
        """사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정하는 노드"""
        current_turn = state.get("turn_count", 0)
        print(f"\n++++++++++ 🤖 FINANCIAL AGENT (Turn {current_turn + 1}) ++++++++++")
        print("사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...")
        system_prompt = SystemMessage(
            content="""당신은 사용자의 요청을 해결하기 위해 필요한 도구를 호출하는 역할만 수행합니다.
            절대로 중간에 답변이나 요약을 생성하지 마세요.
            오직 다음으로 호출할 단 하나의 도구를 결정하고 tool_calls를 생성하세요.
            만약 모든 정보가 수집되었다고 생각되면, tool_calls 없이 '모든 정보 수집 완료'라고만 답변하세요.
            """
        )
        messages_with_system_prompt = [system_prompt, *state["messages"]]
        response = agent_model.invoke(messages_with_system_prompt)
        return {"messages": [response], "turn_count": current_turn + 1}

    def report_node(state: AutonomousState):
        """수집된 모든 정보를 종합하여 최종 리포트를 작성하는 노드"""
        print("\n++++++++++ ✍️ FINANCIAL REPORTER ++++++++++")
        print("수집된 모든 정보를 종합하여 최종 리포트를 작성합니다...")
        report_history = [msg for msg in state["messages"] if not isinstance(msg, HumanMessage)]
        search_history = textwrap.dedent("\n".join([msg.pretty_repr() for msg in report_history]))
        report_prompt = f"""당신은 전문 애널리스트입니다.
        아래 정보 수집 기록을 바탕으로 사용자의 초기 질문에 대한 최종 투자 리포트를 작성해주세요.
        \n\n[정보 수집 기록]
        \n{search_history}
        """
        response = reporting_model.invoke(report_prompt)
        return {"messages": [response]}

    # --- 3-3. 조건부 엣지(Edge) 함수 정의 ---
    MAX_TURNS = 5
    def agent_router(state: AutonomousState):
        """Agent의 응답에 따라 다음 경로를 결정하는 라우터"""
        print("\n----- 🚦 ROUTER -----")
        if state.get("turn_count", 0) >= MAX_TURNS:
            print(f"⚠️ Safety Guard: 최대 반복 횟수({MAX_TURNS}회)를 초과하여 강제로 리포트를 생성합니다.\n")
            return "generate_report"

        last_message = state["messages"][-1]
        if last_message.tool_calls:
            print("분기: [call_tool] -> TOOLS 노드로 이동합니다.\n")
            return "call_tool"
        else:
            print("분기: [generate_report] -> REPORTER 노드로 이동합니다.\n")
            return "generate_report"

    # --- 3-4. 그래프 구성 및 컴파일 ---
    workflow = StateGraph(AutonomousState)
    workflow.add_node("financial_analysis_agent", agent_node)
    workflow.add_node("search_tools", ToolNode(tools))
    workflow.add_node("reporter", report_node)

    workflow.set_entry_point("financial_analysis_agent")
    workflow.add_conditional_edges("financial_analysis_agent", agent_router, {"call_tool": "search_tools", "generate_report": "reporter"})
    workflow.add_edge("search_tools", "financial_analysis_agent")
    workflow.add_edge("reporter", END)

    return workflow.compile()


# --- 4. 메인 실행 함수 ---
async def main():
    """그래프 생성, 시각화, 실행을 총괄하는 비동기 메인 함수"""
    # --- 4-1. 그래프 생성 함수 호출 ---
    app = await create_financial_agent_graph()
    print("✅ 그래프가 성공적으로 컴파일되었습니다.")

    # --- 4-2. 시각화 ---
    display_mermaid_graph(app, title="금융 정보 ReAct Agent")

    # --- 4-3. Agent 실행 ---
    print("\n================ ReAct Agent 모델 실행 ================")
    inputs = {"messages": [HumanMessage(content="""
    엔비디아(NVIDIA)에 대한 종합 투자 리포트를 작성해줘. 최신 주가, 사업 개요, 그리고 'AI 칩'과 관련된 최신 뉴스를 포함해서 분석해줘.
    """)], "turn_count": 0}

    # 사용자 입력을 먼저 출력
    print("\n++++++++++ 🙋‍♂️ USER INPUT ++++++++++")
    inputs["messages"][0].pretty_print()

    # stream_mode="updates"를 사용하여 각 노드의 출력을 순서대로 처리
    async for update in app.astream(inputs, stream_mode="updates"):
        # update는 {'node_name': {'key': 'value'}} 형태의 딕셔너리
        node_name = list(update.keys())[0]
        node_output = list(update.values())[0]

        if node_name == "financial_analysis_agent":
            # agent 노드의 AiMessage를 출력
            node_output['messages'][-1].pretty_print()
        elif node_name == "search_tools":
            # tools 노드는 ToolMessage 리스트를 반환
            for tool_message in node_output['messages']:
                tool_message.pretty_print()
        elif node_name == "reporter":
            # reporter 노드의 최종 결과 AiMessage를 출력
            node_output['messages'][-1].pretty_print()

    print("\n✅ 에이전트 실행이 완료되었습니다.")


# --- 5. 비동기 메인 함수 실행 ---
await main()
# Out:
# 📡 MCP 클라이언트를 HTTP 방식으로 설정합니다...
# ✅ 로딩된 도구: ['get_stock_price', 'get_latest_news', 'get_company_overview', 'get_analyst_opinions']
# ✅ 그래프가 성공적으로 컴파일되었습니다.
#
# 📊 [ 금융 정보 ReAct Agent ]
#     <div style="background-color: white; border: 1px solid #ddd; padding: 10px; border-radius: 5px;">
#         <pre class="mermaid">---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	financial_analysis_agent(financial_analysis_agent)
# 	search_tools(search_tools)
# 	reporter(reporter)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> financial_analysis_agent;
# 	financial_analysis_agent -. &nbsp;generate_report&nbsp; .-> reporter;
# 	financial_analysis_agent -. &nbsp;call_tool&nbsp; .-> search_tools;
# 	search_tools --> financial_analysis_agent;
# 	reporter --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
# </pre>
#     </div>
#     <script type="module">
#         import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.esm.min.mjs';
#         await mermaid.run();
#     </script>
# ================ ReAct Agent 모델 실행 ================
#
# ++++++++++ 🙋‍♂️ USER INPUT ++++++++++
# ================================ Human Message =================================
#
#
#     엔비디아(NVIDIA)에 대한 종합 투자 리포트를 작성해줘. 최신 주가, 사업 개요, 그리고 'AI 칩'과 관련된 최신 뉴스를 포함해서 분석해줘.
#
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 1) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
# ================================== Ai Message ==================================
# Tool Calls:
#   get_stock_price (6bc35d36-eba8-44ec-80c9-c75a48525a10)
#  Call ID: 6bc35d36-eba8-44ec-80c9-c75a48525a10
#   Args:
#     company_name: NVIDIA
#   get_company_overview (97831cea-8cb1-43bf-a773-6b4dbc26de4e)
#  Call ID: 97831cea-8cb1-43bf-a773-6b4dbc26de4e
#   Args:
#     company_name: NVIDIA
#   get_latest_news (1e6f1d06-5a87-4028-9135-8c957ad62a72)
#  Call ID: 1e6f1d06-5a87-4028-9135-8c957ad62a72
#   Args:
#     topic: AI 칩
#     company_name: NVIDIA
# ================================= Tool Message =================================
# Name: get_stock_price
#
# {
#   "title": "Stock Quote & Chart - NVIDIA Investor Relations",
#   "url": "https://investor.nvidia.com/stock-info/stock-quote-and-chart/default.aspx",
#   "content": "| July 14, 2025 | $164.07 |\n| July 11, 2025 | $164.92 |\n| July 10, 2025 | $164.1 |\n| July 09, 2025 | $162.88 |\n| July 08, 2025 | $160 |\n| July 07, 2025 | $158.24 |\n| July 03, 2025 | $159.34 |\n| July 02, 2025 | $157.25 |\n| July 01, 2025 | $153.3 |\n| June 30, 2025 | $157.99 |\n| June 27, 2025 | $157.75 |\n| June 26, 2025 | $155.02 |\n| June 25, 2025 | $154.31 |\n| June 24, 2025 | $147.9 |\n| June 23, 2025 | $144.17 |\n| June 20, 2025 | $143.85 |\n| June 18, 2025 | $145.48 |\n| June 17, 2025 | $144.12 | [...] XNAS:NVDA,NASD:NVDA historical stock data| Stock Date | Stock Price |\n --- |\n| October 29, 2025 | $207.04 |\n| October 28, 2025 | $201.03 |\n| October 27, 2025 | $191.49 |\n| October 24, 2025 | $186.26 |\n| October 23, 2025 | $182.16 |\n| October 22, 2025 | $180.28 |\n| October 21, 2025 | $181.16 |\n| October 20, 2025 | $182.64 |\n| October 17, 2025 | $183.22 |\n| October 16, 2025 | $181.81 |\n| October 15, 2025 | $179.83 |\n| October 14, 2025 | $180.03 |\n| October 13, 2025 | $188.32 | [...] | October 10, 2025 | $183.16 |\n| October 09, 2025 | $192.57 |\n| October 08, 2025 | $189.11 |\n| October 07, 2025 | $185.04 |\n| October 06, 2025 | $185.54 |\n| October 03, 2025 | $187.62 |\n| October 02, 2025 | $188.89 |\n| October 01, 2025 | $187.24 |\n| September 30, 2025 | $186.58 |\n| September 29, 2025 | $181.85 |\n| September 26, 2025 | $178.19 |\n| September 25, 2025 | $177.69 |\n| September 24, 2025 | $176.97 |\n| September 23, 2025 | $178.43 |\n| September 22, 2025 | $183.61 |",
#   "score": 0.8861155
# }
# ================================= Tool Message =================================
# Name: get_company_overview
#
# {
#   "title": "Nvidia - Wikipedia",
#   "url": "https://en.wikipedia.org/wiki/Nvidia",
#   "content": "Nvidia Corporation( (/ɛ n ˈ v ɪ d i ə/_en-VID-ee-ə_) is an American technology company headquartered in Santa Clara, California. Founded in 1993 by Jensen Huang (who remains president and CEO), Chris Malachowsky, and Curtis Priem, it develops graphics processing units (GPUs), systems on chips (SoCs), and application programming interfaces (APIs) for data science, high-performance computing, and mobile and automotive applications.( Nvidia is considered part of the Big Tech group, alongside [...] Nvidia uses external suppliers for all phases of manufacturing, including wafer fabrication, assembly, testing, and packaging. Nvidia thus avoids most of the investment and production costs and risks associated with chip manufacturing, although it does sometimes directly procure some components and materials used in the production of its products (e.g., memory and substrates). Nvidia focuses its own resources on product design, quality assurance, marketing, and customer support.( [...] Originally focused on GPUs for video gaming, Nvidia broadened their use into other markets, including artificial intelligence (AI), professional visualization, and supercomputing. The company's product lines include GeForce GPUs for gaming and creative workloads, and professional GPUs for edge computing, scientific research, and industrial applications. As of the first quarter of 2025, Nvidia held a 92% share of the discrete desktop and laptop GPU market.(",
#   "score": 0.71687365
# }
# ================================= Tool Message =================================
# Name: get_latest_news
#
# {
#   "title": "NVIDIA: 인공 지능 컴퓨팅의 세계적인 리더",
#   "url": "https://www.nvidia.com/ko-kr/",
#   "content": "### 업계 선도 기업, 새로운 추론 모델로 더 스마트한 AI 에이전트 구축\n\n엔터프라이즈와 피지컬 AI를 위해 설계된 새로운 NVIDIA Nemotron™ 및 Cosmos™ 추론 모델은 더 빠른 사고, 향상된 추론 능력, 그리고 낮은 추론 비용을 제공합니다.\n\n인공 지능 | 발표 사항\n\n### 도시와 산업 인프라에 피지컬 AI 도입\n\nNVIDIA Metropolis의 고급 Blueprint, 비전 언어 모델, 그리고 합성 데이터 생성 확장 기능이 다양한 환경에서 생산성을 높이고 안전성을 향상시킵니다.\n\n인공지능 | News\n\n### 비디오 검색 및 요약 에이전트 구축\n\n이제 비디오 검색 및 요약(VSS)을 위한 NVIDIA AI Blueprint를 일반 사용자에게 제공합니다.\n\n인공지능 | 블로그\n\n### 미래의 업무 환경을 위해 AI 에이전트를 연결하는 새로운 AI-Q Blueprint\n\n추론을 사용하고 엔터프라이즈 데이터에 연결할 수 있는 에이전틱 시스템을 개발하십시오. [...] ### NVIDIA AI 팩토리 디지털 트윈: 새로운 에코시스템 및 도구\n\nAI 팩토리 설계 및 운영을 위해 확장된 NVIDIA Omniverse Blueprint, AI 팩토리 전력, 냉각 및 네트워킹 생태계 전반에 걸쳐 더욱 심층적인 통합을 제공\n\n시뮬레이션 | 발표 내용\n\n### NVIDIA RTX PRO Blackwell 세대 소개\n\n데스크톱 및 모바일 워크스테이션용 새로운 NVIDIA RTX PRO Blackwell 세대 GPU가 AI와 뉴럴 렌더링 워크플로우의 새로운 시대를 열어갑니다.\n\n시뮬레이션 | 블로그\n\n### NVIDIA, 물리 AI 발전을 위해 개방형 물리 AI 데이터세트 공개 및 최대 규모의 합성 데이터세트 출시\n\n시뮬레이션에 즉시 활용 가능한 실제 데이터 및 합성 생성 데이터 모음이 이제 오픈 소스로 제공됩니다.\n\n시뮬레이션 | 발표 내용\n\n### NVIDIA Omniverse, 물리 AI 도입 확산으로 생태계 확장",
#   "score": 0.80126834
# }
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 2) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [generate_report] -> REPORTER 노드로 이동합니다.
#
# ================================== Ai Message ==================================
#
# 모든 정보 수집 완료
#
# ++++++++++ ✍️ FINANCIAL REPORTER ++++++++++
# 수집된 모든 정보를 종합하여 최종 리포트를 작성합니다...
# ================================== Ai Message ==================================
#
# ## NVIDIA 투자 리포트 (2025년 10월)
#
# ### 1. 서론
#
# 본 리포트는 인공지능(AI) 컴퓨팅 분야의 선두 기업인 NVIDIA(이하 엔비디아)에 대한 투자 분석을 목적으로 합니다. 엔비디아의 기업 개요, 최신 주가 동향, AI 칩 시장에서의 주요 사업 및 최신 동향을 종합적으로 분석하여 투자 의견을 제시합니다.
#
# ### 2. 기업 개요
#
# 엔비디아는 1993년 젠슨 황(Jensen Huang)이 공동 설립한 미국 기술 기업으로, 캘리포니아 산타클라라에 본사를 두고 있습니다. 그래픽 처리 장치(GPU), 시스템 온 칩(SoC), 그리고 데이터 과학, 고성능 컴퓨팅, 모바일 및 자동차 애플리케이션을 위한 애플리케이션 프로그래밍 인터페이스(API)를 개발합니다. 엔비디아는 '빅 테크(Big Tech)' 그룹의 일원으로 간주됩니다.
#
# 회사는 웨이퍼 제조, 조립, 테스트, 패키징 등 모든 제조 단계를 외부 공급업체에 의존하는 팹리스(Fabless) 모델을 채택하고 있습니다. 이를 통해 제조 관련 투자 및 생산 비용, 위험을 최소화하고, 자체 자원은 제품 설계, 품질 보증, 마케팅 및 고객 지원에 집중하고 있습니다.
#
# 초기에는 비디오 게임용 GPU에 주력했으나, 현재는 인공지능(AI), 전문 시각화, 슈퍼컴퓨팅 등 다양한 시장으로 사업 영역을 확장했습니다. 2025년 1분기 기준으로 엔비디아는 개별 데스크톱 및 노트북 GPU 시장에서 92%의 압도적인 점유율을 차지하고 있습니다.
#
# ### 3. 최신 주가 동향
#
# 엔비디아의 주가는 2025년 6월부터 10월 말까지 상당한 상승세를 보였습니다.
# *   **2025년 6월 17일**: $144.12
# *   **2025년 7월 14일**: $164.07
# *   **2025년 10월 29일**: $207.04
#
# 위 데이터에 따르면, 엔비디아의 주가는 6월 중순 이후 꾸준히 상승하여 10월 말에는 $200를 넘어섰습니다. 이는 약 4개월 반 동안 43% 이상 상승한 수치로, AI 시장의 성장 기대감과 엔비디아의 시장 지배력이 주가에 긍정적으로 반영된 것으로 분석됩니다. 단기적인 변동성은 존재하지만, 전반적인 추세는 우상향을 강력하게 나타내고 있습니다.
#
# ### 4. AI 칩 시장에서의 엔비디아 및 최신 동향
#
# 엔비디아는 AI 컴퓨팅 분야의 세계적인 리더로서, AI 칩(GPU)을 기반으로 한 다양한 솔루션과 플랫폼을 제공하며 시장을 선도하고 있습니다. 최근 주요 동향은 다음과 같습니다.
#
# *   **차세대 AI 추론 모델 개발**: 엔터프라이즈 및 피지컬 AI를 위해 설계된 새로운 NVIDIA Nemotron™ 및 Cosmos™ 추론 모델을 발표했습니다. 이 모델들은 더 빠른 사고, 향상된 추론 능력, 낮은 추론 비용을 제공하여 AI 에이전트 구축을 가속화합니다.
# *   **피지컬 AI 확장**: NVIDIA Metropolis의 고급 Blueprint, 비전 언어 모델, 합성 데이터 생성 확장 기능을 통해 도시 및 산업 인프라에 피지컬 AI 도입을 확산하고 있습니다. 이는 다양한 환경에서 생산성과 안전성을 향상시킵니다.
# *   **AI 에이전트 솔루션 강화**: 비디오 검색 및 요약(VSS)을 위한 NVIDIA AI Blueprint를 일반 사용자에게 제공하고 있으며, 미래의 업무 환경을 위해 AI 에이전트를 연결하는 새로운 AI-Q Blueprint를 통해 추론 및 엔터프라이즈 데이터에 연결 가능한 에이전틱 시스템 개발을 지원합니다.
# *   **AI 팩토리 및 시뮬레이션 생태계 확장**: AI 팩토리 설계 및 운영을 위한 확장된 NVIDIA Omniverse Blueprint를 통해 AI 팩토리 전력, 냉각, 네트워킹 생태계 전반에 걸쳐 심층적인 통합을 제공합니다. 또한, 물리 AI 발전을 위해 개방형 물리 AI 데이터세트를 공개하고 최대 규모의 합성 데이터세트를 출시하여 시뮬레이션에 즉시 활용 가능한 데이터를 제공하며, NVIDIA Omniverse 생태계를 통해 물리 AI 도입을 확산하고 있습니다.
# *   **신규 GPU 출시**: 데스크톱 및 모바일 워크스테이션용 새로운 NVIDIA RTX PRO Blackwell 세대 GPU를 소개하며 AI와 뉴럴 렌더링 워크플로우의 새로운 시대를 열고 있습니다.
#
# 이러한 최신 동향은 엔비디아가 단순한 하드웨어 공급업체를 넘어, AI 모델, 플랫폼, 소프트웨어, 데이터세트 등 포괄적인 AI 생태계를 구축하고 있음을 보여줍니다. 특히 추론 능력 강화와 다양한 산업 분야로의 AI 적용 확대를 통해 AI 시장에서의 지배력을 더욱 공고히 하고 있습니다.
#
# ### 5. 경쟁 우위 및 위험 요소
#
# **경쟁 우위:**
# *   **압도적인 시장 점유율**: 개별 GPU 시장에서 92%의 점유율을 바탕으로 독점적인 지위를 유지하고 있습니다.
# *   **기술 리더십**: AI, 슈퍼컴퓨팅, 시뮬레이션 등 고성장 시장에서 핵심 기술과 혁신을 선도하고 있습니다.
# *   **팹리스 모델의 효율성**: 제조 리스크를 회피하고 R&D, 제품 설계, 소프트웨어 개발에 집중하여 높은 효율성을 달성합니다.
# *   **강력한 AI 생태계**: 하드웨어뿐만 아니라 CUDA, Omniverse, 다양한 AI Blueprint 및 모델, 데이터세트 등을 통해 광범위한 AI 개발 환경을 제공하여 고객 락인(Lock-in) 효과를 창출합니다.
#
# **위험 요소:**
# *   **높은 외부 공급망 의존도**: 제조를 외부 공급업체에 의존하고 있어, 공급망 불안정성이나 특정 부품 수급 문제 발생 시 생산에 차질을 빚을 수 있습니다.
# *   **AI 시장 경쟁 심화**: 인텔, AMD 등 기존 경쟁사뿐만 아니라 아마존, 구글, 마이크로소프트 등 클라우드 기업들의 자체 AI 칩 개발로 경쟁이 심화될 수 있습니다.
# *   **높은 밸류에이션**: 최근 주가 급등으로 인해 PER 등 전통적인 가치 평가 지표상 고평가 논란이 있을 수 있으며, 이는 시장 변동성에 취약하게 만들 수 있습니다.
# *   **기술 변화 속도**: AI 기술의 발전 속도가 매우 빨라, 지속적인 연구 개발 투자와 혁신 없이는 경쟁 우위를 유지하기 어려울 수 있습니다.
#
# ### 6. 결론 및 투자 의견
#
# 엔비디아는 AI 시대의 핵심 인프라를 제공하는 독보적인 기업으로서, GPU 시장에서의 압도적인 점유율과 AI 기술 혁신을 통해 지속적인 성장이 기대됩니다. 새로운 AI 추론 모델, 피지컬 AI 솔루션, AI 에이전트 플랫폼, AI 팩토리 및 시뮬레이션 생태계 확장 등 다각적인 노력을 통해 AI 산업 전반에 걸쳐 영향력을 확대하고 있습니다. 최근 주가 상승세는 이러한 긍정적인 전망을 반영하는 것으로 보입니다.
#
# **투자 의견:**
# 엔비디아에 대한 **'매수(BUY)'** 의견을 제시합니다.
# 장기적인 관점에서 AI 산업의 폭발적인 성장은 엔비디아의 핵심 사업 성장을 견인할 것으로 판단됩니다. 기술 리더십과 강력한 생태계를 바탕으로 엔비디아는 AI 시대의 핵심 수혜주로서 지속적인 기업 가치 상승이 예상됩니다.
#
# 다만, 높은 밸류에이션과 외부 공급망 의존도, 그리고 AI 시장의 경쟁 심화는 투자 시 고려해야 할 위험 요소입니다. 따라서 투자자들은 단기적인 주가 변동성에 대비하고, 엔비디아의 기술 혁신 속도와 경쟁 환경 변화를 지속적으로 모니터링할 필요가 있습니다.
#
# ---
# **면책 조항:** 본 리포트는 제공된 정보를 바탕으로 작성된 분석이며, 투자 조언이 아닙니다. 모든 투자 결정은 투자자 본인의 판단과 책임 하에 이루어져야 합니다.
#
# ✅ 에이전트 실행이 완료되었습니다.

# %% [markdown]
# # 🛑 금융 정보 MCP 서버 종료
#
# 모든 작업이 완료된 후, 백그라운드에서 실행되던 **MCP 서버 프로세스를 종료**하여 시스템 자원을 정리합니다.

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
# --- 금융 정보 MCP 서버 종료 (Port 8000) ---
stop_mcp_server(port=8000, service_name="금융 정보")
# Out:
# 🛑 금융 정보 MCP 서버(Port: 8000)를 종료합니다...
# ✅ 금융 정보 서버가 종료되었습니다.

# %% [markdown]
# # 📜 포트폴리오 MCP 서버 스크립트 (db_server.py)
#
# 이 스크립트는 **SQLite 데이터베이스와 상호작용**하는 도구들을 제공하는 **두 번째 MCP 서버**를 생성합니다.<br>
# `db_server.py` 파일로 저장되며, Agent가 주식 포트폴리오 데이터를 조회하고 분석할 수 있도록 SQL 쿼리 관련 기능들을 API 형태로 노출하는 역할을 합니다.
#
# ### 1\. 주요 기능 및 아키텍처
#
#   * **데이터베이스 생성**: 스크립트 실행 시, `my_portfolio`라는 테이블을 가진 예제용 SQLite 데이터베이스(`portfolio.db`)를 자동으로 생성하고 샘플 데이터를 삽입합니다.
#
#     ```sql
#     CREATE TABLE my_portfolio (
#         id INTEGER PRIMARY KEY AUTOINCREMENT,
#         ticker TEXT NOT NULL UNIQUE,
#         company_name TEXT NOT NULL,
#         shares_owned INTEGER NOT NULL,
#         purchase_price REAL NOT NULL
#     )
#     ```
#
#   * **`SQLDatabaseToolkit` 활용**: 이 스크립트의 핵심은 LangChain의 `SQLDatabaseToolkit`입니다.<br>
#   이 툴킷은 데이터베이스 연결 정보(`db`)와 LLM만 제공하면, 해당 데이터베이스와 상호작용하는 데 필요한 표준 도구들을 LLM에게 제공합니다.
#
#   * **자동 생성 도구 목록**: `SQLDatabaseToolkit`은 다음과 같은 유용한 도구들을 만들어냅니다.
#
#       * **`sql_db_list_tables`** : 데이터베이스 내의 모든 테이블 목록을 조회합니다.
#       * **`sql_db_schema`** : 특정 테이블의 스키마(구조) 정보를 보여줍니다.
#       * **`sql_db_query`** : 실제 SQL 쿼리를 실행하고 결과를 가져옵니다.
#       * **`sql_db_query_checker`** : 실행하기 전에 SQL 쿼리에 문법적 오류가 없는지 확인합니다.
#
#   * **서버 실행**: 자동으로 생성된 DB 도구들을 `FastMCP` 서버에 탑재하여 **포트 8001**에서 실행합니다. (기존 서버와의 충돌 방지)
#
#     ```python
#     if __name__ == "__main__":
#         # 1. DB 생성 및 초기화
#         setup_portfolio_database()
#         # 2. MCP 서버 실행
#         mcp.run(transport="streamable-http")
#     ```
#
# ### 2\. `SQLDatabaseToolkit` 사용법
#
# 데이터베이스 경로를 지정하여 `SQLDatabase` 객체를 만들고, 이를 `SQLDatabaseToolkit`에 `db`와 `llm` 인자와 함께 전달하면 됩니다.
#
# > ```python
# > # 데이터베이스 연결
# > db = SQLDatabase.from_uri("sqlite:///portfolio.db")
# >
# > # LLM과 DB 연결 정보를 제공하여 툴킷 생성
# > toolkit = SQLDatabaseToolkit(db=db, llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash"))
# >
# > # 툴킷에서 자동으로 생성된 도구 목록 가져오기
# > db_tools = toolkit.get_tools()
# > ```

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
# %%writefile /content/db_server.py
# SQLite 데이터베이스와 상호작용하는 도구를 제공하는 MCP 서버입니다.

# --- 1. 라이브러리 임포트 ---
import sqlite3
import uvicorn
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.utilities import SQLDatabase
from langchain_community.agent_toolkits import SQLDatabaseToolkit
from langchain_mcp_adapters.tools import to_fastmcp
from mcp.server.fastmcp import FastMCP

# --- 2. 데이터베이스 설정 및 생성 함수 ---
DB_PATH = "portfolio.db"

def setup_portfolio_database():
    """개인 포트폴리오 예제용 SQLite 데이터베이스를 생성하고 초기화합니다."""
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    cursor.execute("DROP TABLE IF EXISTS my_portfolio")
    cursor.execute("""
    CREATE TABLE my_portfolio (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        ticker TEXT NOT NULL UNIQUE,
        company_name TEXT NOT NULL,
        shares_owned INTEGER NOT NULL,
        purchase_price REAL NOT NULL
    )
    """)
    portfolio_data = [
        ('NVDA', 'NVIDIA Corp', 50, 120.50),
        ('AAPL', 'Apple Inc', 100, 185.75),
        ('TSLA', 'Tesla Inc', 30, 250.00)
    ]
    cursor.executemany(
        "INSERT INTO my_portfolio (ticker, company_name, shares_owned, purchase_price) VALUES (?, ?, ?, ?)",
        portfolio_data
    )
    conn.commit()
    conn.close()
    print(f"✅ 포트폴리오 데이터베이스 '{DB_PATH}'가 성공적으로 생성 및 초기화되었습니다.")


# --- 3. MCP 서버 설정 및 실행 ---
if __name__ == "__main__":

    # 1. (가장 중요) 스크립트 실행 시 DB부터 생성합니다.
    setup_portfolio_database()

    # 2. DB가 확실히 생성된 *이후에* DB 연결 객체를 생성합니다.
    db = SQLDatabase.from_uri(f"sqlite:///{DB_PATH}")

    # 3. SQL 툴킷을 생성합니다.
    toolkit = SQLDatabaseToolkit(db=db, llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash"))

    # 4. 툴킷에서 도구 목록을 가져옵니다.
    db_tools = toolkit.get_tools()
    print(f"🛠️  자동 생성된 DB 도구: {[tool.name for tool in db_tools]}")

    # 5. LangChain 도구를 MCP 서버가 이해할 수 있는 형식으로 변환합니다.
    fastmcp_tools = [to_fastmcp(t) for t in db_tools]

    # 6. MCP 서버 인스턴스를 생성합니다. (포트 8001 사용)
    mcp = FastMCP("PortfolioDBService", tools=fastmcp_tools, port=8001)

    # 7. streamable-http 방식으로 서버를 실행합니다.
    mcp.run(transport="streamable-http")
# Out:
# Overwriting /content/db_server.py

# %% [markdown]
# # 🚀 포트폴리오 MCP 서버 시작
#
# 앞서 작성한 `db_server.py` 스크립트를 백그라운드에서 실행하여 **데이터베이스 도구를 제공하는 두 번째 MCP 서버**를 시작합니다.

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
# --- 포트폴리오 MCP 서버 시작 (Port 8001) ---
start_mcp_server(
    script_name="db_server.py",
    port=8001,
    log_file="db_server.log",
    service_name="포트폴리오 DB"
)
# Out:
# 🚀 포트폴리오 DB MCP 서버를 시작합니다... (Port: 8001)
# ⏱️  서버 시작 대기 중... (최대 30초)
# ------------------------------
# ✅ 포트폴리오 DB MCP 서버가 성공적으로 시작되어 실행 중입니다.
#    (로그 파일: /content/db_server.log)
# 'SUCCESS'

# %% [markdown]
# # 🗃️ 포트폴리오 DB 조회 Agent 워크플로우
#
# 마지막으로, **데이터베이스 조회에만 특화**된 자율 Agent를 구축합니다.<br>
# 이 Agent는 이전의 범용 Agent와 달리, 오직 DB 관련 도구만 사용하여 사용자의 질문에 답변하는 전문가 역할을 수행합니다.
#
# <br>
#
# ### 1\. Agent 아키텍처 및 특징
#
#   * **전용 클라이언트**: Agent는 금융 정보 서버가 아닌, DB 서버(포트 8001)에만 연결하는 전용 `MultiServerMCPClient`를 사용합니다.<br>
#   이를 통해 Agent가 사용할 수 있는 도구를 DB 관련 기능(`sql_db_query` 등)으로 제한합니다.
#
#     ```python
#     client = MultiServerMCPClient({
#         "database_service": {
#             "transport": "streamable_http",
#             "url": "http://localhost:8001/mcp/",
#         }
#     })
#     db_tools = await client.get_tools()
#     ```
#
#   * **체계적 사고를 위한 시스템 프롬프트** : 이 Agent의 가장 큰 특징은 **명확한 행동 지침**을 담은 `SystemMessage`를 받는다는 점입니다. Agent는 이 지침에 따라 체계적으로 사고하고 행동합니다.
#
#     ```python
#     system_prompt = """
#     당신은 ... 데이터베이스 전문가입니다.
#
#     **행동 지침:**
#     1. 가장 먼저 `sql_db_list_tables`를 호출하여 ... 테이블을 확인하세요.
#     2. 그 다음, `sql_db_schema`를 호출하여 ... 구조를 파악하세요.
#     3. 마지막으로, `sql_db_query`를 실행하여 ... 답을 찾으세요.
#     """
#     ```
#
#   * **단순화된 그래프 구조** : 이전 Agent와 달리 별도의 `report_node`가 없습니다. `agent_node`가 도구 호출(Reasoning)과 최종 답변 생성을 모두 담당하여 구조가 더 단순해졌습니다.<br>
#   라우터 역시 도구를 호출할지(`call_tool`), 아니면 프로세스를 종료할지(`end`)만 결정합니다.
#
#     ```python
#     # 라우터의 분기 로직
#     def agent_router(state: AutonomousState):
#         if state["messages"][-1].tool_calls:
#             return "call_tool"
#         else:
#             return "end"
#
#     # 그래프 구성
#     workflow.add_conditional_edges("text_to_sql_agent", agent_router, {
#         "call_tool": "db_tools",
#         "end": END
#     })
#     ```
#
# ### 2\. 실행 및 결과 확인
#
# `main` 함수에서 생성된 DB 조회 Agent를 실행하고, 사용자의 질문("내 포트폴리오의 모든 종목 티커와 보유 수량을 알려줘")에 대해 Agent가 어떻게 단계별로 DB 도구를 사용하여 답변을 찾아가는지 실시간으로 확인할 수 있습니다.

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
# --- 1. 필요한 모든 모듈 임포트 ---
import asyncio
import operator
import textwrap
from typing import List, TypedDict, Annotated

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_mcp_adapters.client import MultiServerMCPClient
from langgraph.graph import StateGraph, END
from langgraph.prebuilt import ToolNode
from langchain_core.messages import BaseMessage, HumanMessage, SystemMessage
from IPython.display import display, HTML


# --- 2. Agent의 상태(State) 정의 ---
class AutonomousState(TypedDict):
    messages: Annotated[List[BaseMessage], operator.add]
    turn_count: int


# --- 3. DB 조회 Agent 그래프 생성 함수 ---
async def create_db_agent_graph():
    """
    DB 조회 ReAct Agent의 실행 가능한 그래프(app)를 생성하고 반환합니다.
    """
    # --- 3-1. DB 서버 클라이언트 설정 및 도구/모델 준비 ---
    print("📡 DB 서버에만 연결하는 MCP 클라이언트를 설정합니다...")
    client = MultiServerMCPClient(
        {"database_service": {"transport": "streamable_http", "url": "http://localhost:8001/mcp/"}}
    )
    db_tools = await client.get_tools()
    print(f"✅ 포트폴리오 Agent용 도구 로딩 완료: {[tool.name for tool in db_tools]}")

    agent_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", temperature=0).bind_tools(db_tools)

    # --- 3-2. 핵심 노드 함수 정의 ---
    def agent_node(state: AutonomousState):
        current_turn = state.get("turn_count", 0)
        print(f"\n++++++++++ 🤖 PORTFOLIO AGENT (Turn {current_turn + 1}) ++++++++++")
        print("DB 조회를 위해 다음 행동을 결정합니다...")

        system_prompt = """
        당신은 사용자의 포트폴리오 데이터베이스를 조회하여 질문에 답변하는 데이터베이스 전문가입니다.

        **행동 지침:**
        1. 가장 먼저 `sql_db_list_tables`를 호출하여 사용 가능한 테이블을 확인하세요.
        2. 그 다음, `sql_db_schema`를 호출하여 관련된 테이블의 구조를 파악하세요.
        3. 마지막으로, 알아낸 테이블과 스키마 정보를 바탕으로 `sql_db_query`를 실행하여 질문에 대한 답을 찾으세요.
        """
        messages_with_system_prompt = [SystemMessage(content=system_prompt), *state["messages"]]

        response = agent_model.invoke(messages_with_system_prompt)
        # 도구 호출이 아닌, 최종 답변일 경우에만 제목을 추가합니다.
        if not response.tool_calls:
            response.content = "## 포트폴리오 조회 결과\n\n" + response.content

        return {"messages": [response], "turn_count": current_turn + 1}

    tool_node = ToolNode(db_tools)

    # --- 3-3. 조건부 엣지(Edge) 함수 정의 ---
    MAX_TURNS = 5
    def agent_router(state: AutonomousState):
        print("\n----- 🚦 ROUTER -----")
        if state.get("turn_count", 0) >= MAX_TURNS:
            print(f"⚠️ Safety Guard: 최대 반복 횟수({MAX_TURNS}회)를 초과하여 강제로 종료합니다.\n")
            return "end"

        last_message = state["messages"][-1]
        if last_message.tool_calls:
            print("분기: [call_tool] -> TOOLS 노드로 이동합니다.\n")
            return "call_tool"
        else:
            print("분기: [end] -> 최종 답변이 생성되어 종료합니다.\n")
            return "end"

    # --- 3-4. 그래프 구성 및 컴파일 ---
    workflow = StateGraph(AutonomousState)
    workflow.add_node("text_to_sql_agent", agent_node)
    workflow.add_node("db_tools", tool_node)

    workflow.set_entry_point("text_to_sql_agent")
    workflow.add_conditional_edges("text_to_sql_agent", agent_router, {"call_tool": "db_tools", "end": END})
    workflow.add_edge("db_tools", "text_to_sql_agent")

    return workflow.compile()


# --- 4. 메인 실행 함수 ---
async def main():
    # --- 4-1. 그래프 생성 함수 호출 ---
    app = await create_db_agent_graph()
    print("✅ 포트폴리오 Agent 그래프가 성공적으로 컴파일되었습니다.")

    # --- 4-2. 시각화 ---
    display_mermaid_graph(app, title="포트폴리오 DB 조회 Agent")

    # --- 4-3. Agent 실행 ---
    print("\n================ PortfolioAgent 테스트 실행 ================")
    inputs = {"messages": [HumanMessage(content="내 포트폴리오에 있는 모든 종목의 티커와 보유 수량을 알려줘.")], "turn_count": 0}

    async for event in app.astream(inputs, stream_mode="values"):
        last_message = event["messages"][-1]
        if isinstance(last_message, HumanMessage):
            print("\n++++++++++ 🙋‍♂️ USER INPUT ++++++++++")
            last_message.pretty_print()
        else:
            last_message.pretty_print()

# --- 5. 비동기 메인 함수 실행 ---
await main()
# Out:
# 📡 DB 서버에만 연결하는 MCP 클라이언트를 설정합니다...
# ✅ 포트폴리오 Agent용 도구 로딩 완료: ['sql_db_query', 'sql_db_schema', 'sql_db_list_tables', 'sql_db_query_checker']
# ✅ 포트폴리오 Agent 그래프가 성공적으로 컴파일되었습니다.
#
# 📊 [ 포트폴리오 DB 조회 Agent ]
#     <div style="background-color: white; border: 1px solid #ddd; padding: 10px; border-radius: 5px;">
#         <pre class="mermaid">---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	text_to_sql_agent(text_to_sql_agent)
# 	db_tools(db_tools)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> text_to_sql_agent;
# 	db_tools --> text_to_sql_agent;
# 	text_to_sql_agent -. &nbsp;end&nbsp; .-> __end__;
# 	text_to_sql_agent -. &nbsp;call_tool&nbsp; .-> db_tools;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
# </pre>
#     </div>
#     <script type="module">
#         import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.esm.min.mjs';
#         await mermaid.run();
#     </script>
# ================ PortfolioAgent 테스트 실행 ================
#
# ++++++++++ 🙋‍♂️ USER INPUT ++++++++++
# ================================ Human Message =================================
#
# 내 포트폴리오에 있는 모든 종목의 티커와 보유 수량을 알려줘.
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 1) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_list_tables (775ef8d6-0451-4897-a2e0-4c3ce432ad1d)
#  Call ID: 775ef8d6-0451-4897-a2e0-4c3ce432ad1d
#   Args:
#     tool_input:
# ================================= Tool Message =================================
# Name: sql_db_list_tables
#
# my_portfolio
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 2) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_schema (c62856bd-9c35-486b-973a-f0d285be65ad)
#  Call ID: c62856bd-9c35-486b-973a-f0d285be65ad
#   Args:
#     table_names: my_portfolio
# ================================= Tool Message =================================
# Name: sql_db_schema
#
#
# CREATE TABLE my_portfolio (
# 	id INTEGER,
# 	ticker TEXT NOT NULL,
# 	company_name TEXT NOT NULL,
# 	shares_owned INTEGER NOT NULL,
# 	purchase_price REAL NOT NULL,
# 	PRIMARY KEY (id),
# 	UNIQUE (ticker)
# )
#
# /*
# 3 rows from my_portfolio table:
# id	ticker	company_name	shares_owned	purchase_price
# 1	NVDA	NVIDIA Corp	50	120.5
# 2	AAPL	Apple Inc	100	185.75
# 3	TSLA	Tesla Inc	30	250.0
# */
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 3) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_query_checker (c4ab3993-5f95-4b55-83b6-b4ab8e62f0f4)
#  Call ID: c4ab3993-5f95-4b55-83b6-b4ab8e62f0f4
#   Args:
#     query: SELECT ticker, shares_owned FROM my_portfolio
# ================================= Tool Message =================================
# Name: sql_db_query_checker
#
# SELECT ticker, shares_owned FROM my_portfolio
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 4) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_query (9f17b761-7181-49db-a58a-bec2cbf1c599)
#  Call ID: 9f17b761-7181-49db-a58a-bec2cbf1c599
#   Args:
#     query: SELECT ticker, shares_owned FROM my_portfolio
# ================================= Tool Message =================================
# Name: sql_db_query
#
# [('NVDA', 50), ('AAPL', 100), ('TSLA', 30)]
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 5) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# ⚠️ Safety Guard: 최대 반복 횟수(5회)를 초과하여 강제로 종료합니다.
#
# ================================== Ai Message ==================================
#
# ## 포트폴리오 조회 결과
#
# 모든 종목의 티커와 보유 수량은 다음과 같습니다.
#
# * NVDA: 50주
# * AAPL: 100주
# * TSLA: 30주

# %% [markdown]
# # 🛑 포트폴리오 MCP 서버 종료
#
# 모든 작업이 완료되었으므로, 백그라운드에서 실행되던 **DB 서버(포트 8001)** 프로세스를 종료하여 시스템 자원을 정리합니다.

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
# --- 포트폴리오 MCP 서버 종료 (Port 8001) ---
stop_mcp_server(port=8001, service_name="포트폴리오 DB")
# Out:
# 🛑 포트폴리오 DB MCP 서버(Port: 8001)를 종료합니다...
# ✅ 포트폴리오 DB 서버가 종료되었습니다.

# %% [markdown]
# # 👑 Orchestrator: 전문가 Agent들을 지휘하는 상위 Agent
#
# 지금까지 만든 `금융 정보 Agent`와 `포트폴리오 DB 조회 Agent`를 각각의 전문가로 보고, 이 전문가들을 총괄하여 복잡한 임무를 수행하게 할 `상위 Agent(Orchestrator)`를 구축합니다.<br>
# 이는 **단일 Agent로는 해결하기 어려운 복잡한 문제를 여러 개의 단순한 하위 문제로 나누어 해결**할 수 있게 해주는 매우 강력한 계층적 접근 방식입니다.
#
# <br>
#
# ### 1. 하위 Agent를 '도구(Tool)'로 추상화
#
# > 가장 핵심적인 아이디어는, 앞서 만든 두 전문가 Agent를 **하나의 '도구(함수)'처럼** 만드는 것입니다.<br>
# 상위 Agent가 이 도구를 호출하면, 내부적으로는 해당 하위 Agent의 전체 워크플로우가 실행되고 그 최종 결과만 반환됩니다.
# >
# > ```python
# > @tool
# > async def financial_info_agent_tool(query: str) -> str:
# >     """금융 정보 분석 전문가 Agent를 호출하는 도구"""
# >     # 1. 하위 Agent 그래프 생성
# >     app = await create_financial_agent_graph()
# >     # 2. 하위 Agent 실행 및 결과 반환
# >     response = await app.ainvoke({"messages": [HumanMessage(content=query)], ...})
# >     return response['messages'][-1].content
# > ```
#
# ### 2. 상위 Agent (Orchestrator) 워크플로우
#
# > 상위 Agent는 '계획을 세우는 Agent'와 '최종 보고서를 작성하는 Reporter'의 역할로 나뉩니다.
# >
# > #### 2.1. 마스터 Agent (`orchestrator_agent_node`)
# >
# > > 사용자의 복잡한 질문을 받고, **어떤 전문가 Agent(도구)를 어떤 순서로 호출할지 계획**을 세우는 '마스터 Agent' 역할을 합니다. **한 번에 하나의 도구만 호출**하도록 규칙을 설정하여 신중하게 작업을 수행합니다.
# > >
# > > ```python
# > > system_prompt = """
# > > 당신은 전문가 팀을 이끄는 마스터 Agent입니다. 당신의 임무는 사용자의 복잡한 요청을 해결하기 위해, 가장 적합한 전문가 Agent(도구)를 순서대로 호출하는 것입니다.
# > > **매우 중요한 규칙:**
# > > 1. 당신은 도구를 반드시 **한 번에 하나씩만** 순서대로 호출해야 합니다.
# > > 2. **모든 정보 수집이 완료되었다고 판단되면, ... '모든 정보 수집 완료'라고만 답변하세요.**
# > > """
# > > ```
# >
# > #### 2.2. 최고 투자 책임자 (`orchestrator_report_node`)
# >
# > > 모든 하위 Agent들의 작업이 끝나면, 각 전문가가 가져온 정보들을 모두 모아 **'최고 투자 책임자(CIO)'의 관점에서 최종 종합 리포트를 작성**합니다.
# > >
# > > ```python
# > > report_prompt = f"""
# > > 당신은 최고 투자 책임자(CIO)입니다. 아래는 각 팀(하위 Agent)이 수집하고 분석한 투자 정보입니다.
# > >
# > > [각 팀의 분석 보고 내용]
# > > {dedented_history}
# > >
# > > ... 최종 종합 투자 리포트를 상세하고 명확하게 작성해주세요.
# > > """
# > > ```
#
# ### 3. 실행 및 결과 확인
#
# > 복잡한 사용자 질문("내 포트폴리오의 모든 종목에 대해 최신 주가와 부정적 뉴스를 종합해서 리포트 해줘")이 입력되면, 상위 Agent는 다음과 같이 행동합니다.
# >
# > 1.  **포트폴리오 DB 조회 Agent**를 호출하여 포트폴리오에 어떤 종목이 있는지 파악합니다.
# > 2.  알아낸 각 종목에 대해 **금융 정보 Agent**를 순서대로 호출하여 주가와 뉴스를 분석합니다.
# > 3.  모든 정보가 취합되면, 최종 리포트 노드가 **종합적인 투자 리포트를 생성**하며 프로세스를 완료합니다.

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
# --- 1. 금융 정보 MCP 서버 시작 및 확인 (Port 8000) ---
start_mcp_server(
    script_name="search_server.py",
    port=8000,
    log_file="search_server.log",
    service_name="금융 정보"
)

print("\n" + "="*40 + "\n")

# --- 2. 포트폴리오 MCP 서버 시작 및 확인 (Port 8001) ---
start_mcp_server(
    script_name="db_server.py",
    port=8001,
    log_file="db_server.log",
    service_name="포트폴리오 DB"
)

print("\n" + "="*40)
print("✅ 모든 MCP 서버 시작 작업이 완료되었습니다.")
print("   각 서버의 최종 상태를 위 로그에서 확인하세요.")
# Out:
# 🚀 금융 정보 MCP 서버를 시작합니다... (Port: 8000)
# ⏱️  서버 시작 대기 중... (최대 30초)
# ------------------------------
# ✅ 금융 정보 MCP 서버가 성공적으로 시작되어 실행 중입니다.
#    (로그 파일: /content/search_server.log)
#
# ========================================
#
# 🚀 포트폴리오 DB MCP 서버를 시작합니다... (Port: 8001)
# ⏱️  서버 시작 대기 중... (최대 30초)
# ------------------------------
# ✅ 포트폴리오 DB MCP 서버가 성공적으로 시작되어 실행 중입니다.
#    (로그 파일: /content/db_server.log)
#
# ========================================
# ✅ 모든 MCP 서버 시작 작업이 완료되었습니다.
#    각 서버의 최종 상태를 위 로그에서 확인하세요.

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
# --- 1. 필요한 모든 모듈 임포트 ---
import asyncio
import operator
import textwrap
from typing import List, TypedDict, Annotated

from langchain_core.tools import tool
from langchain_core.messages import BaseMessage, HumanMessage, SystemMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph, END
from langgraph.prebuilt import ToolNode


# --- 2. 하위 Agent를 호출하는 '도구(Tool)' 함수 정의 ---
@tool
async def financial_info_agent_tool(query: str) -> str:
    """
    특정 회사에 대한 최신 주가, 뉴스, 사업 개요 등 금융 정보를 상세히 분석하고 리포트를 작성할 때 사용합니다.
    예: '삼성전자 주가와 최신 AI 관련 뉴스 알려줘'
    """
    print(f"\n>>>> [호출] 금융 정보 Agent (입력: {query})")
    app = await create_financial_agent_graph() # 이전 단계에서 정의한 금융 정보 조회 에이전트를 재사용합니다.
    response = await app.ainvoke({"messages": [HumanMessage(content=query)], "turn_count": 0})
    print("<<<< [완료] 금융 정보 Agent")
    return response["messages"][-1].content

@tool
async def portfolio_db_agent_tool(query: str) -> str:
    """
    사용자의 개인 주식 포트폴리오 데이터베이스를 조회할 때 사용합니다.
    보유 종목, 수량, 매수 가격 등의 정보를 확인할 수 있습니다.
    예: '내 포트폴리오에 있는 모든 종목 알려줘'
    """
    print(f"\n>>>> [호출] DB 조회 Agent (입력: {query})")
    app = await create_db_agent_graph() # 이전 단계에서 정의한 포트폴리오 DB 조회 에이전트를 재사용합니다.
    response = await app.ainvoke({"messages": [HumanMessage(content=query)], "turn_count": 0})
    print("<<<< [완료] DB 조회 Agent")
    return response["messages"][-1].content



# --- 3. 상위 Agent (Orchestrator) 워크플로우 구축 ---
async def create_orchestrator_graph():
    """
    'Agent + Reporter' 구조를 가진 상위 Orchestrator 그래프를 생성합니다.
    """
    # 상위 Agent가 사용할 도구 목록
    orchestrator_tools = [financial_info_agent_tool, portfolio_db_agent_tool]

    # 상위 Agent용 LLM 설정
    orchestrator_llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0).bind_tools(orchestrator_tools)
    reporting_llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.5)

    # 상위 Agent의 상태 정의
    class OrchestratorState(TypedDict):
        messages: Annotated[List[BaseMessage], operator.add]
        turn_count: int

    # --- 노드 정의 ---
    def orchestrator_agent_node(state: OrchestratorState):
        """Orchestrator의 계획 및 도구 호출 담당 노드"""
        current_turn = state.get("turn_count", 0)
        print(f"\n\n++++++++++ 👑 ORCHESTRATOR AGENT (Turn {current_turn + 1}) ++++++++++")
        print("사용자의 복합 질문을 분석하고, 어떤 전문가 Agent를 호출할지 계획을 세웁니다...")
        system_prompt = """
        당신은 전문가 팀을 이끄는 마스터 Agent입니다. 당신의 임무는 사용자의 복잡한 요청을 해결하기 위해, 가장 적합한 전문가 Agent(도구)를 순서대로 호출하는 것입니다.
        **매우 중요한 규칙:**
        1. 당신은 도구를 반드시 **한 번에 하나씩만** 순서대로 호출해야 합니다.
        2. **포트폴리오의 모든 종목에 대한 정보 수집이 완료되었다고 판단되면, 더 이상 도구를 호출하지 말고 '모든 정보 수집 완료'라고만 답변하세요.**
        """
        response = orchestrator_llm.invoke([SystemMessage(content=system_prompt), *state["messages"]])
        return {"messages": [response], "turn_count": current_turn + 1}

    def orchestrator_report_node(state: OrchestratorState):
        """모든 하위 Agent의 결과물을 종합하여 최종 리포트를 생성하는 노드"""
        print("\n\n++++++++++ 💎 ORCHESTRATOR REPORTER ++++++++++")
        print("모든 전문가 Agent의 분석 결과를 종합하여 최종 리포트를 작성합니다...")
        report_history = [msg for msg in state["messages"] if not isinstance(msg, HumanMessage)]
        history_str = "\n".join([msg.pretty_repr() for msg in report_history])
        dedented_history = textwrap.dedent(history_str)
        initial_query = state["messages"][0].content

        report_prompt = f"""
        당신은 최고 투자 책임자(CIO)입니다. 아래는 각 팀(하위 Agent)이 수집하고 분석한 투자 정보입니다.

        [각 팀의 분석 보고 내용]
        {dedented_history}

        [초기 사용자 요청]
        {initial_query}

        위 정보를 모두 종합하여, 사용자의 초기 요청에 대한 최종 종합 투자 리포트를 상세하고 명확하게 작성해주세요.
        각 종목별 분석 내용을 먼저 요약하고, 마지막에 종합적인 결론과 투자 전략을 제시해주세요.
        """
        final_report = reporting_llm.invoke(report_prompt)
        return {"messages": [final_report]}

    # --- 라우터 정의 ---
    MAX_ORCHESTRATOR_TURNS = 10 # Orchestrator의 최대 실행 횟수 정의
    def orchestrator_router(state: OrchestratorState):
        """Orchestrator Agent의 다음 행동을 결정하는 라우터"""
        print("\n----- 🚦 ORCHESTRATOR ROUTER -----")

        # 최대 실행 횟수를 초과했는지 먼저 확인합니다.
        if state.get("turn_count", 0) >= MAX_ORCHESTRATOR_TURNS:
            print(f"⚠️ Safety Guard: 최대 반복 횟수({MAX_ORCHESTRATOR_TURNS}회)를 초과하여 강제로 리포트 생성을 시작합니다.\n")
            return "generate_report"

        last_message = state["messages"][-1]
        if last_message.tool_calls:
            print("분기: [call_tool] -> 하위 Agent(Tool)를 호출합니다.\n")
            return "call_tool"
        else:
            print("분기: [generate_report] -> 최종 리포트 생성을 시작합니다.\n")
            return "generate_report"

    # --- 그래프 구성 ---
    workflow = StateGraph(OrchestratorState)
    workflow.add_node("orchestrator_agent", orchestrator_agent_node)
    workflow.add_node("agent_as_tools", ToolNode(orchestrator_tools))
    workflow.add_node("reporter", orchestrator_report_node)

    workflow.set_entry_point("orchestrator_agent")
    workflow.add_edge("agent_as_tools", "orchestrator_agent")
    workflow.add_edge("reporter", END)

    # agent의 결과에 따라 tools로 가거나 reporter로 가도록 조건부 엣지 설정
    workflow.add_conditional_edges(
        "orchestrator_agent",
        orchestrator_router,
        {"call_tool": "agent_as_tools", "generate_report": "reporter"}
    )

    orchestrator_app = workflow.compile()
    print("\n🎉 'Agent + Reporter' 구조의 상위 Agent가 성공적으로 컴파일되었습니다.")
    return orchestrator_app


# --- 4. 상위 Agent 실행 ---
async def run_orchestrator():
    print("\n🚀 상위 Agent 실행을 시작합니다...")
    orchestrator_app = await create_orchestrator_graph()

    # --- 4-2. 시각화 ---
    display_mermaid_graph(orchestrator_app, title="Orchestrator (상위 Agent)")

    complex_query = "내 포트폴리오에 있는 모든 종목의 현재 상황에 대해 알려줘. 종목별 최신 주가와 부정적인 뉴스가 있는지 각각 확인해서 종합 리포트를 작성해줘."
    inputs = {"messages": [HumanMessage(content=complex_query)], "turn_count": 0}

    print("\n\n================ Orchestrator Agent 모델 실행 ================")
    print("\n++++++++++ 🙋‍♂️ USER INPUT ++++++++++")
    inputs["messages"][0].pretty_print()

    # 각 노드의 출력을 순서대로 처리
    async for update in orchestrator_app.astream(inputs, stream_mode="updates"):
        # update는 {'node_name': {'key': 'value'}} 형태의 딕셔너리
        node_name = list(update.keys())[0]
        node_output = list(update.values())[0]

        if node_name == "orchestrator_agent":
            # agent 노드의 AiMessage (계획 또는 최종 답변)를 출력
            print(f"\n--- 👑 ORCHESTRATOR AGENT ---")
            node_output['messages'][-1].pretty_print()

        elif node_name == "agent_as_tools":
            # tools 노드는 ToolMessage 리스트를 반환
            print("\n--- 🛠️ TOOLS ---")
            for tool_message in node_output['messages']:
                tool_message.pretty_print()

        elif node_name == "reporter":
            # reporter 노드의 최종 결과 AiMessage를 출력
            print("\n--- 💎 ORCHESTRATOR REPORTER ---")
            node_output['messages'][-1].pretty_print()

    print("\n✅ Orchestrator 실행이 완료되었습니다.")

# 비동기 함수 실행
await run_orchestrator()
# Out:
# 🚀 상위 Agent 실행을 시작합니다...
#
# 🎉 'Agent + Reporter' 구조의 상위 Agent가 성공적으로 컴파일되었습니다.
#
# 📊 [ Orchestrator (상위 Agent) ]
#     <div style="background-color: white; border: 1px solid #ddd; padding: 10px; border-radius: 5px;">
#         <pre class="mermaid">---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	orchestrator_agent(orchestrator_agent)
# 	agent_as_tools(agent_as_tools)
# 	reporter(reporter)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> orchestrator_agent;
# 	agent_as_tools --> orchestrator_agent;
# 	orchestrator_agent -. &nbsp;call_tool&nbsp; .-> agent_as_tools;
# 	orchestrator_agent -. &nbsp;generate_report&nbsp; .-> reporter;
# 	reporter --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
# </pre>
#     </div>
#     <script type="module">
#         import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.esm.min.mjs';
#         await mermaid.run();
#     </script>
# ================ Orchestrator Agent 모델 실행 ================
#
# ++++++++++ 🙋‍♂️ USER INPUT ++++++++++
# ================================ Human Message =================================
#
# 내 포트폴리오에 있는 모든 종목의 현재 상황에 대해 알려줘. 종목별 최신 주가와 부정적인 뉴스가 있는지 각각 확인해서 종합 리포트를 작성해줘.
#
#
# ++++++++++ 👑 ORCHESTRATOR AGENT (Turn 1) ++++++++++
# 사용자의 복합 질문을 분석하고, 어떤 전문가 Agent를 호출할지 계획을 세웁니다...
#
# ----- 🚦 ORCHESTRATOR ROUTER -----
# 분기: [call_tool] -> 하위 Agent(Tool)를 호출합니다.
#
#
# --- 👑 ORCHESTRATOR AGENT ---
# ================================== Ai Message ==================================
# Tool Calls:
#   portfolio_db_agent_tool (30240c60-250a-4160-baf0-2bab98cb827c)
#  Call ID: 30240c60-250a-4160-baf0-2bab98cb827c
#   Args:
#     query: 내 포트폴리오에 있는 모든 종목 알려줘
#
# >>>> [호출] DB 조회 Agent (입력: 내 포트폴리오에 있는 모든 종목 알려줘)
# 📡 DB 서버에만 연결하는 MCP 클라이언트를 설정합니다...
# ✅ 포트폴리오 Agent용 도구 로딩 완료: ['sql_db_query', 'sql_db_schema', 'sql_db_list_tables', 'sql_db_query_checker']
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 1) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 2) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
#
# ++++++++++ 🤖 PORTFOLIO AGENT (Turn 3) ++++++++++
# DB 조회를 위해 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [end] -> 최종 답변이 생성되어 종료합니다.
#
# <<<< [완료] DB 조회 Agent
#
# --- 🛠️ TOOLS ---
# ================================= Tool Message =================================
# Name: portfolio_db_agent_tool
#
# ## 포트폴리오 조회 결과
#
# 내 포트폴리오에는 NVDA, AAPL, TSLA 세 종목이 있습니다.
#
#
# ++++++++++ 👑 ORCHESTRATOR AGENT (Turn 2) ++++++++++
# 사용자의 복합 질문을 분석하고, 어떤 전문가 Agent를 호출할지 계획을 세웁니다...
#
# ----- 🚦 ORCHESTRATOR ROUTER -----
# 분기: [call_tool] -> 하위 Agent(Tool)를 호출합니다.
#
#
# --- 👑 ORCHESTRATOR AGENT ---
# ================================== Ai Message ==================================
# Tool Calls:
#   financial_info_agent_tool (af4156d6-33e4-4e7d-aefa-c8a858cc3342)
#  Call ID: af4156d6-33e4-4e7d-aefa-c8a858cc3342
#   Args:
#     query: NVDA 최신 주가와 부정적인 뉴스 알려줘
#
# >>>> [호출] 금융 정보 Agent (입력: NVDA 최신 주가와 부정적인 뉴스 알려줘)
# 📡 MCP 클라이언트를 HTTP 방식으로 설정합니다...
# ✅ 로딩된 도구: ['get_stock_price', 'get_latest_news', 'get_company_overview', 'get_analyst_opinions']
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 1) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 2) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [generate_report] -> REPORTER 노드로 이동합니다.
#
#
# ++++++++++ ✍️ FINANCIAL REPORTER ++++++++++
# 수집된 모든 정보를 종합하여 최종 리포트를 작성합니다...
# <<<< [완료] 금융 정보 Agent
#
# --- 🛠️ TOOLS ---
# ================================= Tool Message =================================
# Name: financial_info_agent_tool
#
# ## 엔비디아(NVDA) 투자 리포트
#
# **작성일:** 2025년 10월 31일
# **작성자:** 전문 애널리스트
#
# ---
#
# ### **[요약]**
#
# 엔비디아(NVDA)는 인공지능(AI) 산업의 핵심 플레이어로서 강력한 시장 지위를 유지하고 있으며, 최근 주가 또한 긍정적인 상승 추세를 보였습니다. AI 성장론과 미중 정상회담 등 긍정적인 거시경제 요인이 투자 심리를 확대하고 있습니다. 그러나 최근 GPU 공급 관련한 투자자들의 부정적 시각과 밸류에이션에 대한 논란이 존재하여, 투자 결정에 있어 신중한 접근이 요구됩니다. 단기적인 시장 변동성과 루머에 대한 모니터링이 필요하며, 장기적인 AI 성장 모멘텀은 여전히 유효합니다.
#
# ---
#
# ### **1. 현재 주가 및 최근 동향**
#
# *   **현재 주가:** 2025년 10월 29일 기준, 엔비디아(NVDA)의 주가는 **$207.04**를 기록했습니다. (참고: 실시간 시세는 $202.49-$202.61 수준으로 변동될 수 있습니다.)
# *   **최근 주가 추이 (2025년 10월 13일 ~ 10월 29일):**
#     *   10월 중순 $180 초반대에서 시작하여 꾸준히 상승, 10월 말에는 $207.04까지 도달하며 뚜렷한 상승 모멘텀을 보여주었습니다. 이는 약 2주간 10% 이상의 상승률을 기록한 것입니다.
# *   **시장 분위기:** 전반적으로 주간 상승 모멘텀이 이어지고 있으며, 이번 주 실적 발표에 대한 기대감이 지속되고 있습니다.
#
# ---
#
# ### **2. 주요 시장 동인 및 거시 환경**
#
# *   **긍정적 요인:**
#     *   **AI 성장론:** 인공지능 산업의 폭발적인 성장이 엔비디아의 핵심 성장 동력으로 작용하며, 투자 심리를 크게 확대하고 있습니다.
#     *   **미중 정상회담:** 미중 정상회담 개최 소식은 글로벌 경제의 불확실성을 일부 해소하며 투자 심리에 긍정적인 영향을 미친 것으로 보입니다.
# *   **중립/혼재 요인:**
#     *   **연준 파월 의장의 매파적 발언 소화:** 미국 연방준비제도(Fed) 파월 의장의 매파적 발언은 시장에 부담으로 작용할 수 있으나, 현재 시장은 이를 "소화"하며 전반적인 상승 모멘텀을 유지하려는 경향을 보입니다.
#
# ---
#
# ### **3. 회사 관련 뉴스 및 투자 심리**
#
# *   **긍정적 측면:**
#     *   AI 산업의 핵심 기술 제공자로서의 독보적인 위치는 엔비디아의 장기적인 성장 잠재력을 뒷받침합니다.
#     *   일부 투자자들은 현재 주가 수준을 여전히 "저평가 구간"으로 판단하며 추가 상승 여력이 있다고 보고 있습니다.
# *   **부정적/회의적 측면:**
#     *   **GPU 공급 관련 의혹:** "없어서 못 판다"는 GPU를 국내에 26만장 우선 공급한다는 소식에 대해 일부 투자자들은 "땡처리", "끝물에 최고가에 떠넘기려는 것"이라는 강한 의혹을 제기하고 있습니다. 이는 회사의 투명성과 향후 실적에 대한 우려를 낳을 수 있습니다.
#     *   **실적 부풀리기 의혹:** 하청업체에 매입을 시켜 실적을 올리는 방식에 대한 비판적인 시각이 존재하며, 삼성전자와의 관계 및 삼성전자의 향후 실적 전망에 대해서도 회의적인 의견이 제기되었습니다.
#     *   **높은 밸류에이션 논란:** 현재 주가가 역사적 고점 부근에 위치하고 있어, 추가 상승 여력에 대한 이견이 존재합니다.
#
# ---
#
# ### **4. 리스크 요인**
#
# *   **투자자 심리 악화:** GPU 공급 관련 의혹이나 실적 부풀리기 루머가 확산될 경우, 투자 심리 위축 및 주가 하락으로 이어질 수 있습니다.
# *   **밸류에이션 부담:** AI 산업의 높은 성장 기대감이 주가에 선반영된 만큼, 예상치 못한 실적 부진이나 경쟁 심화 시 급격한 조정이 발생할 수 있습니다.
# *   **거시 경제 불확실성:** 연준의 통화 정책, 글로벌 지정학적 리스크 등 거시 경제 변동성은 언제든 주가에 부정적인 영향을 미칠 수 있습니다.
# *   **경쟁 심화:** AMD 등 경쟁사들의 추격과 자체 AI 칩 개발 움직임은 엔비디아의 시장 점유율에 장기적인 위협이 될 수 있습니다.
#
# ---
#
# ### **5. 투자 제언**
#
# 엔비디아는 AI 시대의 핵심 수혜주로서 강력한 성장 잠재력을 보유하고 있으며, 최근 주가도 긍정적인 흐름을 보였습니다. 그러나 최근 제기된 GPU 공급 관련 의혹과 일부 투자자들의 회의적인 시각은 단기적인 변동성을 확대시킬 수 있는 요인입니다.
#
# *   **신규 투자자:** 현재 혼재된 투자 심리와 밸류에이션 부담을 고려할 때, **'관망(Hold)'** 포지션을 유지하며 시장의 추가적인 정보와 실적 발표를 기다리는 것이 현명하다고 판단됩니다. 특히 GPU 공급 관련 논란에 대한 명확한 해명이 나올 때까지는 보수적인 접근이 필요합니다.
# *   **기존 투자자:** AI 성장론에 대한 장기적인 믿음이 있다면 보유를 유지할 수 있으나, 최근 주가 상승을 감안하여 일부 **'차익 실현(Partial Profit-Taking)'**을 고려하여 리스크를 관리하는 것도 좋은 전략입니다.
#
# **주요 모니터링 포인트:**
# 1.  향후 실적 발표 내용 및 가이던스
# 2.  GPU 공급 관련 의혹에 대한 회사 측의 공식 입장
# 3.  거시 경제 지표 및 연준의 통화 정책 방향
# 4.  경쟁사들의 AI 칩 개발 동향
#
# ---
#
# **면책 조항:** 본 리포트는 제공된 정보에 기반한 전문 애널리스트의 의견이며, 투자 권유를 목적으로 하지 않습니다. 모든 투자 결정은 투자자 본인의 판단과 책임 하에 이루어져야 합니다.
#
#
# ++++++++++ 👑 ORCHESTRATOR AGENT (Turn 3) ++++++++++
# 사용자의 복합 질문을 분석하고, 어떤 전문가 Agent를 호출할지 계획을 세웁니다...
#
# ----- 🚦 ORCHESTRATOR ROUTER -----
# 분기: [call_tool] -> 하위 Agent(Tool)를 호출합니다.
#
#
# --- 👑 ORCHESTRATOR AGENT ---
# ================================== Ai Message ==================================
# Tool Calls:
#   financial_info_agent_tool (583f03b7-6c86-4e5d-be3f-0a4966d436c3)
#  Call ID: 583f03b7-6c86-4e5d-be3f-0a4966d436c3
#   Args:
#     query: AAPL 최신 주가와 부정적인 뉴스 알려줘
#
# >>>> [호출] 금융 정보 Agent (입력: AAPL 최신 주가와 부정적인 뉴스 알려줘)
# 📡 MCP 클라이언트를 HTTP 방식으로 설정합니다...
# ✅ 로딩된 도구: ['get_stock_price', 'get_latest_news', 'get_company_overview', 'get_analyst_opinions']
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 1) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 2) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [generate_report] -> REPORTER 노드로 이동합니다.
#
#
# ++++++++++ ✍️ FINANCIAL REPORTER ++++++++++
# 수집된 모든 정보를 종합하여 최종 리포트를 작성합니다...
# <<<< [완료] 금융 정보 Agent
#
# --- 🛠️ TOOLS ---
# ================================= Tool Message =================================
# Name: financial_info_agent_tool
#
# ## 애플(AAPL) 투자 리포트: 과열된 주가 속 잠재적 위험 요인 분석
#
# **작성일:** 2024년 10월 27일 (정보 수집 시점 기준)
# **분석 대상:** Apple Inc. (NASDAQ: AAPL)
# **현재 주가:** $271.40 (직전 24시간 대비 0.63% 상승)
#
# ---
#
# ### 1. 현재 주가 및 시장 동향
#
# 애플(AAPL)의 주가는 현재 $271.40를 기록하며, 지난 24시간 동안 0.63% 상승했습니다. 최근 몇 주간 꾸준히 상승세를 보이며 사상 최고치에 근접한 수준입니다. 이는 단기적으로 긍정적인 시장 분위기를 반영하는 것으로 보입니다. 일부 전문 트레이더 및 시장 전문가들의 분석에 따르면, 애플 주식은 $275.00, 나아가 $285.00까지 상승할 잠재력이 있는 것으로 예측되기도 합니다. 애플은 10월 30일 장 마감 후 2025 회계연도 4분기 실적을 발표할 예정이며, 이는 주가에 중요한 변곡점이 될 수 있습니다.
#
# ### 2. 주요 하방 리스크 및 부정적 요인
#
# 그러나 이러한 단기적인 상승세에도 불구하고, 애플 주식에 대한 심각한 하방 리스크와 부정적 의견이 제기되고 있습니다.
#
# *   **'매도' 등급 하향 조정 및 목표가 하향:** MoffettNathanson의 수석 애널리스트 크레이그 모펫은 애플 주식에 대한 투자 등급을 '중립'에서 '매도'로 하향 조정했습니다. 모펫은 애플 주가가 지나치게 높게 평가받고 있으며, 현재의 시장 환경에서 투자 대비 위험-보상 구조가 매력적이지 않다고 지적했습니다. 그는 목표가를 $188로 제시했으며, 이는 현재 주가($271.40) 대비 약 **30% 이상의 하락 가능성**을 의미합니다.
#
# *   **과도한 가치 평가 논란:** 모펫은 최근 주가 상승이 "압도적으로 부정적인 뉴스와 대조되는 비정상적인 흐름"이라고 평가하며, 현재의 주가 수준이 기업의 본질적 가치를 초과하고 있다고 분석했습니다.
#
# *   **핵심 사업 관련 부정적 뉴스:**
#     *   **검색 엔진 계약 문제:** 연방 법원이 구글이 애플에 매년 250억 달러를 지불하며 아이폰 기본 검색 엔진 지위를 유지하는 것이 불법이라고 판결했습니다. 이는 애플의 수익 구조에 중대한 리스크로 작용할 수 있습니다.
#     *   **중국 시장 판매 부진:** 중국 내 아이폰 판매가 기대에 미치지 못하고 있으며, 이는 애플의 글로벌 매출 성과에 부정적인 영향을 미 미치고 있습니다.
#     *   **신제품 성과 미비 및 AI 기능에 대한 회의론:** 최신 기술 제품인 비전 프로 헤드셋이 시장에서 기대 이하의 성과를 보였고, 아이폰 16 판매 또한 부진한 상황입니다. 특히, 아이폰 16에 탑재된 새로운 AI 기능이 소비자들에게 큰 매력을 주지 못하고 있으며, 이는 애플의 기술 혁신 및 업그레이드 주기에 대한 우려를 낳고 있습니다.
#
# ### 3. 종합 분석 및 투자 의견
#
# 애플 주식은 단기적으로 강력한 상승 모멘텀을 유지하며 사상 최고치에 근접하고 있습니다. 일부 분석은 추가적인 상승 여력을 제시하고 있으며, 다가오는 실적 발표는 긍정적 또는 부정적 촉매제가 될 수 있습니다.
#
# 그러나 이러한 표면적인 강세 이면에는 MoffettNathanson과 같은 주요 투자 기관의 '매도' 의견과 함께 심각한 사업적 리스크들이 존재합니다. 구글과의 검색 엔진 계약 문제, 핵심 시장인 중국에서의 부진, 신제품 및 AI 기능에 대한 시장의 미온적인 반응 등은 애플의 장기적인 성장 동력에 대한 우려를 증폭시키고 있습니다. 애널리스트는 현재 주가 수준이 과도하게 고평가되어 있으며, 위험 대비 보상 비율이 매력적이지 않다고 판단하고 있습니다.
#
# ### 4. 결론 및 권고
#
# 애플(AAPL)에 대한 투자는 현재 매우 상반된 신호 속에서 신중한 접근이 요구됩니다.
#
# *   **단기 투자자:** 단기적인 기술적 상승 여력과 실적 발표 모멘텀을 노릴 수 있으나, 급격한 하락 위험에 대비한 엄격한 손절매(예: S1=$258.00, S2=$252.00) 설정이 필수적입니다.
# *   **장기 투자자:** 현재의 주가 수준은 주요 애널리스트에 의해 과도하게 고평가된 것으로 판단되며, 핵심 사업 부문의 잠재적 리스크가 상당합니다. 따라서, 현재 시점에서의 신규 진입은 매우 보수적으로 접근하거나 보류하는 것을 권고합니다. 부정적 뉴스들이 해소되고, 실적 발표를 통해 명확한 성장 동력이 확인될 때까지 관망하는 것이 현명할 수 있습니다.
#
# **결론적으로, 애플은 여전히 훌륭한 기업이지만, 현재 주가는 여러 부정적인 요인들을 충분히 반영하지 못하고 과열되어 있을 가능성이 높습니다. 투자 결정 시에는 단기적인 시장 분위기보다는 기업의 근본적인 가치와 잠재적 리스크를 종합적으로 고려하여 매우 신중하게 접근하시길 바랍니다.**
#
#
# ++++++++++ 👑 ORCHESTRATOR AGENT (Turn 4) ++++++++++
# 사용자의 복합 질문을 분석하고, 어떤 전문가 Agent를 호출할지 계획을 세웁니다...
#
# ----- 🚦 ORCHESTRATOR ROUTER -----
# 분기: [call_tool] -> 하위 Agent(Tool)를 호출합니다.
#
#
# --- 👑 ORCHESTRATOR AGENT ---
# ================================== Ai Message ==================================
# Tool Calls:
#   financial_info_agent_tool (ac928933-26fd-4b29-ad01-120353ab05a7)
#  Call ID: ac928933-26fd-4b29-ad01-120353ab05a7
#   Args:
#     query: TSLA 최신 주가와 부정적인 뉴스 알려줘
#
# >>>> [호출] 금융 정보 Agent (입력: TSLA 최신 주가와 부정적인 뉴스 알려줘)
# 📡 MCP 클라이언트를 HTTP 방식으로 설정합니다...
# ✅ 로딩된 도구: ['get_stock_price', 'get_latest_news', 'get_company_overview', 'get_analyst_opinions']
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 1) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [call_tool] -> TOOLS 노드로 이동합니다.
#
#
# ++++++++++ 🤖 FINANCIAL AGENT (Turn 2) ++++++++++
# 사용자 요청과 이전 기록을 바탕으로 다음 행동을 결정합니다...
#
# ----- 🚦 ROUTER -----
# 분기: [generate_report] -> REPORTER 노드로 이동합니다.
#
#
# ++++++++++ ✍️ FINANCIAL REPORTER ++++++++++
# 수집된 모든 정보를 종합하여 최종 리포트를 작성합니다...
# <<<< [완료] 금융 정보 Agent
#
# --- 🛠️ TOOLS ---
# ================================= Tool Message =================================
# Name: financial_info_agent_tool
#
# ## 테슬라(TSLA) 투자 리포트: 현재 주가 및 시장 심리 분석
#
# **작성일:** 2024년 12월 18일 (정보 수집 기록에 기반)
# **애널리스트:** [전문 애널리스트]
#
# ---
#
# ### **1. 요약 (Executive Summary)**
#
# 테슬라(TSLA)는 현재 460달러 수준에서 거래되고 있으며, 최근 52주 고점인 488.54달러에 근접한 수준을 유지하고 있습니다. 시장은 테슬라의 전기차 판매 성장 둔화, 마진 압박, 신규 모델 부재 등에 대한 우려를 표하고 있으나, 동시에 FSD(Full Self-Driving), 옵티머스 로봇, 에너지 사업 등 미래 성장 동력에 대한 잠재력은 여전히 높게 평가되고 있습니다.
#
# 다만, 일부 분석가들은 언론의 부정적인 편향과 단편적인 정보에 기반한 평가가 테슬라의 본질적인 혁신을 간과하고 있다고 주장하며, 시장의 시각에 대한 비판적인 관점도 존재합니다. 본 리포트는 테슬라의 현재 주가, 시장의 주요 우려 사항, 그리고 미래 성장 동력에 대한 상반된 시각을 분석하여 투자 결정에 도움을 드리고자 합니다.
#
# ---
#
# ### **2. 현재 주가 및 시장 동향**
#
# *   **현재 주가:** 약 461.51 달러 (변동폭 내)
# *   **직전 종가 (Prev Close):** 460.55 달러
# *   **일중 변동폭 (Day Range):** 452.65 달러 ~ 465.70 달러
# *   **52주 최고가 (52 Week High):** 488.54 달러 (2024년 12월 18일)
# *   **52주 최저가 (52 Week Low):** 214.25 달러 (2025년 4월 7일)
#     *   *참고: 52주 최고가와 최저가 날짜 순서가 일반적인 기준과 다소 상이하나, 제공된 데이터를 기준으로 작성되었습니다. 이는 테슬라 주가의 높은 변동성을 시사합니다.*
#
# 테슬라 주가는 최근 52주 최고가에 근접한 수준에서 거래되고 있으며, 상당한 변동성을 동반하고 있습니다. 시장은 테슬라의 단기 실적과 장기적인 성장 동력 사이에서 복합적인 심리를 보이고 있습니다.
#
# ---
#
# ### **3. 테슬라에 대한 시장의 주요 우려 (부정적 시각)**
#
# 월가 애널리스트 및 언론에서 주로 제기되는 테슬라에 대한 부정적인 시각은 다음과 같습니다.
#
# *   **성장 둔화 우려:**
#     *   **시장 점유율 하락:** 중국 BYD, 유럽 프리미엄 브랜드, 북미 포드/GM 등 경쟁 심화로 인한 전기차 시장 점유율 하락 가능성.
#     *   **제품 라인업 노후화:** 2020년 모델 Y 이후 신규 양산 모델 부재 및 25,000달러 모델 출시 지연.
#     *   **수익성 악화:** 매출총이익률이 32.9%에서 19.3%로 급락했으며, 6차례 가격 인하로 인한 마진 압박 지속.
# *   **과도한 밸류에이션 논란:**
#     *   **높은 PER:** 자동차 업계 평균(6-8배) 대비 현저히 높은 87배의 PER(주가수익비율).
#     *   **미래 가치 선반영:** 로보택시, 옵티머스 로봇, 에너지 사업 등 미래 사업의 성공 가능성이 이미 주가에 과도하게 반영되었다는 지적.
#     *   **경쟁사 대비 시가총액:** BYD의 판매량(302만대)이 테슬라(181만대)를 앞섬에도 불구하고, 테슬라의 시가총액이 10배 이상 높은 점을 근거로 과대평가 주장이 제기됩니다.
# *   **구조적 리스크 과장:** 특정 사고나 부정적 이슈가 과장되어 보도되는 경향.
#
# ---
#
# ### **4. 미래 성장 동력 및 긍정적 시각**
#
# 위에서 언급된 시장의 부정적 시각에 대한 비판적 관점에서는, 테슬라의 본질적인 혁신과 미래 성장 동력이 간과되고 있다고 주장합니다.
#
# *   **FSD(Full Self-Driving) 발전:**
#     *   **엣지케이스 해결 능력:** 공사 구간, 응급차량 대응 등 복잡한 상황 처리 능력 개선.
#     *   **사용자 만족도 급상승:** FSD 구독자 90% 이상 리뉴얼률을 통해 높은 만족도 확인.
#     *   **애널리스트의 긍정적 평가:** 모건스탠리의 아담 조나스 애널리스트는 FSD를 직접 체험 후 "게임 체인저"로 평가하며, 1,400마일 왕복 구간의 99%를 자율 처리했다고 언급. FSD 구독료 8,000달러를 18개월 사용 기준 "바겐(bargain)"으로 평가.
# *   **옵티머스 로봇의 잠재력:**
#     *   **하드웨어 혁신:** 액추에이터, 손 구조 등 기계공학적 혁신.
#     *   **AI 인퍼런스 능력:** 실시간 환경 인식 및 작업 수행 능력의 급속한 발전.
#     *   **제조 비용 혁신:** 대량생산 시 원가 절감 가능성 및 인력 부족 시대 로봇 수요 폭증에 따른 거대한 시장 잠재력.
# *   **에너지 사업:** 로보택시, 옵티머스와 함께 미래 핵심 성장 동력으로 언급되나, 시장에서 충분히 평가받지 못하고 있다는 지적.
#
# ---
#
# ### **5. 애널리스트 및 언론의 정보 편향성 지적**
#
# 일부에서는 월가 애널리스트와 언론이 테슬라의 혁신을 제대로 평가하지 못하고 있다는 비판적인 시각이 제기됩니다.
#
# *   **2차 자료 의존증:** 실제 체험보다 뉴스 기사나 보고서에 의존하며, 기자들 또한 실제 체험 없이 기사를 작성하고 애널리스트들이 이를 바탕으로 평가하는 악순환. 경쟁사 PR 자료를 여과 없이 수용하는 경향.
# *   **부정적 뉴스 편향:** 자극적인 사고 소식은 크게 보도하고, 점진적인 개선 사항이나 긍정적 변화는 간과하는 문제.
# *   **단편적 데이터:** 전체 맥락 없이 일부 지표만으로 판단하는 오류.
#
# 이러한 편향이 테슬라의 FSD, 로보택시, 옵티머스 로봇, 에너지 비즈니스 등 핵심 성장 동력에 대한 저평가를 초래할 수 있다는 지적입니다.
#
# ---
#
# ### **6. 결론 및 투자 제언**
#
# 테슬라는 현재 전기차 시장의 경쟁 심화와 마진 압박이라는 단기적인 도전 과제에 직면해 있습니다. 이는 시장이 테슬라의 밸류에이션에 대해 회의적인 시각을 가지는 주된 이유입니다.
#
# 그러나 FSD의 지속적인 발전, 옵티머스 로봇의 잠재력, 그리고 에너지 사업 확장은 테슬라가 단순한 자동차 제조업체가 아닌 미래 기술 플랫폼 기업으로 진화할 수 있는 강력한 성장 동력을 제공합니다. 주가 측면에서는 52주 고점에 근접해 있어 단기적인 상승 여력은 제한적일 수 있으나, 장기적인 관점에서는 현재 시장이 간과하고 있을 수 있는 미래 기술의 가치에 주목할 필요가 있습니다.
#
# 따라서, 테슬라에 대한 투자는 단기적인 시장 변동성보다는 FSD, 옵티머스 등 혁신적인 기술의 상용화와 이에 따른 기업 가치 변화 가능성에 초점을 맞춘 **장기적인 관점의 접근이 유효**할 것으로 판단됩니다. 현재 가격은 단기적으로 부담스러울 수 있으나, 미래 성장 동력의 잠재력을 고려할 때 **지속적인 관심과 면밀한 모니터링이 필요**합니다.
#
# **투자자께서는 본 리포트의 내용을 참고하시어 개인의 투자 목표와 위험 감수 수준에 맞는 신중한 결정을 내리시기를 권고합니다.**
#
# ---
#
#
# ++++++++++ 👑 ORCHESTRATOR AGENT (Turn 5) ++++++++++
# 사용자의 복합 질문을 분석하고, 어떤 전문가 Agent를 호출할지 계획을 세웁니다...
#
# ----- 🚦 ORCHESTRATOR ROUTER -----
# 분기: [generate_report] -> 최종 리포트 생성을 시작합니다.
#
#
# --- 👑 ORCHESTRATOR AGENT ---
# ================================== Ai Message ==================================
#
# 모든 정보 수집 완료
#
#
# ++++++++++ 💎 ORCHESTRATOR REPORTER ++++++++++
# 모든 전문가 Agent의 분석 결과를 종합하여 최종 리포트를 작성합니다...
#
# --- 💎 ORCHESTRATOR REPORTER ---
# ================================== Ai Message ==================================
#
# ## 최고 투자 책임자(CIO) 종합 투자 리포트
#
# **작성일:** 2025년 10월 31일 (제공된 정보 기준)
# **대상 포트폴리오:** NVDA, AAPL, TSLA
#
# ---
#
# ### **[요약]**
#
# 고객님의 포트폴리오에 포함된 엔비디아(NVDA), 애플(AAPL), 테슬라(TSLA) 세 종목에 대한 심층 분석 결과, 각 기업은 고유한 강점과 미래 성장 동력을 보유하고 있으나, 동시에 상당한 단기적 리스크와 부정적 이슈에 직면해 있습니다. 전반적으로 시장의 높은 기대감이 주가에 선반영되어 밸류에이션 부담이 커진 상황이며, 각 기업별로 특정 사업 부문의 부진 또는 논란이 투자 심리에 영향을 미치고 있습니다. 따라서 현재 시점에서는 신중한 접근과 면밀한 모니터링이 필수적입니다.
#
# ---
#
# ### **1. 종목별 분석**
#
# #### **1.1. 엔비디아 (NVDA)**
#
# *   **최신 주가:** $207.04 (2025년 10월 29일 기준)
# *   **긍정적 요인:** AI 산업의 핵심 플레이어로서 독보적인 시장 지위, AI 성장론에 기반한 강력한 상승 모멘텀, 미중 정상회담 등 거시경제 긍정 요인.
# *   **부정적 뉴스 및 우려:**
#     *   **GPU 공급 관련 의혹:** "없어서 못 판다"는 GPU를 국내에 26만장 우선 공급한다는 소식에 대해 "땡처리", "끝물에 최고가에 떠넘기려는 것"이라는 강한 의혹 제기.
#     *   **실적 부풀리기 의혹:** 하청업체에 매입을 시켜 실적을 올린다는 비판적 시각.
#     *   **높은 밸류에이션 논란:** 현재 주가가 역사적 고점 부근에 위치하여 추가 상승 여력에 대한 이견 존재.
# *   **투자 제언 (애널리스트 의견):**
#     *   **신규 투자자:** '관망(Hold)' 포지션 유지. GPU 공급 관련 논란에 대한 명확한 해명 및 실적 발표를 기다리는 보수적 접근 권고.
#     *   **기존 투자자:** AI 성장론에 대한 장기적 믿음이 있다면 보유 유지, 단기 주가 상승을 감안한 '일부 차익 실현(Partial Profit-Taking)' 고려하여 리스크 관리.
#
# #### **1.2. 애플 (AAPL)**
#
# *   **최신 주가:** $271.40 (2024년 10월 27일 기준, 직전 24시간 대비 0.63% 상승)
# *   **긍정적 요인:** 최근 몇 주간 꾸준한 상승세로 사상 최고치 근접, 단기적으로 긍정적인 시장 분위기.
# *   **부정적 뉴스 및 우려:**
#     *   **'매도' 등급 하향 조정:** MoffettNathanson의 수석 애널리스트가 '매도'로 등급 하향 및 목표가 $188 제시 (현재 주가 대비 30% 이상 하락 가능성). 주가가 지나치게 고평가되었다는 지적.
#     *   **검색 엔진 계약 문제:** 구글과의 250억 달러 규모 검색 엔진 계약이 불법으로 판결, 애플 수익 구조에 중대한 리스크.
#     *   **중국 시장 판매 부진:** 아이폰 판매 기대치 하회.
#     *   **신제품 및 AI 기능 회의론:** 비전 프로 헤드셋 성과 미비, 아이폰 16 판매 부진, 새로운 AI 기능에 대한 소비자 매력 부족.
# *   **투자 제언 (애널리스트 의견):**
#     *   **단기 투자자:** 엄격한 손절매 설정 필수.
#     *   **장기 투자자:** 현재 주가 수준은 과도하게 고평가된 것으로 판단되며, 신규 진입은 매우 보수적으로 접근하거나 보류 권고. 부정적 뉴스가 해소되고 명확한 성장 동력이 확인될 때까지 관망 필요.
#
# #### **1.3. 테슬라 (TSLA)**
#
# *   **최신 주가:** 약 $461.51 (2024년 12월 18일 기준)
# *   **긍정적 요인:** FSD(Full Self-Driving) 기술의 지속적인 발전 및 사용자 만족도 상승, 옵티머스 로봇의 혁신적 잠재력, 에너지 사업의 미래 성장 동력.
# *   **부정적 뉴스 및 우려:**
#     *   **성장 둔화 우려:** 경쟁 심화로 인한 시장 점유율 하락 가능성, 신규 양산 모델 부재 및 25,000달러 모델 출시 지연.
#     *   **수익성 악화:** 잦은 가격 인하로 인한 마진 압박 지속, 매출총이익률 급락.
#     *   **과도한 밸류에이션 논란:** 자동차 업계 평균 대비 현저히 높은 PER, 미래 가치 선반영 지적.
#     *   **애널리스트 및 언론의 정보 편향성:** 테슬라의 혁신을 제대로 평가하지 못하고 부정적 뉴스에 편향된 시각 존재.
# *   **투자 제언 (애널리스트 의견):**
#     *   단기적인 시장 변동성보다는 FSD, 옵티머스 등 혁신 기술의 상용화 및 기업 가치 변화 가능성에 초점을 맞춘 **장기적인 관점의 접근이 유효**.
#     *   현재 가격은 단기적으로 부담스러울 수 있으나, 미래 성장 동력의 잠재력을 고려할 때 **지속적인 관심과 면밀한 모니터링이 필요**.
#
# ---
#
# ### **2. 종합 결론 및 투자 전략**
#
# 고객님의 포트폴리오에 있는 NVDA, AAPL, TSLA는 모두 혁신적인 기술과 강력한 브랜드 파워를 가진 선도 기업입니다. 그러나 현재 시점에서는 각 종목이 높은 밸류에이션 부담과 함께 고유한 단기적 리스크에 직면해 있습니다.
#
# *   **밸류에이션 부담:** 세 종목 모두 미래 성장 기대감이 주가에 상당 부분 선반영되어 있어, 현재 주가 수준에서 추가 상승 여력에 대한 회의적인 시각이 존재합니다. 특히 애플은 주요 애널리스트로부터 '매도' 의견과 함께 목표가 하향 조정이 이루어졌습니다.
# *   **사업적 리스크:** 엔비디아는 GPU 공급 및 실적 부풀리기 의혹, 애플은 검색 엔진 계약 문제와 중국 시장 부진, 테슬라는 전기차 판매 둔화와 마진 압박 등 각 기업의 핵심 사업 부문에서 부정적인 이슈가 부각되고 있습니다.
# *   **장기 성장 동력 vs. 단기 변동성:** 엔비디아의 AI, 테슬라의 FSD 및 옵티머스 로봇 등 강력한 장기 성장 동력은 여전히 유효하지만, 단기적인 시장 변동성과 부정적 뉴스에 대한 투자 심리 위축 가능성을 간과할 수 없습니다.
#
# **CIO의 종합 투자 전략 제언:**
#
# 1.  **리스크 관리 강화:** 현재 포트폴리오의 높은 밸류에이션과 잠재적 리스크를 고려하여, 전체 포트폴리오의 리스크 노출을 점검하고 필요시 일부 포지션에 대한 **차익 실현 또는 비중 축소**를 고려해야 합니다. 특히 단기 하방 리스크가 크게 부각된 애플에 대해서는 보수적인 접근이 필요합니다.
# 2.  **신규 투자 보류 및 관망:** 현재 시점에서 세 종목 모두에 대한 신규 투자는 매우 신중하게 접근하거나 **보류**하는 것이 현명합니다. 각 기업의 주요 리스크 요인(GPU 공급 의혹 해소, 애플의 핵심 사업 부진 개선, 테슬라의 FSD 상용화 진전 등)에 대한 명확한 해결책과 긍정적인 신호가 나타날 때까지 **관망(Hold)** 포지션을 유지하는 것을 권고합니다.
# 3.  **장기적 관점 유지 (선별적):** 테슬라와 엔비디아의 경우, AI 및 자율주행, 로봇 등 미래 혁신 기술의 장기적인 성장 잠재력은 여전히 높습니다. 따라서 이들 기업의 **장기적인 비전을 믿는 투자자라면 보유 포지션을 유지**하되, 시장의 주요 모니터링 포인트를 지속적으로 추적하며 기업의 펀더멘털 변화에 주의를 기울여야 합니다.
# 4.  **정보의 다각적 분석:** 언론이나 일부 애널리스트의 편향된 시각에만 의존하기보다는, 기업의 공식 발표, 실적 보고서, 그리고 독립적인 분석 자료를 종합적으로 검토하여 균형 잡힌 시각을 유지하는 것이 중요합니다.
#
# **주요 모니터링 포인트:**
#
# *   각 기업의 분기별 실적 발표 및 가이던스
# *   부정적 뉴스(GPU 공급 의혹, 검색 엔진 계약 등)에 대한 기업 측의 공식 해명 및 해결 방안
# *   거시 경제 지표 및 연준의 통화 정책 변화
# *   경쟁사들의 기술 개발 및 시장 점유율 변화
#
# ---
#
# **면책 조항:** 본 리포트는 제공된 정보를 바탕으로 한 CIO의 종합적인 투자 의견이며, 투자 권유를 목적으로 하지 않습니다. 모든 투자 결정은 투자자 본인의 판단과 책임 하에 이루어져야 합니다. 시장 상황은 언제든지 변동될 수 있으며, 과거의 성과가 미래의 수익을 보장하지 않습니다.
#
# ✅ Orchestrator 실행이 완료되었습니다.

# %% [markdown]
# 👇 아래 버튼을 눌러 코드를 실행합니다.

# %%
stop_mcp_server(port=8000, service_name="금융 정보")
stop_mcp_server(port=8001, service_name="포트폴리오 DB")
# Out:
# 🛑 금융 정보 MCP 서버(Port: 8000)를 종료합니다...
# ✅ 금융 정보 서버가 종료되었습니다.
#
# 🛑 포트폴리오 DB MCP 서버(Port: 8001)를 종료합니다...
# ✅ 포트폴리오 DB 서버가 종료되었습니다.
